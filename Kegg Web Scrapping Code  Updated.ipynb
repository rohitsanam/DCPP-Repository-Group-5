# %%
import pandas as pd
import numpy as np
import requests 
from bs4 import BeautifulSoup

# %%
import re

# %%
import json

# %%
with open('kegg_urls.json') as f:
    urls=json.load(f)

# %%
urls
# Out:
# ['https://www.kegg.jp/entry/H02420',
#  'https://www.kegg.jp/entry/H00016',
#  'https://www.kegg.jp/entry/H01508',
#  'https://www.kegg.jp/entry/H01509',
#  'https://www.kegg.jp/entry/H01559',
#  'https://www.kegg.jp/entry/H00054',
#  'https://www.kegg.jp/entry/H00055',
#  'https://www.kegg.jp/entry/H00017',
#  'https://www.kegg.jp/entry/H00018',
#  'https://www.kegg.jp/entry/H00034',
#  'https://www.kegg.jp/entry/H00020',
#  'https://www.kegg.jp/entry/H00044',
#  'https://www.kegg.jp/entry/H00048',
#  'https://www.kegg.jp/entry/H02302',
#  'https://www.kegg.jp/entry/H01557',
#  'https://www.kegg.jp/entry/H00046',
#  'https://www.kegg.jp/entry/H00047',
#  'https://www.kegg.jp/entry/H00019',
#  'https://www.kegg.jp/entry/H00045',
#  'https://www.kegg.jp/entry/H01591',
#  'https://www.kegg.jp/entry/H00014',
#  'https://www.kegg.jp/entry/H00013',
#  'https://www.kegg.jp/entry/H00015',
#  'https://www.kegg.jp/entry/H00038',
#  'https://www.kegg.jp/entry/H00039',
# ...

# %%
tab={'Entry':[],'Name':[],'Description':[],'Category':[],'Brite':[]}

# %%
err_url=[]

# %%
for i in urls:
    print(i)  
    try:
        url = i
        response = requests.get(url)
        html = response.text
        soup = BeautifulSoup(html,'html.parser')
        a=soup.find_all('th',string=re.compile('Entry'))[0].find_next_siblings()[0].text.strip()
        tab['Entry'].append(re.findall('[H0-9]+',a))
        tab['Name'].append(soup.find_all('th',string=re.compile('Name'))[0].find_next_siblings()[0].text.strip())
        tab['Description'].append(soup.find_all('th',string=re.compile('Description'))[0].find_next_siblings()[0].text.strip())
        tab['Category'].append(soup.find_all('th',string=re.compile('Category'))[0].find_next_siblings()[0].text.strip())
        tab['Brite'].append(soup.find_all('th',string=re.compile('Brite'))[0].find_next_siblings()[0].text.strip())
    except IndexError:
        err_url.append(i)
        urls.remove(i)
# Out:
# https://www.kegg.jp/entry/H02420
# https://www.kegg.jp/entry/H00016
# https://www.kegg.jp/entry/H01508
# https://www.kegg.jp/entry/H01509
# https://www.kegg.jp/entry/H01559
# https://www.kegg.jp/entry/H00054
# https://www.kegg.jp/entry/H00055
# https://www.kegg.jp/entry/H00017
# https://www.kegg.jp/entry/H00018
# https://www.kegg.jp/entry/H00034
# https://www.kegg.jp/entry/H00020
# https://www.kegg.jp/entry/H00044
# https://www.kegg.jp/entry/H00048
# https://www.kegg.jp/entry/H02302
# https://www.kegg.jp/entry/H01557
# https://www.kegg.jp/entry/H00046
# https://www.kegg.jp/entry/H00047
# https://www.kegg.jp/entry/H00019
# https://www.kegg.jp/entry/H00045
# https://www.kegg.jp/entry/H01591
# https://www.kegg.jp/entry/H00014
# https://www.kegg.jp/entry/H00013
# https://www.kegg.jp/entry/H00015
# https://www.kegg.jp/entry/H00038
# https://www.kegg.jp/entry/H00039
# https://www.kegg.jp/entry/H00040
# https://www.kegg.jp/entry/H01555
# https://www.kegg.jp/entry/H01463
# ...

# %%
err_url
# Out:
# []

# %%
df=pd.DataFrame(tab)

# %%
df.head()
# Out:
#       Entry                   Name  \
# 0  [H02420]   Head and neck cancer
# 1  [H00016]            Oral cancer
# 2  [H01508]  Salivary gland cancer
# 3  [H01509]       Tonsillar cancer
# 4  [H01559]   Oropharyngeal cancer
#
#                                          Description Category  \
# 0  Head and neck cancers are a heterogeneous coll...   Cancer
# 1  Oral cancer refers to a subgroup of head and n...   Cancer
# 2  Salivary gland carcinomas are rare tumours rep...   Cancer
# 3  Tonsillar cancer (TC) is the most common oroph...   Cancer
# 4  Oropharyngeal cancer is a generic term that in...   Cancer
#
#                                                Brite
# 0  Human diseases [BR:br08402]\n Cancers\n  Head ...
# 1  Human diseases [BR:br08402]\n Cancers\n  Head ...
# 2  Human diseases [BR:br08402]\n Cancers\n  Head ...
# 3  Human diseases [BR:br08402]\n Cancers\n  Head ...
# 4  Human diseases [BR:br08402]\n Cancers\n  Head ...

# %%
df.to_csv('all data kegg.csv',index=False)

# %%
tab2={'Entry':[],'Name':[],'Carcinogen':[],'Drug':[],'Gene':[]}

# %%
for i in urls:
    print(i)  
    try:
        url = i
        response = requests.get(url)
        html = response.text
        soup = BeautifulSoup(html,'html.parser')
        a=soup.find_all('th',string=re.compile('Entry'))[0].find_next_siblings()[0].text.strip()
        tab2['Entry'].append(re.findall('[H0-9]+',a))
        tab2['Name'].append(soup.find_all('th',string=re.compile('Name'))[0].find_next_siblings()[0].text.strip())
        if len(soup.find_all('th',string=re.compile('Carcinogen')))==0:
            tab2['Carcinogen'].append('')
        else:
            tab2['Carcinogen'].append(soup.find_all('th',string=re.compile('Carcinogen'))[0].find_next_siblings()[0].text.strip())
        if len(soup.find_all('th',string=re.compile('Drug')))==0:
            tab2['Drug'].append('')
        else:
            tab2['Drug'].append(soup.find_all('th',string=re.compile('Drug'))[0].find_next_siblings()[0].text.strip())
        if len(soup.find_all('th',string=re.compile('Gene')))==0:
            tab2['Gene'].append('')
        else:
            tab2['Gene'].append(soup.find_all('th',string=re.compile('Gene'))[0].find_next_siblings()[0].text.strip())
    except IndexError:
        err_url.append(i)
        urls.remove(i)
# Out:
# https://www.kegg.jp/entry/H02420
# https://www.kegg.jp/entry/H00016
# https://www.kegg.jp/entry/H01508
# https://www.kegg.jp/entry/H01509
# https://www.kegg.jp/entry/H01559
# https://www.kegg.jp/entry/H00054
# https://www.kegg.jp/entry/H00055
# https://www.kegg.jp/entry/H00017
# https://www.kegg.jp/entry/H00018
# https://www.kegg.jp/entry/H00034
# https://www.kegg.jp/entry/H00020
# https://www.kegg.jp/entry/H00044
# https://www.kegg.jp/entry/H00048
# https://www.kegg.jp/entry/H02302
# https://www.kegg.jp/entry/H01557
# https://www.kegg.jp/entry/H00046
# https://www.kegg.jp/entry/H00047
# https://www.kegg.jp/entry/H00019
# https://www.kegg.jp/entry/H00045
# https://www.kegg.jp/entry/H01591
# https://www.kegg.jp/entry/H00014
# https://www.kegg.jp/entry/H00013
# https://www.kegg.jp/entry/H00015
# https://www.kegg.jp/entry/H00038
# https://www.kegg.jp/entry/H00039
# https://www.kegg.jp/entry/H00040
# https://www.kegg.jp/entry/H01555
# https://www.kegg.jp/entry/H01463
# ...

# %%
#df2=pd.DataFrame(tab_carcinogenic)
#df2.to_csv('kegg carcinogenic.csv',index=False)

# %%
df2=pd.DataFrame(tab2)
df2.head()
# Out:
#       Entry                   Name  \
# 0  [H02420]   Head and neck cancer
# 1  [H00016]            Oral cancer
# 2  [H01508]  Salivary gland cancer
# 3  [H01509]       Tonsillar cancer
# 4  [H01559]   Oropharyngeal cancer
#
#                                           Carcinogen  \
# 0
# 1  Alcoholic beverages\nAreca nut\nBetel quid wit...
# 2
# 3                                   Alcohol\nTobacco
# 4                        Tobacco\nAlcohol\nAreca nut
#
#                                                 Drug  \
# 0  Methotrexate sodium [DR:D02115]\nDocetaxel [DR...
# 1
# 2
# 3
# 4
#
#                                                 Gene
# 0
# 1  p53 (mutation, deletion) [HSA:7157] [KO:K04451...
# 2  CRTC1-MAML2 (translocation) [HSA:23373 84441] ...
# 3  CDKN2A (overexpression) [HSA:1029] [KO:K06621]...
# 4  TP53 (mutation) [HSA:7157] [KO:K04451]\nEGFR (...

# %%
df.count()
# Out:
# Entry          2260
# Name           2260
# Description    2260
# Category       2260
# Brite          2260
# dtype: int64

# %%
entry1=[]
for i in df['Entry']:
    entry1.append(i[0])
entry2=[]
for i in df['Entry']:
    entry2.append(i[0])

# %%
df['Entry_Final']=entry1
df2['Entry_Final']=entry2

# %%
df_all=df.merge(df2,on='Entry_Final',how='left')

# %%
df_all.drop(columns=['Entry_y','Name_y'],inplace=True)
#df_all.drop(columns=['Entry_x'],inplace=True)
df_all.rename(columns={'Name_x':'Name','Entry_Final':'Entry'},inplace=True)
df_all.head()
# Out:
#                     Name                                        Description  \
# 0   Head and neck cancer  Head and neck cancers are a heterogeneous coll...
# 1            Oral cancer  Oral cancer refers to a subgroup of head and n...
# 2  Salivary gland cancer  Salivary gland carcinomas are rare tumours rep...
# 3       Tonsillar cancer  Tonsillar cancer (TC) is the most common oroph...
# 4   Oropharyngeal cancer  Oropharyngeal cancer is a generic term that in...
#
#   Category                                              Brite   Entry  \
# 0   Cancer  Human diseases [BR:br08402]\n Cancers\n  Head ...  H02420
# 1   Cancer  Human diseases [BR:br08402]\n Cancers\n  Head ...  H00016
# 2   Cancer  Human diseases [BR:br08402]\n Cancers\n  Head ...  H01508
# 3   Cancer  Human diseases [BR:br08402]\n Cancers\n  Head ...  H01509
# 4   Cancer  Human diseases [BR:br08402]\n Cancers\n  Head ...  H01559
#
#                                           Carcinogen  \
# 0
# ...

# %%
df_all=df_all[['Entry','Name','Description','Category','Brite','Carcinogen','Drug','Gene']]

# %%
df_all.to_csv('kegg disease.csv',index=False)

# %% [markdown]
# # Below is testing

# %%
url = "https://www.genome.jp/entry/H02420"
response = requests.get(url)
html = response.text
print(html)
# Out:
# <!doctype html>
# <html><head>
# <title>KEGG DISEASE: Head and neck cancer</title>
# <link type="text/css" rel="stylesheet" href="/css/gn2.css?1634759381">
# <link type="text/css" rel="stylesheet" href="/css/bget.css?1634759381">
# <link rel="stylesheet" href="/css/bget.css?1634759381" type="text/css">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <link rel="stylesheet" type="text/css" href="/css/bgetm.css?1634759381" media="only screen and (max-width: 768px)">
# <style>.kcfd{display:none;}</style>
# <script>
# <!--
# var getElementsByClassName = document.getElementsByClassName ?
#   function (cl){
#     return document.getElementsByClassName(cl);
#   } :
#   function (cl){
#     var elms = [];
#     var objs = document.getElementsByTagName('*');
#     for(var i=0;i<objs.length;i++){
#       var obj = objs[i];
#       if(obj.className == cl){
#         elms.push(obj);
#       }
#     }
#     return elms;
#   };
# function toggleField(clk,cl,show,hide){
# ...

# %%
soup = BeautifulSoup(html,'html.parser')
soup.prettify

# %%
#printing our HTML
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    KEGG DISEASE: Prune belly syndrome
#   </title>
#   <link href="/css/gn2.css?1634759022" rel="stylesheet" type="text/css"/>
#   <link href="/css/bget.css?1634759022" rel="stylesheet" type="text/css"/>
#   <link href="/css/bget.css?1634759022" rel="stylesheet" type="text/css"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="/css/bgetm.css?1634759022" media="only screen and (max-width: 768px)" rel="stylesheet" type="text/css"/>
#   <style>
#    .kcfd{display:none;}
#   </style>
#   <script>
#    <!--
# var getElementsByClassName = document.getElementsByClassName ?
#   function (cl){
#     return document.getElementsByClassName(cl);
#   } :
#   function (cl){
#     var elms = [];
#     var objs = document.getElementsByTagName('*');
#     for(var i=0;i<objs.length;i++){
#       var obj = objs[i];
#       if(obj.className == cl){
#         elms.push(obj);
#       }
#     }
#     return elms;
# ...

# %%
len(soup.find_all('th',string=re.compile('Carcinogenic')))
# Out:
# 0

# %%
tab1={}

# %%
tab1['Entry']=[soup.find_all('th',string=re.compile('Entry'))[0].find_next_siblings()[0].text.strip()]
a=soup.find_all('th',string=re.compile('Entry'))[0].find_next_siblings()[0].text.strip()

# %%
print(re.findall('[H0-9]+',a))

# %%
tab['Name']=[soup.find_all('th',string=re.compile('Name'))[0].find_next_siblings()[0].text]

# %%
tab['Description']=[soup.find_all('th',string=re.compile('Description'))[0].find_next_siblings()[0].text]

# %%
tab['Category']=[soup.find_all('th',string=re.compile('Category'))[0].find_next_siblings()[0].text]

# %%
tab['Brite']=[soup.find_all('th',string=re.compile('Brite'))[0].find_next_siblings()[0].text]

# %%
tab

# %%
df=pd.DataFrame(tab)

# %%
df

# %%
tab1=tab
tab1['Entry'].append('i')
tab1

# %%
url = "https://www.kegg.jp/brite/br08402"
response = requests.get(url)
html = response.text
print(html)

# %%
soup = BeautifulSoup(html,'html.parser')
print(soup.prettify())

# %%
qwerty='''<!DOCTYPE html>
<html lang="en">
 <head>
  <meta charset="utf-8"/>
  <meta content="width=device-width,initial-scale=1" name="viewport"/>
  <title>
   KEGG BRITE: Human Diseases
  </title>
  <link href="https://www.kegg.jp/brite/br08402" rel="canonical"/>
  <script asrc="/js/jquery-3.1.0.min.js" src="/js/jquery-3.5.1.min.js">
  </script>
  <script src="/js/jquery-ui.js">
  </script>
  <script src="/js/jquery.balloon.min.js">
  </script>
  <script src="/js/lz-string.min.js">
  </script>
  <script src="/kegg-bin/get_data.cgi?data=0021&amp;id=show_brite.merged.js&amp;v1.02">
  </script>
  <link href="/css/kegg.css?v1.02" rel="stylesheet" type="text/css"/>
  <link href="/css/get_htext.css?v1.02" rel="stylesheet" type="text/css"/>
  <link href="/css/kegg-brite-viewer.css?v1.02" rel="stylesheet">
   <link href="/css/kegg-brite-control-panel.css?v1.02" rel="stylesheet">
    <link href="/css/jquery-ui.css" rel="stylesheet">
     <style type="text/css">
      html, body { -webkit-text-size-adjust: 100%; }
body > .footer hr { margin-top: 0px; }
body > .footer { margin-top: 5px; }
h2 .subtitle:before { content: ' - '; }
.hidden { display: none ! important; }
#waiting-circle {
  position: fixed;
  top: 20px;
  right: 20px;
  display: none;
}

#scroll-to-top {
  position: fixed;
  display: none;
  right: 10px;
  bottom: 10px;
  cursor: pointer;
  z-index: 10;
}
     </style>
     <script type="text/javascript">
      <!--

$(function () {
	$('.change-type')
	.on('click', function () {
		let url = '/kegg-bin/list_menu?id=br08402'
		window.open(url, 'menu_win', 'menubar=no,toolbar=no,scrollbars=yes,resizable=yes,width=500,height=700');
	})
	.balloon({
		position: 'right',
		contents: 'Open window to change prefix of 08402',
		css: {
			fontSize: '1.0em'
		}
	})
})

function change_proc_enabled(item)
{
  var form = item.form;

  var value = "";
	var type = item.type.toLowerCase();
	if (type === 'checkbox') {
  	if (item.checked) value = item.value;
	}
	else if (type === 'select-one') {
		var index = item.options.selectedIndex;
		value = item.options[index].value;
	}
	else {
		alert('Unknow element type: ' + item.type);
		return;
	}

  form.proc_enabled.value = value;
  submit_form(form, "");
}

function submit_form(form, action)
{
  if(action == "")
  {
    action = "/kegg-bin/show_brite";
  }

  form.action = action;
  form.submit();
}

// -->
     </script>
    </link>
   </link>
  </link>
 </head>
 <body>
  <h2>
   <a href="/kegg/brite.html">
    <img align="middle" border="0" src="/Fig/bget/kegg3.gif"/>
   </a>
   Human Diseases
  </h2>
  <div id="scroll-to-top">
   <svg height="25" width="25">
    <g transform="scale(0.25)">
     <circle cx="50" cy="50" fill="#ffffff" fill-opacity="0.7" r="43" stroke="#999999" stroke-width="7">
     </circle>
     <path d="M50 20 L20 50 L80 50 Z" style="fill:#999999">
     </path>
     <line stroke="#999999" stroke-width="10" x1="50" x2="50" y1="50" y2="80">
     </line>
    </g>
   </svg>
  </div>
  <form action="/kegg-bin/show_brite" method="post" name="selmenu" style="margin:0px;">
   <input name="htext" type="hidden" value="br08402"/>
   <input name="filedir" type="hidden" value=""/>
   <input name="highlight" type="hidden" value=""/>
   <input name="option" type="hidden"/>
   <input name="extend" type="hidden" value=""/>
   <input name="uploadfile" type="hidden" value=""/>
   <input name="format" type="hidden" value=""/>
   <input name="wrap" type="hidden" value=""/>
   <input name="length" type="hidden" value=""/>
   <input name="open" type="hidden" value=""/>
   <input name="close" type="hidden" value=""/>
   <input name="hier" type="hidden" value=""/>
   <input name="no_menu" type="hidden" value=""/>
   <table style="border-collapse:collapse;">
    <tr>
     <td>
      [
      <a href="/kegg-bin/show_brite?query=08402&amp;htext=br08902.keg&amp;option=-b&amp;panel=collapse">
       Brite menu
      </a>
      |
      <a href="/kegg-bin/download_htext?htext=br08402&amp;format=htext&amp;filedir=">
       Download htext
      </a>
      |
      <a href="/kegg-bin/download_htext?htext=br08402&amp;format=json&amp;filedir=">
       Download json
      </a>
      |
      <a href="javascript:void(window.open('/kegg/document/help_brite.html','KEGG_Help','width=720,height=640'))">
       Help
      </a>
      ]
     </td>
     <td>
     </td>
    </tr>
    <tr>
     <td style="padding-right:20px;">
     </td>
     <td>
     </td>
    </tr>
   </table>
  </form>
  <hr/>
  <div id="tree">
  </div>
  <div id="controlPanel">
   <div class="controller">
    <h5>
     Option
     <span class="ui-icon ui-icon-close clear-filter hidden">
     </span>
    </h5>
    <div class="option">
     <div class="row">
      <label>
       <input class="eventTrigger" data-type="expandMode" type="checkbox"/>
       One-click mode
      </label>
     </div>
     <div class="row">
      <label>
       <input class="eventTrigger" data-type="rowBorder" type="checkbox"/>
       Row border
      </label>
      <label style="margin-left:5px;">
       <input class="eventTrigger" data-type="rowStripe" type="checkbox"/>
       shading
      </label>
     </div>
     <div class="row hidden">
      <label>
       <!-- e.g. show_brite?pruning=neighbor:off -->
       <input checked="" class="eventTrigger" data-type="pruningNeighborNode" type="checkbox"/>
       Pruning neighbor node
      </label>
     </div>
    </div>
    <h5>
     Search
     <span class="ui-icon ui-icon-shuffle search pruning">
     </span>
    </h5>
    <div>
     <form class="search">
      <div class="row query">
       <input autocomplete="off" class="query" name="query" style="width:110px;" type="text" value=""/>
       <input class="submit" type="button" value="Go"/>
       <span class="ui-icon ui-icon-close clear-query hidden">
       </span>
      </div>
      <div class="row searchResult" style="margin-top:5px; display:none;">
       <hr align="left" style="color:#dddddd; width:95%;"/>
       <span class="current">
        0
       </span>
       /
       <span class="all">
        0
       </span>
       <button class="move prev" type="button">
        <svg height="10px" width="16px">
         <polyline fill="none" points="2,8,8,2,14,8" stroke="#000">
         </polyline>
        </svg>
       </button>
       <button class="move next" type="button">
        <svg height="10px" width="16px">
         <polyline fill="none" points="2,2,8,8,14,2" stroke="#000">
         </polyline>
        </svg>
       </button>
      </div>
     </form>
    </div>
    <h5>
     ID search
     <span class="ui-icon ui-icon-shuffle search-brite pruning">
     </span>
     <span class="ui-icon ui-icon-plus search-brite">
     </span>
    </h5>
    <div class="mapper search-brite">
     <form class="query">
      <div class="row" style="display:grid; grid-template-columns:1fr 1fr; column-gap:5px;">
       <div>
        <textarea class="query" rows="2" style="width:110px; resize:none;"></textarea>
       </div>
       <div>
        <input class="submit" type="button" value="Go"/>
        <span class="ui-icon ui-icon-close clear-query hidden">
        </span>
       </div>
      </div>
     </form>
     <ul class="personal simple hidden">
     </ul>
    </div>
    <h5>
     Join
     <span class="ui-icon ui-icon-lightbulb join-brite id-highlight">
     </span>
     <span class="ui-icon ui-icon-shuffle join-brite pruning">
     </span>
     <span class="ui-icon ui-icon-plus join-brite">
     </span>
    </h5>
    <div class="mapper join-brite">
     <ul class="binary-relation simple">
      <li>
       <label>
        <input data-entry="0" data-header="1" data-inherit-entry="1" type="checkbox" value="disease2icd11"/>
        <span class="title">
         ICD-11
        </span>
       </label>
      </li>
      <li>
       <label>
        <input data-entry="0" data-header="1" data-inherit-entry="1" data-line-break=";" type="checkbox" value="disease2relpath"/>
        <span class="title">
         Related pathway
        </span>
       </label>
      </li>
      <li>
       <label>
        <input data-entry="0" data-header="1" data-inherit-entry="1" type="checkbox" value="disease2gene"/>
        <span class="title">
         Gene
        </span>
       </label>
      </li>
     </ul>
     <ul class="personal simple">
     </ul>
    </div>
   </div>
   <button class="close">
    <img src="/Fig/left_triangle_12x12.png"/>
   </button>
   <button class="open">
    <img src="/Fig/right_triangle_12x12.png"/>
   </button>
  </div>
  <div class="footer">
   <hr/>
   [
   <a href="/kegg/disease/">
    DISEASE
   </a>
   |
   <a href="/kegg/brite.html">
    BRITE
   </a>
   |
   <a href="/kegg/kegg2.html">
    KEGG2
   </a>
   |
   <a href="/kegg/">
    KEGG
   </a>
   ]
   <br/>
   Last updated: October 7, 2021
   <br/>
   <br/>
   <a href="/brite/jp08402">
    » Japanese version
   </a>
  </div>
  <div id="waiting-circle">
   <img src="/Fig/waiting-circle-small.gif"/>
  </div>
  <input class="hidden" id="displayControlPanel" type="text" value="">
   <input class="hidden" id="expandClass" type="text" value="">
    <input class="hidden" id="initialExpandedNodes" type="text" value="">
     <input class="hidden" id="expandedNodes" type="text" value="">
      <script type="text/javascript">
       const env = {
    htextNo: '08402',
    org: 'br',
    columnTitle: ["Disease"],
    columnWidth: [],
    joinPruningColumn: [],
    joinPruningQuery: [],
    highlight: {},
    isIndexFile: false,
    visibleIndentHandle: false,
    root: {"isRoot":true,"children":[{"children":[{"values":["Head and neck cancers"],"children":[{"expanded":false,"children":[],"values":["<a href=\"/entry/H02420\">H02420</a>  Head and neck cancer"]},{"values":["<a href=\"/entry/H00016\">H00016</a>  Oral cancer"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01508\">H01508</a>  Salivary gland cancer"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01509\">H01509</a>  Tonsillar cancer"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01559\">H01559</a>  Oropharyngeal cancer"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00054\">H00054</a>  Nasopharyngeal cancer"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00055\">H00055</a>  Laryngeal cancer"]},{"values":["------  Hypopharyngeal cancer"],"expanded":false,"children":[]}],"expanded":false},{"values":["Cancers of the digestive system"],"expanded":false,"children":[{"values":["<a href=\"/entry/H00017\">H00017</a>  Esophageal cancer"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00018\">H00018</a>  Gastric cancer [PATH:<a href=\"/pathway/hsa05226\">hsa05226</a>]"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00034\">H00034</a>  Carcinoid"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00020\">H00020</a>  Colorectal cancer [PATH:<a href=\"/pathway/hsa05210\">hsa05210</a>]"]},{"values":["<a href=\"/entry/H00044\">H00044</a>  Cancer of the anal canal"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00048\">H00048</a>  Hepatocellular carcinoma [PATH:<a href=\"/pathway/hsa05225\">hsa05225</a>]"]},{"values":["<a href=\"/entry/H02302\">H02302</a>  Hepatoblastoma"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01557\">H01557</a>  Hepatic angiosarcoma"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00046\">H00046</a>  Cholangiocarcinoma"]},{"values":["<a href=\"/entry/H00047\">H00047</a>  Gallbladder cancer"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00019\">H00019</a>  Pancreatic cancer [PATH:<a href=\"/pathway/hsa05212\">hsa05212</a>]"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00045\">H00045</a>  Pancreatic neuroendocrine tumor"]},{"values":["<a href=\"/entry/H01591\">H01591</a>  Gastrotintestinal stromal tumor"],"children":[],"expanded":false}]},{"values":["Cancers of the lung and pleura"],"children":[{"children":[],"expanded":false,"values":["<a href=\"/entry/H00014\">H00014</a>  Non-small cell lung cancer [PATH:<a href=\"/pathway/hsa05223\">hsa05223</a>]"]},{"values":["<a href=\"/entry/H00013\">H00013</a>  Small cell lung cancer [PATH:<a href=\"/pathway/hsa05222\">hsa05222</a>]"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00015\">H00015</a>  Malignant pleural mesothelioma"],"expanded":false,"children":[]}],"expanded":false},{"values":["Skin cancers"],"expanded":false,"children":[{"values":["<a href=\"/entry/H00038\">H00038</a>  Melanoma [PATH:<a href=\"/pathway/hsa05218\">hsa05218</a>]"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00039\">H00039</a>  Basal cell carcinoma [PATH:<a href=\"/pathway/hsa05217\">hsa05217</a>]"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00040\">H00040</a>  Squamous cell carcinoma"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01555\">H01555</a>  Merkel cell carcinoma"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01463\">H01463</a>  Mycosis fungoides"]}]},{"expanded":false,"children":[{"expanded":false,"children":[],"values":["<a href=\"/entry/H00036\">H00036</a>  Osteosarcoma"]},{"values":["<a href=\"/entry/H00035\">H00035</a>  Ewing sarcoma"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00053\">H00053</a>  Extraskeletal myxoid chondrosarcoma"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00041\">H00041</a>  Kaposi sarcoma [PATH:<a href=\"/pathway/hsa05167\">hsa05167</a>]"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00049\">H00049</a>  Myxoid liposarcoma"]},{"values":["<a href=\"/entry/H00037\">H00037</a>  Rhabdomyosarcoma"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00050\">H00050</a>  Synovial sarcoma"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00051\">H00051</a>  Alveolar soft part sarcoma"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00052\">H00052</a>  Clear cell sarcoma of soft tissue"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01985\">H01985</a>  Desmoplastic small round cell tumor"]},{"children":[],"expanded":false,"values":["------  Fibrosarcoma"]},{"children":[],"expanded":false,"values":["------  Malignant fibrous histiocytoma (MFH)"]},{"children":[],"expanded":false,"values":["------  Leiomyosarcoma"]},{"values":["<a href=\"/entry/H01666\">H01666</a>  Angiosarcoma"],"expanded":false,"children":[]},{"values":["------  Chondrosarcoma"],"children":[],"expanded":false},{"values":["------  Epithelioid sarcoma"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01665\">H01665</a>  Primary peritoneal carcinoma"]}],"values":["Cancers of soft tissues and bone"]},{"expanded":false,"children":[{"values":["<a href=\"/entry/H00031\">H00031</a>  Breast cancer [PATH:<a href=\"/pathway/hsa05224\">hsa05224</a>]"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00029\">H00029</a>  Vulvar cancer"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00030\">H00030</a>  Cervical cancer"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00026\">H00026</a>  Endometrial cancer [PATH:<a href=\"/pathway/hsa05213\">hsa05213</a>]"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00027\">H00027</a>  Ovarian cancer"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01554\">H01554</a>  Fallopian tube cancer"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00028\">H00028</a>  Choriocarcinoma"],"children":[],"expanded":false}],"values":["Cancers of the breast and female genital organs"]},{"values":["Cancers of male genital organs"],"expanded":false,"children":[{"values":["<a href=\"/entry/H00025\">H00025</a>  Penile cancer"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00024\">H00024</a>  Prostate cancer [PATH:<a href=\"/pathway/hsa05215\">hsa05215</a>]"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00023\">H00023</a>  Testicular cancer"]}]},{"children":[{"values":["<a href=\"/entry/H00021\">H00021</a>  Renal cell carcinoma [PATH:<a href=\"/pathway/hsa05211\">hsa05211</a>]"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02301\">H02301</a>  Nephroblastoma"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00022\">H00022</a>  Bladder cancer [PATH:<a href=\"/pathway/hsa05219\">hsa05219</a>]"],"expanded":false,"children":[]}],"expanded":false,"values":["Cancers of the urinary system"]},{"children":[{"values":["<a href=\"/entry/H01513\">H01513</a>  Retinoblastoma"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00042\">H00042</a>  Glioma [PATH:<a href=\"/pathway/hsa05214\">hsa05214</a>]"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01667\">H01667</a>  Medulloblastoma"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00043\">H00043</a>  Neuroblastoma"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["------  Schwannoma"]},{"values":["<a href=\"/entry/H01556\">H01556</a>  Meningioma"],"expanded":false,"children":[]}],"expanded":false,"values":["Cancers of eye, brain, and central nervous system"]},{"values":["Cancers of endocrine organs"],"expanded":false,"children":[{"expanded":false,"children":[],"values":["<a href=\"/entry/H00032\">H00032</a>  Thyroid cancer [PATH:<a href=\"/pathway/hsa05216\">hsa05216</a>]"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01592\">H01592</a>  Medullary thyroid cancer"]},{"values":["<a href=\"/entry/H00033\">H00033</a>  Adrenal carcinoma"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01510\">H01510</a>  Malignant paraganglioma"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01558\">H01558</a>  Parathyroid carcinoma"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00247\">H00247</a>  Multiple endocrine neoplasia syndrome"]}]},{"expanded":false,"children":[{"values":["<a href=\"/entry/H00007\">H00007</a>  Hodgkin lymphoma"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02418\">H02418</a>  Non-Hodgkin lymphoma"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01613\">H01613</a>  Follicular lymphoma"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02424\">H02424</a>  Primary central nervous system lymphoma"]},{"values":["<a href=\"/entry/H02434\">H02434</a>  Diffuse large B-cell lymphoma, not otherwise specified"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01464\">H01464</a>  Mantle cell lymphoma"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00001\">H00001</a>  B-cell acute lymphoblastic leukemia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00002\">H00002</a>  T-cell acute lymphoblastic leukemia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00008\">H00008</a>  Burkitt lymphoma"]},{"values":["<a href=\"/entry/H00011\">H00011</a>  Lymphoplasmacytic lymphoma"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01463\">H01463</a>  Mycosis fungoides"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01892\">H01892</a>  Peripheral T cell lymphoma"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01601\">H01601</a>  Anaplastic large-cell lymphoma"]},{"values":["<a href=\"/entry/H00010\">H00010</a>  Multiple myeloma"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00005\">H00005</a>  Chronic lymphocytic leukemia"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00006\">H00006</a>  Hairy cell leukemia"]},{"values":["<a href=\"/entry/H00009\">H00009</a>  Adult T-cell leukemia [PATH:<a href=\"/pathway/hsa05166\">hsa05166</a>]"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00003\">H00003</a>  Acute myeloid leukemia [PATH:<a href=\"/pathway/hsa05221\">hsa05221</a>]"]},{"values":["<a href=\"/entry/H00004\">H00004</a>  Chronic myeloid leukemia [PATH:<a href=\"/pathway/hsa05220\">hsa05220</a>]"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02410\">H02410</a>  Myelodysplastic/myeloproliferative neoplasms"]},{"values":["<a href=\"/entry/H02411\">H02411</a>  Chronic myelomonocytic leukemia"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02412\">H02412</a>  Atypical chronic myeloid leukemia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01511\">H01511</a>  Mast-cell leukemia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01605\">H01605</a>  Myelofibrosis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01512\">H01512</a>  Langerhans cell histiocytosis"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02425\">H02425</a>  Erdheim-Chester disease"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01590\">H01590</a>  Chronic eosinophilic leukemia"]},{"values":["<a href=\"/entry/H01599\">H01599</a>  Hypereosinophilic syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00012\">H00012</a>  Polycythemia vera"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01612\">H01612</a>  Essential thrombocytosis"]}],"values":["Cancers of haematopoietic and lymphoid tissues"]},{"values":["Cancer category"],"expanded":false,"children":[{"values":["<a href=\"/entry/H02421\">H02421</a>  Solid tumor"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02427\">H02427</a>  Soft tissue sarcomas"]}]}],"expanded":false,"values":["<b>Cancers</b>"]},{"values":[],"expanded":false,"children":[]},{"values":["<b>Immune system diseases</b>"],"expanded":false,"children":[{"values":["Allergies and autoimmune diseases"],"expanded":false,"children":[{"values":["<a href=\"/entry/H00079\">H00079</a>  Asthma [PATH:<a href=\"/pathway/hsa05310\">hsa05310</a>]"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00080\">H00080</a>  Systemic lupus erythematosus [PATH:<a href=\"/pathway/hsa05322\">hsa05322</a>]"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00081\">H00081</a>  Hashimoto thyroiditis [PATH:<a href=\"/pathway/hsa05320\">hsa05320</a>]"]},{"values":["<a href=\"/entry/H00082\">H00082</a>  Graves disease [PATH:<a href=\"/pathway/hsa05320\">hsa05320</a>]"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00083\">H00083</a>  Allograft rejection [PATH:<a href=\"/pathway/hsa05330\">hsa05330</a>]"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00084\">H00084</a>  Graft-versus-host disease [PATH:<a href=\"/pathway/hsa05332\">hsa05332</a>]"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00346\">H00346</a>  Extrinsic allergic alveolitis"]},{"values":["<a href=\"/entry/H00630\">H00630</a>  Rheumatoid arthritis [PATH:<a href=\"/pathway/hsa05323\">hsa05323</a>]"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01191\">H01191</a>  Asthma with nasal polyps and aspirin intolerance"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01232\">H01232</a>  Syndromic multisystem autoimmune disease"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01275\">H01275</a>  Interleukin 1 receptor antagonist deficiency (DIRA)"]},{"values":["<a href=\"/entry/H01357\">H01357</a>  Allergic contact dermatitis"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01358\">H01358</a>  Atopic dermatitis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01359\">H01359</a>  Anaphylaxis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01360\">H01360</a>  Allergic rhinitis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01782\">H01782</a>  Eosinophilic gastrointestinal disorder"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01361\">H01361</a>  Eosinophilic esophagitis"]},{"values":["<a href=\"/entry/H01362\">H01362</a>  Dermatitis herpetiformis"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01452\">H01452</a>  Pediatric autoimmune neuropsychiatric disorders associated with streptococcal infection"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01476\">H01476</a>  Behcet disease"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01479\">H01479</a>  Castleman disease"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01492\">H01492</a>  Systemic sclerosis"]},{"values":["<a href=\"/entry/H01500\">H01500</a>  Lupus nephritis"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01502\">H01502</a>  Sjogren syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01504\">H01504</a>  Vogt-Koyanagi-Harada syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01516\">H01516</a>  Adult onset Still disease"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01581\">H01581</a>  IgA nephropathy"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01594\">H01594</a>  Myasthenia gravis"]},{"values":["<a href=\"/entry/H01595\">H01595</a>  Cutaneous lupus erythematosus"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01596\">H01596</a>  Lambert-Eaton myasthenic syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01672\">H01672</a>  Juvenile idiopathic arthritis [PATH:<a href=\"/pathway/hsa05323\">hsa05323</a>]"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01674\">H01674</a>  Ankylosing spondylitis"]},{"values":["<a href=\"/entry/H01685\">H01685</a>  Autoimmune hepatitis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01710\">H01710</a>  Mixed connective tissue disease"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01721\">H01721</a>  Anti-glomerular basement membrane (GBM) disease"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01726\">H01726</a>  Membranoproliferative glomerulonephritis"]},{"values":["<a href=\"/entry/H01863\">H01863</a>  Atopic myelitis"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02159\">H02159</a>  Familial cold autoinflammatory syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02402\">H02402</a>  Thyroid eye disease"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02414\">H02414</a>  Autoinflammation, panniculitis, and dermatosis syndrome"],"children":[],"expanded":false}]},{"values":["Primary immunodeficiency"],"expanded":false,"children":[{"values":["<a href=\"/entry/H01725\">H01725</a>  Primary immunodeficiency disease [PATH:<a href=\"/pathway/hsa05340\">hsa05340</a>]"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00085\">H00085</a>  Agammaglobulinemias [PATH:<a href=\"/pathway/hsa05340\">hsa05340</a>]"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00086\">H00086</a>  Hyper IgM syndromes, autosomal recessive type [PATH:<a href=\"/pathway/hsa05340\">hsa05340</a>]"]},{"values":["<a href=\"/entry/H00087\">H00087</a>  Other humoral immunodeficiencies"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02308\">H02308</a>  Immunodeficiency-centromeric instability-facial anomalies syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00088\">H00088</a>  Common variable immunodeficiency [PATH:<a href=\"/pathway/hsa05340\">hsa05340</a>]"]},{"values":["<a href=\"/entry/H00089\">H00089</a>  IFN-gamma/IL-12 axis"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00090\">H00090</a>  NK cell defects"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00091\">H00091</a>  T-B+Severe combined immunodeficiency [PATH:<a href=\"/pathway/hsa05340\">hsa05340</a>]"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00092\">H00092</a>  T-B-Severe combined immunodeficiency [PATH:<a href=\"/pathway/hsa05340\">hsa05340</a>]"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01244\">H01244</a>  T+B+Severe combined immunodeficiencies (SCIDs) [PATH:<a href=\"/pathway/hsa05340\">hsa05340</a>]"]},{"values":["<a href=\"/entry/H00093\">H00093</a>  Combined immunodeficiency [PATH:<a href=\"/pathway/hsa05340\">hsa05340</a>]"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02309\">H02309</a>  Adenosine deaminase deficiency"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01128\">H01128</a>  Reticular dysgenesis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00064\">H00064</a>  Ataxia telangiectasia"]},{"values":["<a href=\"/entry/H00094\">H00094</a>  Immunodeficiency associated with DNA repair defects"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01344\">H01344</a>  Nijmegen syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02015\">H02015</a>  LIG4 syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00095\">H00095</a>  Ectodermal dysplasia associated immunodeficiency [PATH:<a href=\"/pathway/hsa05340\">hsa05340</a>]"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01245\">H01245</a>  Immunodeficiency without anhidrotic ectodermal dysplasia [PATH:<a href=\"/pathway/hsa05340\">hsa05340</a>]"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00096\">H00096</a>  Defects of toll-like receptor signaling"]},{"values":["<a href=\"/entry/H00097\">H00097</a>  Chemokine receptor defect"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00098\">H00098</a>  Chronic granulomatous disease"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00099\">H00099</a>  Leukocyte adhesion deficiency"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00100\">H00100</a>  Neutropenic disorders"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00939\">H00939</a>  Darsun syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01218\">H01218</a>  P14 deficiency"]},{"values":["<a href=\"/entry/H00101\">H00101</a>  Other phagocyte defects"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02021\">H02021</a>  Chediak-Higashi syndrome"]},{"values":["<a href=\"/entry/H02022\">H02022</a>  Griscelli syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02024\">H02024</a>  Neutrophil specific granule deficiency"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02025\">H02025</a>  Myeloperoxidase deficiency"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00102\">H00102</a>  Classic complement pathway component defects"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00103\">H00103</a>  Late complement pathway defects"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00104\">H00104</a>  Alternative complement pathway component defects"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00105\">H00105</a>  Mannose-binding lectin pathway component defects"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00106\">H00106</a>  Complement regulatory protein defects"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00107\">H00107</a>  Other well-defined immunodeficiency syndromes [PATH:<a href=\"/pathway/hsa05340\">hsa05340</a>]"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00108\">H00108</a>  Autoimmune lymphoproliferative syndromes"]},{"values":["<a href=\"/entry/H00109\">H00109</a>  Familial hemophagocytic lymphohistiocytosis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00924\">H00924</a>  Severe combined immunodeficiency with microcephaly, growth retardation, and sensitivity to ionizing radiation"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00984\">H00984</a>  Bare lymphocyte syndrome type1 [PATH:<a href=\"/pathway/hsa05340\">hsa05340</a>]"]},{"values":["<a href=\"/entry/H00985\">H00985</a>  Bare lymphocyte syndrome type2 [PATH:<a href=\"/pathway/hsa05340\">hsa05340</a>]"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00931\">H00931</a>  Growth hormone insensitivity with immunodeficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00962\">H00962</a>  RIDDLE syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01181\">H01181</a>  T-cell immunodeficiency congenital alopecia and nail dystrophy"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00721\">H00721</a>  Pyogenic bacterial infections, recurrent, due to MYD88 deficiency"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01240\">H01240</a>  Immune thrombocytopenia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01387\">H01387</a>  Activated PI3K-delta syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01523\">H01523</a>  Wiskott-Aldrich syndrome"]},{"values":["<a href=\"/entry/H01524\">H01524</a>  DiGeorge syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01968\">H01968</a>  Hyper-IgE syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01969\">H01969</a>  X-linked lymphoproliferative syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01970\">H01970</a>  Lymphoproliferative syndrome 1"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01971\">H01971</a>  IPEX syndrome"]},{"values":["<a href=\"/entry/H01972\">H01972</a>  Autoimmune polyendocrinopathy syndrome type 1 [PATH:<a href=\"/pathway/hsa05340\">hsa05340</a>]"],"expanded":false,"children":[]}]},{"expanded":false,"children":[{"expanded":false,"children":[],"values":["<a href=\"/entry/H00286\">H00286</a>  Crohn disease"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01466\">H01466</a>  Ulcerative colitis [PATH:<a href=\"/pathway/hsa05321\">hsa05321</a>]"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01227\">H01227</a>  Inflammatory bowel disease (IBD) [PATH:<a href=\"/pathway/hsa05321\">hsa05321</a>]"]},{"values":["<a href=\"/entry/H00285\">H00285</a>  Blau syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01309\">H01309</a>  Sarcoidosis, early-onset"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00287\">H00287</a>  Pyogenic sterile arthritis, pyoderma gangrenosum, and acne syndrome"]},{"values":["<a href=\"/entry/H00288\">H00288</a>  Familial Mediterranean fever"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00282\">H00282</a>  Cryopyrin associated periodic syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00290\">H00290</a>  Aicardi-Goutieres syndrome"]},{"values":["<a href=\"/entry/H00291\">H00291</a>  Familial chilblain lupus (FCL)"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00206\">H00206</a>  Mevalonate kinase deficiency"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00912\">H00912</a>  Tumor necrosis factor receptor-associated periodic syndrome"]},{"values":["<a href=\"/entry/H01094\">H01094</a>  Eosinophil peroxidase deficiency"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01109\">H01109</a>  Chronic mucocutaneous candidiasis"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01117\">H01117</a>  Chronic recurrent multifocal osteomyelitis"]},{"values":["<a href=\"/entry/H01136\">H01136</a>  Carboxypeptidase N deficiency"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01491\">H01491</a>  Neuromyelitis optica"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01527\">H01527</a>  Chronic inflammatory demyelinating polyradiculoneuropathy"]},{"values":["<a href=\"/entry/H01689\">H01689</a>  Fisher syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01698\">H01698</a>  Giant cell arteritis"]},{"values":["<a href=\"/entry/H01724\">H01724</a>  HTLV1-associated myelopathy"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01741\">H01741</a>  Autoinflammation lipodystrophy and dermatosis syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01743\">H01743</a>  Autoinflammation and PLCG2-associated antibody deficiency and immune dysregulation"]},{"values":["<a href=\"/entry/H01744\">H01744</a>  Autoinflammatory syndrome with pyogenic bacterial infection and amylopectinosis"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01746\">H01746</a>  STING-associated vasculopathy with onset in infancy"]},{"values":["<a href=\"/entry/H01748\">H01748</a>  Autoinflammation with infantile enterocolitis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01761\">H01761</a>  Immunoglobulin G4-related disease"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01765\">H01765</a>  Eosinophilic sinusitis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01767\">H01767</a>  Henoch-Schonlein purpura nephritis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01812\">H01812</a>  Rasmussen encephalitis"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01842\">H01842</a>  Bickerstaff brainstem encephalitis"]},{"values":["<a href=\"/entry/H01924\">H01924</a>  Sydenham chorea"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02133\">H02133</a>  Vici syndrome"]},{"values":["<a href=\"/entry/H02467\">H02467</a>  Neonatal inflammatory skin and bowel disease"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02484\">H02484</a>  X-linked reticulate pigmentary disorder with systemic manifestations"]}],"values":["Other immune system diseases"]}]},{"values":[],"expanded":false,"children":[]},{"values":["<b>Nervous system diseases</b>"],"children":[{"expanded":false,"children":[{"expanded":false,"children":[],"values":["<a href=\"/entry/H00056\">H00056</a>  Alzheimer disease [PATH:<a href=\"/pathway/hsa05010\">hsa05010</a>]"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00066\">H00066</a>  Lewy body dementia (LBD)"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00057\">H00057</a>  Parkinson disease [PATH:<a href=\"/pathway/hsa05012\">hsa05012</a>]"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01600\">H01600</a>  Parkinsonian syndrome"]},{"values":["<a href=\"/entry/H00058\">H00058</a>  Amyotrophic lateral sclerosis (ALS) [PATH:<a href=\"/pathway/hsa05014\">hsa05014</a>]"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00059\">H00059</a>  Huntington disease [PATH:<a href=\"/pathway/hsa05016\">hsa05016</a>]"]},{"values":["<a href=\"/entry/H01243\">H01243</a>  Huntington disease-like syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00060\">H00060</a>  Dentatorubropallidoluysian atrophy (DRPLA)"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00062\">H00062</a>  Spinal and bulbar muscular atrophy (SBMA)"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00063\">H00063</a>  Spinocerebellar ataxia (SCA) [PATH:<a href=\"/pathway/hsa05017\">hsa05017</a>]"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01478\">H01478</a>  Machado-Joseph disease [PATH:<a href=\"/pathway/hsa05017\">hsa05017</a>]"]},{"values":["<a href=\"/entry/H01038\">H01038</a>  Cerebellar ataxia cayman type"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01170\">H01170</a>  Autosomal recessive spastic ataxia of Charlevoix-Saguenay"]},{"values":["<a href=\"/entry/H01891\">H01891</a>  Autosomal recessive spinocerebellar ataxias [PATH:<a href=\"/pathway/hsa05017\">hsa05017</a>]"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00061\">H00061</a>  Prion disease [PATH:<a href=\"/pathway/hsa05020\">hsa05020</a>]"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00064\">H00064</a>  Ataxia telangiectasia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02014\">H02014</a>  Ataxia-telangiectasia-like syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00065\">H00065</a>  Alexander disease"]},{"values":["<a href=\"/entry/H00075\">H00075</a>  Refsum disease"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00067\">H00067</a>  Friedreich ataxia"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00068\">H00068</a>  Leber hereditary optic atrophy"]},{"values":["<a href=\"/entry/H00076\">H00076</a>  Cockayne syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00077\">H00077</a>  Progressive supranuclear palsy"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00078\">H00078</a>  Frontotemporal lobar degeneration"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02342\">H02342</a>  Frontotemporal dementia and amyotrophic lateral sclerosis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00074\">H00074</a>  Canavan disease"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00264\">H00264</a>  Charcot-Marie-Tooth disease [PATH:<a href=\"/pathway/hsa05022\">hsa05022</a>]"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00455\">H00455</a>  Spinal muscular atrophy [PATH:<a href=\"/pathway/hsa05022\">hsa05022</a>]"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00655\">H00655</a>  McLeod syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00833\">H00833</a>  Neurodegeneration with brain iron accumulation"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02206\">H02206</a>  Aceruloplasminemia"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02207\">H02207</a>  Kufor-Rakeb syndrome"]},{"values":["<a href=\"/entry/H02208\">H02208</a>  Pantothenate kinase-associated neurodegeneration"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02209\">H02209</a>  HARP syndrome"]},{"values":["<a href=\"/entry/H00841\">H00841</a>  Infantile progressive bulbar palsy"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00816\">H00816</a>  Agenesis of the corpus callosum with peripheral neuropathy"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00879\">H00879</a>  Perry syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00845\">H00845</a>  Familial amyloidosis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02322\">H02322</a>  Amyloidosis, Finnish type"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00970\">H00970</a>  Juvenile primary lateral sclerosis [PATH:<a href=\"/pathway/hsa05014\">hsa05014</a>]"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01115\">H01115</a>  Polyneuropathy, hearing loss, ataxia, retinitis pigmentosa, and cataract"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01172\">H01172</a>  Infantile ascending hereditary spastic paralysis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01177\">H01177</a>  Infantile bilateral striatal necrosis"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01184\">H01184</a>  Familial dementia"]},{"values":["<a href=\"/entry/H01185\">H01185</a>  Cerebral amyloid angiopathy"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01204\">H01204</a>  Cerebellar ataxia, mental retardation (MR), and dysequilibrium syndrome (CAMRQ)"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01212\">H01212</a>  Familial encephalopathy with neuroserpin inclusion bodies"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01259\">H01259</a>  Giant axonal neuropathy"]},{"values":["<a href=\"/entry/H01284\">H01284</a>  Marinesco-Sjogren syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01295\">H01295</a>  Neurodegeneration due to cerebral folate transport deficiency"]},{"values":["<a href=\"/entry/H01432\">H01432</a>  Choreoacanthocytosis"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01578\">H01578</a>  Subacute myelo-optico-neuropathy (SMON)"]},{"values":["<a href=\"/entry/H01614\">H01614</a>  Multiple system atrophy"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01616\">H01616</a>  Spinocerebellar degeneration"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01696\">H01696</a>  Subacute sclerosing panencephalitis"]},{"values":["<a href=\"/entry/H01779\">H01779</a>  Neuroferritinopathy"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01807\">H01807</a>  Hereditary diffuse leukoencephalopathy with spheroids"]},{"values":["<a href=\"/entry/H01898\">H01898</a>  PNPLA6-related disorders"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01903\">H01903</a>  Brown-Vialetto-Van Laere syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01036\">H01036</a>  Posterior column ataxia with retinitis pigmentosa"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00749\">H00749</a>  Episodic ataxias"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00832\">H00832</a>  Core neuroacanthocytosis syndromes"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00848\">H00848</a>  Ataxia with ocular apraxia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00856\">H00856</a>  Distal hereditary motor neuropathies"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00869\">H00869</a>  Leukoencephalopathy with vanishing white matter"]},{"values":["<a href=\"/entry/H02200\">H02200</a>  Leukoencephalopathy, progressive, with ovarian failure"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00871\">H00871</a>  Leukoencephalopathy with brain stem and spinal cord involvement and lactate elevation"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00874\">H00874</a>  Leukoencephalopathy with dystonia and motor neuropathy"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02377\">H02377</a>  Leukodystrophy and acquired microcephaly with or without dystonia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00875\">H00875</a>  Megaloencephalic leukoencephalopathy with subcortical cysts"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00878\">H00878</a>  Cystic leukoencephalopathy without megalencephaly"]},{"values":["<a href=\"/entry/H02457\">H02457</a>  Developmental delay, leukoencephalopathy, and neurologic decompensation"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00999\">H00999</a>  Coenzyme Q10 deficiency"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01570\">H01570</a>  Autosomal dominant striatal degeneration"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01574\">H01574</a>  Familial idiopathic basal ganglia calcification"]},{"values":["<a href=\"/entry/H02144\">H02144</a>  Gordon Holmes syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02252\">H02252</a>  PEHO syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02338\">H02338</a>  PEHO-like syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02261\">H02261</a>  PEBAT"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02262\">H02262</a>  PEBEL"]},{"values":["<a href=\"/entry/H02273\">H02273</a>  Nonprogressive cerebellar ataxia with mental retardation"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02293\">H02293</a>  Spastic paraplegia-psychomotor retardation-seizures syndrome"]},{"values":["<a href=\"/entry/H02473\">H02473</a>  Leukoencephalopathy, brain calcifications, and cysts"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02476\">H02476</a>  Childhood-onset neurodegeneration with brain atrophy"],"expanded":false,"children":[]}],"values":["Neurodegenerative diseases"]},{"values":["Epilepsy"],"children":[{"values":["<a href=\"/entry/H00577\">H00577</a>  Symptomatic generalized epilepsies"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00606\">H00606</a>  Early infantile epileptic encephalopathy"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01460\">H01460</a>  West syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01813\">H01813</a>  Lennox-Gastaut syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01818\">H01818</a>  Dravet syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02353\">H02353</a>  Hyperekplexia and epilepsy"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01819\">H01819</a>  Early myoclonic encephalopathy"]},{"values":["<a href=\"/entry/H01823\">H01823</a>  Myoclonic-astatic epilepsy"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02361\">H02361</a>  Myoclonic-atonic epilepsy"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01815\">H01815</a>  Malignant migrating partial seizures in infancy"]},{"values":["<a href=\"/entry/H00783\">H00783</a>  Febrile seizures"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00806\">H00806</a>  Benign familial neonatal seizure"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02362\">H02362</a>  Benign familial infantile seizure"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00807\">H00807</a>  Nocturnal frontal lobe epilepsy"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00808\">H00808</a>  Idiopathic generalized epilepsies"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02215\">H02215</a>  Childhood absence epilepsy"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02216\">H02216</a>  Juvenile absence epilepsy"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02217\">H02217</a>  Juvenile myoclonic epilepsy"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02212\">H02212</a>  Familial infantile myoclonic epilepsy"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02213\">H02213</a>  Familial adult myoclonic epilepsy"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02214\">H02214</a>  Familial focal epilepsy with variable foci"]},{"values":["<a href=\"/entry/H00809\">H00809</a>  Familial epilepsy temporal lobe (ETL)"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00810\">H00810</a>  Progressive myoclonic epilepsy"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01994\">H01994</a>  Lafora disease"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01995\">H01995</a>  Unverricht-Lundborg disease"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00996\">H00996</a>  Amish infantile epilepsy syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01124\">H01124</a>  Pyridoxamine-5'-phosphate oxidase (PNPO) deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01247\">H01247</a>  Pyridoxine-dependent epilepsy"]},{"values":["<a href=\"/entry/H01258\">H01258</a>  Generalized epilepsy and paroxysmal dyskinesia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01514\">H01514</a>  Landau-Kleffner syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01775\">H01775</a>  PCDH19-related epilepsy syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01808\">H01808</a>  Hemiconvulsion-hemiplegia-epilepsy syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01822\">H01822</a>  Epilepsy with myoclonic absence"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01826\">H01826</a>  Mesial temporal lobe epilepsy with hippocampal sclerosis"]},{"values":["<a href=\"/entry/H01827\">H01827</a>  Rolandic epilepsy, mental retardation, and speech dyspraxia"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01829\">H01829</a>  Acute encephalitis with refractory repetitive partial seizures"]},{"values":["<a href=\"/entry/H02058\">H02058</a>  Kohlschutter-Tonz syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02150\">H02150</a>  Infantile or early childhood epileptic encephalopathy"]},{"values":["<a href=\"/entry/H02250\">H02250</a>  Early-onset vitamin B6-dependent epilepsy"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02360\">H02360</a>  Epileptic encephalopathy, childhood-onset"]},{"values":["<a href=\"/entry/H02472\">H02472</a>  Early-onset progressive encephalopathy"],"expanded":false,"children":[]}],"expanded":false},{"expanded":false,"children":[{"values":["<a href=\"/entry/H00527\">H00527</a>  Retinitis pigmentosa"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00589\">H00589</a>  Familial exudative vitreoretinopathy"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00612\">H00612</a>  Primary open angle glaucoma"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00633\">H00633</a>  Duane retraction syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00690\">H00690</a>  Aland Island eye disease"]},{"values":["<a href=\"/entry/H00726\">H00726</a>  Meesmann corneal dystrophy"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00732\">H00732</a>  Sorsby fundus dystrophy"]},{"values":["<a href=\"/entry/H00776\">H00776</a>  Congenital motor nystagmus (CMN)"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00779\">H00779</a>  Usher syndrome (US)"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00787\">H00787</a>  Congenital stationary night blindness"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00789\">H00789</a>  Keratoconus"]},{"values":["<a href=\"/entry/H00805\">H00805</a>  Vitreoretinal degeneration"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02073\">H02073</a>  Wagner syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02075\">H02075</a>  Enhanced S-cone syndrome"]},{"values":["<a href=\"/entry/H02341\">H02341</a>  Goldmann-Favre syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02077\">H02077</a>  Snowflake vitreoretinal degeneration"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02078\">H02078</a>  Autosomal dominant vitreoretinochoroidopathy"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00821\">H00821</a>  Age-related macular degeneration"]},{"values":["<a href=\"/entry/H01770\">H01770</a>  Macular dystrophy"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00481\">H00481</a>  Cone-rod dystrophy and cone dystrophy"]},{"values":["<a href=\"/entry/H00814\">H00814</a>  Vitelliform macular dystrophy"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00819\">H00819</a>  Stargardt disease"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01010\">H01010</a>  Occult macular dystrophy"]},{"values":["<a href=\"/entry/H01768\">H01768</a>  Central areolar choroidal dystrophy"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01890\">H01890</a>  Pattern dystrophies of the retinal pigment epithelium"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01009\">H01009</a>  Newfoundland rod-cone dystrophy"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00825\">H00825</a>  Familial flecked retina syndrome"]},{"values":["<a href=\"/entry/H02440\">H02440</a>  Fleck retina, familial benign"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00837\">H00837</a>  Leber congenital amaurosis"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00838\">H00838</a>  Congenital fibrosis of the extraocular muscles"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00951\">H00951</a>  Reis-Bucklers corneal dystrophy"]},{"values":["<a href=\"/entry/H00952\">H00952</a>  Thiel-Behnke dystrophies"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00953\">H00953</a>  Gelatinous drop-like corneal dystrophy"]},{"values":["<a href=\"/entry/H00954\">H00954</a>  Macular corneal dystrophy"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00955\">H00955</a>  Granular corneal dystrophies"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00956\">H00956</a>  Lattice corneal dystrophies"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00957\">H00957</a>  Fleck corneal dystrophy"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00958\">H00958</a>  Congenital stromal corneal dystrophy"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00959\">H00959</a>  Schnyder corneal dystrophy"]},{"values":["<a href=\"/entry/H00960\">H00960</a>  Fuchs corneal dystrophy"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00961\">H00961</a>  Posterior polymorphous corneal dystrophy"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00963\">H00963</a>  Congenital hereditary endothelial dystrophy"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01149\">H01149</a>  Ring dermoid of cornea"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01221\">H01221</a>  Epithelial basement membrane corneal dystrophy"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00971\">H00971</a>  Achromatopsia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00973\">H00973</a>  Bradyopsia"]},{"values":["<a href=\"/entry/H00974\">H00974</a>  Blue cone monochromacy"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00976\">H00976</a>  Colorblindness"]},{"values":["<a href=\"/entry/H01015\">H01015</a>  Jalili syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01020\">H01020</a>  Optic atrophy"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01088\">H01088</a>  Pigmented paravenous chorioretinal atrophy"]},{"values":["<a href=\"/entry/H01180\">H01180</a>  Sveinsson chorioretinal atrophy (SCRA)"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01116\">H01116</a>  Choroideremia"]},{"values":["<a href=\"/entry/H01118\">H01118</a>  Progressive external ophthalmoplegia"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01130\">H01130</a>  Late-onset retinal degeneration"]},{"values":["<a href=\"/entry/H01202\">H01202</a>  Cataract"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01256\">H01256</a>  Foveal hypoplasia"]},{"values":["<a href=\"/entry/H01273\">H01273</a>  Autosomal dominant keratitis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01378\">H01378</a>  Bosch-Boonstra optic atrophy syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01480\">H01480</a>  Idiopathic macular hole"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01641\">H01641</a>  Dry eye desease"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01644\">H01644</a>  Blepharitis"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01651\">H01651</a>  Macular edema"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01717\">H01717</a>  Optic neuritis"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01719\">H01719</a>  Optic neuropathy"]},{"values":["<a href=\"/entry/H01798\">H01798</a>  Autosomal dominant neovascular inflammatory vitreoretinopathy"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02041\">H02041</a>  Myopia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02104\">H02104</a>  Megalocornea"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02107\">H02107</a>  Bietti crystalline corneoretinal dystrophy"]},{"values":["<a href=\"/entry/H02108\">H02108</a>  Basal laminar drusen"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02110\">H02110</a>  Doyne honeycomb retinal dystrophy"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02112\">H02112</a>  Persistent hyperplastic primary vitreous"]},{"values":["<a href=\"/entry/H02113\">H02113</a>  Infantile cerebellar-retinal degeneration"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02114\">H02114</a>  Spastic paraplegia, optic atrophy, and neuropathy"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02135\">H02135</a>  Cone-rod dystrophy and hearing loss"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02204\">H02204</a>  Hereditary hyperferritinaemia-cataract syndrome"]},{"values":["<a href=\"/entry/H02469\">H02469</a>  Cone-rod synaptic disorder"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01457\">H01457</a>  Diabetic retinopathy"],"children":[],"expanded":false}],"values":["Eye disease"]},{"values":["Ear disease"],"expanded":false,"children":[{"expanded":false,"children":[],"values":["<a href=\"/entry/H01920\">H01920</a>  Partington syndrome"]},{"values":["<a href=\"/entry/H00604\">H00604</a>  Deafness, autosomal dominant"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00605\">H00605</a>  Deafness, autosomal recessive"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01209\">H01209</a>  Deafness, X-linked"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02336\">H02336</a>  Deafness, Y-linked"]},{"values":["<a href=\"/entry/H01704\">H01704</a>  Sudden sensorineural hearing loss"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01705\">H01705</a>  Bilateral sudden sensorineural hearing loss"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01706\">H01706</a>  Delayed endolymphatic hydrops"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01495\">H01495</a>  Meniere disease"]},{"values":["<a href=\"/entry/H02339\">H02339</a>  Auditory neuropathy"],"children":[],"expanded":false}]},{"values":["Other nervous and sensory system diseases"],"expanded":false,"children":[{"values":["<a href=\"/entry/H02359\">H02359</a>  Dejerine-Sottas disease"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02344\">H02344</a>  Cowchock syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00265\">H00265</a>  Hereditary sensory and autonomic neuropathy"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00266\">H00266</a>  Hereditary spastic paraplegia"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00524\">H00524</a>  Scapuloperoneal spinal muscular atrophy"]},{"values":["<a href=\"/entry/H00688\">H00688</a>  Familial advanced sleep phase syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00689\">H00689</a>  Delayed sleep phase syndrome"]},{"values":["<a href=\"/entry/H00916\">H00916</a>  Congenital central hypoventilation syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00770\">H00770</a>  Congenital myasthenic syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00772\">H00772</a>  Paroxysmal extreme pain disorder"]},{"values":["<a href=\"/entry/H00769\">H00769</a>  Hyperekplexia"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00774\">H00774</a>  Congenital insensitivity to pain"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00775\">H00775</a>  Hemiplegic migraine"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00803\">H00803</a>  Seizures-sensorineural deafness-ataxia-mental retardation-electrolyte imbalance (SESAME)"]},{"values":["<a href=\"/entry/H00831\">H00831</a>  Primary dystonia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00836\">H00836</a>  GLUT1 deficiency syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00840\">H00840</a>  Band-like calcification with simplified gyration and polymicrogyria"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00860\">H00860</a>  Benign hereditary chorea"]},{"values":["<a href=\"/entry/H00989\">H00989</a>  Mohr-Tranebjaerg syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00998\">H00998</a>  Alternating hemiplegia of childhood"]},{"values":["<a href=\"/entry/H01000\">H01000</a>  Retinal vasculopathy with cerebral leukodystrophy"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01005\">H01005</a>  Dopamine beta-hydroxylase deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01007\">H01007</a>  Choroid plexus papilloma"]},{"values":["<a href=\"/entry/H01097\">H01097</a>  Spastic quadriplegic cerebral palsy"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01131\">H01131</a>  Hereditary neuralgic amyotrophy"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01155\">H01155</a>  Roussy-Levy syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01161\">H01161</a>  Aromatic L-amino acid decarboxylase deficiency"]},{"values":["<a href=\"/entry/H01201\">H01201</a>  Jensen syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01287\">H01287</a>  Congenital mirror movements"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01293\">H01293</a>  Narcolepsy"]},{"values":["<a href=\"/entry/H01296\">H01296</a>  Hereditary neuropathy with liability to pressure palsies"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01301\">H01301</a>  Hemorrhagic destruction of the brain, subependymal calcification, and cataracts"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00798\">H00798</a>  Familial carpal tunnel syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01812\">H01812</a>  Rasmussen encephalitis"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01436\">H01436</a>  Guillain-Barre syndrome"]},{"values":["<a href=\"/entry/H01689\">H01689</a>  Fisher syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01490\">H01490</a>  Multiple sclerosis"]},{"values":["<a href=\"/entry/H01491\">H01491</a>  Neuromyelitis optica"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01504\">H01504</a>  Vogt-Koyanagi-Harada syndrome"]},{"values":["<a href=\"/entry/H01506\">H01506</a>  Hepatic encephalopathy"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01527\">H01527</a>  Chronic inflammatory demyelinating polyradiculoneuropathy"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01528\">H01528</a>  Neuroleptic malignant syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01565\">H01565</a>  Wernicke encephalopathy"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01577\">H01577</a>  Essential tremor"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01588\">H01588</a>  Cluster headache"]},{"values":["<a href=\"/entry/H01594\">H01594</a>  Myasthenia gravis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01596\">H01596</a>  Lambert-Eaton myasthenic syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01597\">H01597</a>  Restless legs syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01608\">H01608</a>  Cervical dystonia"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01609\">H01609</a>  Insomnia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01638\">H01638</a>  Neuropathic pain"]},{"values":["<a href=\"/entry/H01668\">H01668</a>  Neoplastic meningitis"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01429\">H01429</a>  Aseptic meningitis"]},{"values":["<a href=\"/entry/H01724\">H01724</a>  HTLV1-associated myelopathy"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01676\">H01676</a>  Normal pressure hydrocephalus"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01692\">H01692</a>  Subependymal giant cell astrocytoma"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01836\">H01836</a>  Congenital pain insensitivity with anhidrosis"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01837\">H01837</a>  Congenital suprabulbar paresis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01841\">H01841</a>  Acute encephalopathy with biphasic seizures and late reduced diffusion"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01842\">H01842</a>  Bickerstaff brainstem encephalitis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01846\">H01846</a>  Superficial siderosis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01924\">H01924</a>  Sydenham chorea"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01987\">H01987</a>  Familial dysautonomia"]},{"values":["<a href=\"/entry/H02101\">H02101</a>  Autosomal dominant sensory ataxia"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02137\">H02137</a>  Laurence-Moon syndrome"]},{"values":["<a href=\"/entry/H02140\">H02140</a>  Boucher-Neuhauser syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02174\">H02174</a>  Sudden infant death with dysgenesis of the testes syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02251\">H02251</a>  Coats plus syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02345\">H02345</a>  Autosomal recessive peripheral neuropathy (PNRIID)"]},{"values":["<a href=\"/entry/H02357\">H02357</a>  Congenital hypomyelinating neuropathy"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02366\">H02366</a>  Cerebellar ataxia, neuropathy, and vestibular areflexia syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02367\">H02367</a>  Chorea, childhood-onset, with psychomotor retardation"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02388\">H02388</a>  Infantile-onset limb and orofacial dyskinesia"]},{"values":["<a href=\"/entry/H02389\">H02389</a>  Familial dyskinesia with facial myokymia"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02390\">H02390</a>  Autosomal recessive neuromyotonia and axonal neuropathy"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02430\">H02430</a>  Ataxia, combined cerebellar and peripheral, with hearing loss and diabetes mellitus"]},{"values":["<a href=\"/entry/H02450\">H02450</a>  Horizontal gaze palsy with progressive scoliosis"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02489\">H02489</a>  Mild encephalopathy with reversible myelin vacuolization"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01459\">H01459</a>  Diabetic neuropathy"]},{"values":["<a href=\"/entry/H02510\">H02510</a>  Jaberi-Elahi syndrome"],"expanded":false,"children":[]}]}],"expanded":false},{"expanded":false,"children":[],"values":[]},{"values":["<b>Cardiovascular diseases</b>"],"expanded":false,"children":[{"values":["Cardiac diseases"],"children":[{"children":[],"expanded":false,"values":["<a href=\"/entry/H00292\">H00292</a>  Hypertrophic cardiomyopathy [PATH:<a href=\"/pathway/hsa05410\">hsa05410</a>]"]},{"values":["<a href=\"/entry/H00293\">H00293</a>  Arrhythmogenic right ventricular cardiomyopathy [PATH:<a href=\"/pathway/hsa05412\">hsa05412</a>]"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00294\">H00294</a>  Dilated cardiomyopathy [PATH:<a href=\"/pathway/hsa05414\">hsa05414</a>]"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01219\">H01219</a>  Restrictive cardiomyopathy"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02498\">H02498</a>  Diabetic cardiomyopathy [PATH:<a href=\"/pathway/hsa05415\">hsa05415</a>]"]},{"values":["<a href=\"/entry/H00295\">H00295</a>  Viral myocarditis [PATH:<a href=\"/pathway/hsa05416\">hsa05416</a>]"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01216\">H01216</a>  Left ventricular noncompaction"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00654\">H00654</a>  Barth syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00720\">H00720</a>  Long QT syndrome"]},{"values":["<a href=\"/entry/H00725\">H00725</a>  Short QT syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02091\">H02091</a>  Jervell and Lange-Nielsen syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00728\">H00728</a>  Brugada syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00729\">H00729</a>  Sick sinus syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00730\">H00730</a>  Familial idiopathic ventricular fibrillation"]},{"values":["<a href=\"/entry/H00731\">H00731</a>  Atrial fibrillation"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00918\">H00918</a>  Double-outlet right ventricle"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01019\">H01019</a>  Catecholaminergic polymorphic ventricular tachycardia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01154\">H01154</a>  Wolff-Parkinson-White (WPW) syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01263\">H01263</a>  Progressive cardiac conduction defect (PCCD)"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01632\">H01632</a>  Angina pectoris"]},{"values":["<a href=\"/entry/H01729\">H01729</a>  Premature ventricular complexes"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01730\">H01730</a>  Myocardial infarction"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01736\">H01736</a>  Persistent truncus arteriosus"]},{"values":["<a href=\"/entry/H01868\">H01868</a>  Mitral valve prolapse"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01926\">H01926</a>  Ventricular septal defect"]},{"values":["<a href=\"/entry/H02122\">H02122</a>  Chronic atrial and intestinal dysrhythmia"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02125\">H02125</a>  Cardiac conduction disease with dilated cardiomyopathy"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02269\">H02269</a>  Familial ventricular tachycardia"]}],"expanded":false},{"children":[{"expanded":false,"children":[],"values":["<a href=\"/entry/H01482\">H01482</a>  Infantile hemangioma"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01875\">H01875</a>  Infantile hepatic hemangioma"]},{"values":["<a href=\"/entry/H00771\">H00771</a>  Inherited erythromelalgia"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00801\">H00801</a>  Familial thoracic aortic aneurysm and dissection"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00877\">H00877</a>  Brain small vessel disease"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00896\">H00896</a>  Lymphangioleiomyomatosis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01471\">H01471</a>  Lymphangioma"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01735\">H01735</a>  Lymphangiomatosis"]},{"values":["<a href=\"/entry/H00919\">H00919</a>  Arterial tortuosity syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01002\">H01002</a>  Generalized arterial calcification of infancy"]},{"values":["<a href=\"/entry/H01006\">H01006</a>  Hereditary angioedema"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01120\">H01120</a>  Proliferative vasculopathy and hydranencephaly-hydrocephaly syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01382\">H01382</a>  Polyarteritis nodosa"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00824\">H00824</a>  Calcification of joints and arteries"]},{"values":["<a href=\"/entry/H01396\">H01396</a>  Moyamoya disease"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01433\">H01433</a>  Budd-Chiari syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01465\">H01465</a>  Large-vessel vasculitis"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01698\">H01698</a>  Giant cell arteritis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01468\">H01468</a>  Eosinophilic granulomatosis with polyangiitis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01625\">H01625</a>  Buerger disease"]},{"values":["<a href=\"/entry/H01626\">H01626</a>  Arteriosclerosis obliterans"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02505\">H02505</a>  Atherosclerosis [PATH:<a href=\"/pathway/hsa05417\">hsa05417</a>]"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01629\">H01629</a>  Chronic arterial occlusive disease"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01620\">H01620</a>  Raynaud syndrome"]},{"values":["<a href=\"/entry/H01658\">H01658</a>  Microscopic polyangiitis"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01687\">H01687</a>  Extrahepatic portal vein obstruction"]},{"values":["<a href=\"/entry/H01723\">H01723</a>  Deep vein thrombosis"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01718\">H01718</a>  Kawasaki disease"]},{"values":["<a href=\"/entry/H01742\">H01742</a>  Coronary artery disease"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01809\">H01809</a>  Sturge-Weber syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01866\">H01866</a>  Pulmonary veno-occlusive disease and pulmonary capillary hemangiomatosis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02088\">H02088</a>  Primary intraosseous vascular malformation"]}],"expanded":false,"values":["Vascular diseases"]},{"values":["Hematologic diseases"],"expanded":false,"children":[{"values":["<a href=\"/entry/H00228\">H00228</a>  Thalassemia"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00229\">H00229</a>  Sickle cell anemia"]},{"values":["<a href=\"/entry/H00230\">H00230</a>  Hereditary spherocytosis"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00231\">H00231</a>  Hereditary elliptocytosis"]},{"values":["<a href=\"/entry/H00232\">H00232</a>  Hereditary stomatocytosis"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00219\">H00219</a>  Hemophilia"]},{"values":["<a href=\"/entry/H01254\">H01254</a>  Congenital prothrombin deficiency"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00220\">H00220</a>  Factor V deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00221\">H00221</a>  Combined deficiency of factors V and VIII"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00222\">H00222</a>  Afibrinogenemia"]},{"values":["<a href=\"/entry/H00223\">H00223</a>  Inherited thrombophilia"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01740\">H01740</a>  Macrothrombocytopenia"]},{"values":["<a href=\"/entry/H00224\">H00224</a>  Bernard-Soulier syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00233\">H00233</a>  MYH9-related disease"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02051\">H02051</a>  May-Hegglin anomaly"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02052\">H02052</a>  Sebastian syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02053\">H02053</a>  Fechtner syndrome"]},{"values":["<a href=\"/entry/H00226\">H00226</a>  Glanzmann thrombasthenia"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00225\">H00225</a>  Thrombotic thrombocytopenic purpura"]},{"values":["<a href=\"/entry/H00227\">H00227</a>  Congenital amegakaryocytic thrombocytopenia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00234\">H00234</a>  Pelger-Huet anomaly"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00235\">H00235</a>  Methemoglobinemia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00236\">H00236</a>  Congenital polycythemia"]},{"values":["<a href=\"/entry/H00237\">H00237</a>  Diamond-Blackfan anemia"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00238\">H00238</a>  Fanconi anemia"]},{"values":["<a href=\"/entry/H00578\">H00578</a>  Epstein syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00664\">H00664</a>  Anemia due to disorders of glycolytic enzymes"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00668\">H00668</a>  Anemia due to disorders of glutathione metabolism"]},{"values":["<a href=\"/entry/H00674\">H00674</a>  Anemia due to disorders of nucleotide metabolism"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00917\">H00917</a>  Congenital dyserythropoietic anemias (CDAs)"]},{"values":["<a href=\"/entry/H02256\">H02256</a>  Factor VII deficiency"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02257\">H02257</a>  Factor X deficiency"]},{"values":["<a href=\"/entry/H00938\">H00938</a>  Factor XI deficiency"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00941\">H00941</a>  Factor XII deficiency"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00945\">H00945</a>  Factor XIII deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02259\">H02259</a>  Stormorken syndrome"]},{"values":["<a href=\"/entry/H00978\">H00978</a>  Thrombocytopenia (THC)"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00982\">H00982</a>  Sideroblastic anemia"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00983\">H00983</a>  Alpha-2-plasmin inhibitor (a2-PI) deficiency"]},{"values":["<a href=\"/entry/H00920\">H00920</a>  Exocrine pancreatic insufficiency, dyserythropoietic anemia, and calvarial hyperostosis"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00995\">H00995</a>  Combined deficiency of vitamin K-dependent clotting factors"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01013\">H01013</a>  Adult i phenotype"]},{"values":["<a href=\"/entry/H01031\">H01031</a>  Orthostatic intolerance"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01053\">H01053</a>  Paroxysmal nocturnal hemoglobinuria"]},{"values":["<a href=\"/entry/H01078\">H01078</a>  Fletcher factor deficiency"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01106\">H01106</a>  Plasminogen activator inhibitor type 1 deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01125\">H01125</a>  Hereditary pyropoikilocytosis"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01132\">H01132</a>  Aplastic anemia"]},{"values":["<a href=\"/entry/H01145\">H01145</a>  Atransferrinemia"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01162\">H01162</a>  Scott syndrome"]},{"values":["<a href=\"/entry/H01183\">H01183</a>  Thiamine-responsive megaloblastic anemia"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01196\">H01196</a>  Hypochromic microcytic anemia"]},{"values":["<a href=\"/entry/H01206\">H01206</a>  Plasminogen deficiency"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01214\">H01214</a>  Rh-null hemolytic anemia (RHN)"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01235\">H01235</a>  Bleeding disorder platelet-type"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01252\">H01252</a>  Hereditary folate malabsorption"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01277\">H01277</a>  Vitamin B12 deficiency anaemia"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01278\">H01278</a>  Iron-refractory iron deficiency anemia"]},{"values":["<a href=\"/entry/H01303\">H01303</a>  Hypercatabolic hypoproteinemia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01381\">H01381</a>  Antithrombin III deficiency"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01434\">H01434</a>  Atypical hemolytic uremic syndrome"]},{"values":["<a href=\"/entry/H01481\">H01481</a>  Myelodysplastic syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01484\">H01484</a>  5q- syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01580\">H01580</a>  Vitamin C deficiency"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01584\">H01584</a>  IgA vasculitis"]},{"values":["<a href=\"/entry/H01585\">H01585</a>  Autoimmune hemolytic anemia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01586\">H01586</a>  Acquired pure red cell aplasia"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01587\">H01587</a>  Disseminated intravascular coagulation"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01697\">H01697</a>  Antiphospholipid syndrome"]},{"values":["<a href=\"/entry/H01720\">H01720</a>  Southeast Asian ovalocytosis"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01759\">H01759</a>  Autoimmune hemorrhaphilia XIII/13"]},{"values":["<a href=\"/entry/H01938\">H01938</a>  Hypermanganesemia with dystonia"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01978\">H01978</a>  Dehydrated hereditary stomatocytosis"]},{"values":["<a href=\"/entry/H01979\">H01979</a>  Overhydrated hereditary stomatocytosis"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02001\">H02001</a>  Familial pseudohyperkalemia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02002\">H02002</a>  Cryohydrocytosis"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02092\">H02092</a>  von Willebrand disease"]},{"values":["<a href=\"/entry/H02093\">H02093</a>  Platelet-type von Willebrand disease"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02097\">H02097</a>  Gray platelet syndrome"]}]},{"values":["Hypertensive diseases"],"expanded":false,"children":[{"values":["<a href=\"/entry/H00602\">H00602</a>  Glucocorticoid-remediable aldosteronism (GRA)"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00242\">H00242</a>  Liddle syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00603\">H00603</a>  Hypertension exacerbated in pregnancy"]},{"values":["<a href=\"/entry/H01619\">H01619</a>  Primary pulmonary hypertension"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01621\">H01621</a>  Pulmonary arterial hypertension"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01622\">H01622</a>  Chronic thromboembolic pulmonary hypertension"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01631\">H01631</a>  Acute heart failure"]},{"values":["<a href=\"/entry/H01633\">H01633</a>  High blood pressure"],"children":[],"expanded":false}]}]},{"values":[],"children":[],"expanded":false},{"values":["<b>Respiratory diseases</b>"],"children":[{"expanded":false,"children":[{"values":["<a href=\"/entry/H00904\">H00904</a>  Cutis laxa with severe pulmonary, gastrointestinal, and urinary abnormalities"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00830\">H00830</a>  Alveolar capillary dysplasia with misalignment of pulmonary veins"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01103\">H01103</a>  Alpha-1-antitrypsin deficiency"]},{"values":["<a href=\"/entry/H01110\">H01110</a>  Pneumothorax"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01122\">H01122</a>  Congenital pulmonary alveolar proteinosis"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01298\">H01298</a>  Pulmonary alveolar microlithiasis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01299\">H01299</a>  Idiopathic pulmonary fibrosis"]},{"values":["<a href=\"/entry/H01714\">H01714</a>  Chronic obstructive pulmonary disease (COPD)"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01716\">H01716</a>  Idiopathic interstitial pneumonias"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01727\">H01727</a>  Primary alveolar hypoventilation syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02124\">H02124</a>  Interstitial lung and liver disease"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02466\">H02466</a>  Rajab interstitial lung disease with brain calcification"]}],"values":["Lung diseases"]},{"children":[{"expanded":false,"children":[],"values":["<a href=\"/entry/H00892\">H00892</a>  Bronchiectasis with or without elevated sweat chloride"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01713\">H01713</a>  Diffuse panbronchiolitis"]},{"values":["<a href=\"/entry/H01715\">H01715</a>  Obesity hypoventilation syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01873\">H01873</a>  Obliterative bronchiolitis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00564\">H00564</a>  Primary ciliary dyskinesia"]}],"expanded":false,"values":["Tracheobronchial diseases"]}],"expanded":false},{"expanded":false,"children":[],"values":[]},{"values":["<b>Endocrine and metabolic diseases</b>"],"children":[{"values":["Diabetes"],"children":[{"children":[],"expanded":false,"values":["<a href=\"/entry/H00409\">H00409</a>  Type 2 diabetes mellitus [PATH:<a href=\"/pathway/hsa04930\">hsa04930</a>]"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00408\">H00408</a>  Type 1 diabetes mellitus [PATH:<a href=\"/pathway/hsa04940\">hsa04940</a>]"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00410\">H00410</a>  Maturity onset diabetes of the young (MODY) [PATH:<a href=\"/pathway/hsa04950\">hsa04950</a>]"]},{"values":["<a href=\"/entry/H00512\">H00512</a>  Permanent neonatal diabetes mellitus"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00513\">H00513</a>  Transient neonatal diabetes mellitus"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00766\">H00766</a>  Wolcott-Rallison syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00854\">H00854</a>  Wolfram syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00942\">H00942</a>  Rabson-Mendenhall syndrome"]},{"values":["<a href=\"/entry/H01224\">H01224</a>  Ketosis-prone diabetes mellitus"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01228\">H01228</a>  Insulin-resistant diabetes mellitus with acanthosis nigricans"]},{"values":["<a href=\"/entry/H01377\">H01377</a>  Mitchell-Riley syndrome"],"children":[],"expanded":false}],"expanded":false},{"values":["Hypothalamus and pituitary gland diseases"],"expanded":false,"children":[{"values":["<a href=\"/entry/H00253\">H00253</a>  Neurohypophyseal diabetes insipidus (NPDI)"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00254\">H00254</a>  Growth hormone deficiency"]},{"values":["<a href=\"/entry/H02035\">H02035</a>  Isolated growth hormone deficiency"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02036\">H02036</a>  Combined pituitary hormone deficiency"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02037\">H02037</a>  Laron syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02038\">H02038</a>  X-linked panhypopituitarism"]},{"values":["<a href=\"/entry/H02039\">H02039</a>  Kowarski syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02040\">H02040</a>  Insulin-like growth factor I deficiency"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01102\">H01102</a>  Pituitary adenomas"]},{"values":["<a href=\"/entry/H01618\">H01618</a>  Pituitary gigantism"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01483\">H01483</a>  Acromegaly"]},{"values":["<a href=\"/entry/H00255\">H00255</a>  Hypogonadotropic hypogonadism"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00937\">H00937</a>  Precocious puberty"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02018\">H02018</a>  Central precocious puberty"]},{"values":["<a href=\"/entry/H01011\">H01011</a>  Adrenocorticotropic hormone deficiency"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01253\">H01253</a>  Isolated follicle-stimulating hormone deficiency"]},{"values":["<a href=\"/entry/H01274\">H01274</a>  Growth delay due to insulin-like growth factor I resistance"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01294\">H01294</a>  Nephrogenic syndrome of inappropriate antidiuresis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01388\">H01388</a>  Hyperprolactinemia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01682\">H01682</a>  Syndrome of inappropriate secretion of antidiuretic hormone"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01683\">H01683</a>  Disorders of antidiuretic hormone (ADH) secretion"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01699\">H01699</a>  Isolated TSH deficiency"]},{"values":["<a href=\"/entry/H01701\">H01701</a>  Pituitary TSH hypersecretion"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01700\">H01700</a>  Hypopituitarism"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01860\">H01860</a>  Abnormal pituitary gonadotropin secretion"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01864\">H01864</a>  Excessive secretion of growth hormone"]},{"values":["<a href=\"/entry/H01907\">H01907</a>  Acid-labile subunit deficiency"],"children":[],"expanded":false}]},{"values":["Thyroid gland diseases"],"expanded":false,"children":[{"expanded":false,"children":[],"values":["<a href=\"/entry/H00250\">H00250</a>  Congenital nongoitrous hypothyroidism (CHNG)"]},{"values":["<a href=\"/entry/H00251\">H00251</a>  Thyroid dyshormonogenesis"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00249\">H00249</a>  Thyroid hormone resistance syndrome"]},{"values":["<a href=\"/entry/H00650\">H00650</a>  Allan-Herndon-Dudley syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00913\">H00913</a>  Brain-lung-thyroid syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01040\">H01040</a>  Bamforth-Lazarus syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01186\">H01186</a>  Abnormal thyroid hormone metabolism"]},{"values":["<a href=\"/entry/H01269\">H01269</a>  Congenital hyperthyroidism"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01645\">H01645</a>  Hyperthyroidism"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01647\">H01647</a>  Subacute thyroiditis"]},{"values":["<a href=\"/entry/H02034\">H02034</a>  Central hypothyroidism and testicular enlargement"],"expanded":false,"children":[]}]},{"children":[{"expanded":false,"children":[],"values":["<a href=\"/entry/H00244\">H00244</a>  Pseudohypoparathyroidism"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00246\">H00246</a>  Primary hyperparathyroidism"]},{"values":["<a href=\"/entry/H01669\">H01669</a>  Secondary hyperparathyroidism"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02030\">H02030</a>  Neonatal hyperparathyroidism"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01862\">H01862</a>  Hypoparathyroidism"]}],"expanded":false,"values":["Parathyroid diseases"]},{"values":["Adrenal gland diseases"],"expanded":false,"children":[{"children":[],"expanded":false,"values":["<a href=\"/entry/H00216\">H00216</a>  Congenital adrenal hyperplasia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00602\">H00602</a>  Glucocorticoid-remediable aldosteronism (GRA)"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01603\">H01603</a>  Primary aldosteronism"]},{"values":["<a href=\"/entry/H00260\">H00260</a>  Pigmented micronodular adrenocortical disease [PATH:<a href=\"/pathway/hsa04934\">hsa04934</a>]"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01598\">H01598</a>  Addison disease"]},{"values":["<a href=\"/entry/H01772\">H01772</a>  Adrenal hypoplasia, congenital"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01111\">H01111</a>  Cortisone reductase deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01163\">H01163</a>  Corticosteroid-binding globulin (CBG) deficiency"]},{"values":["<a href=\"/entry/H00256\">H00256</a>  Familial glucocorticoid deficiency"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00257\">H00257</a>  Achalasia Addisonianism Alacrima syndrome"]},{"values":["<a href=\"/entry/H00258\">H00258</a>  Aldosterone synthase deficiency"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00259\">H00259</a>  Apparent mineralocorticoid excess syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01431\">H01431</a>  Cushing syndrome [PATH:<a href=\"/pathway/hsa04934\">hsa04934</a>]"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01702\">H01702</a>  Glucocorticoid resistance syndrome"]},{"values":["<a href=\"/entry/H02049\">H02049</a>  Bilateral macronodular adrenal hyperplasia [PATH:<a href=\"/pathway/hsa04934\">hsa04934</a>]"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02314\">H02314</a>  Adrenal insufficiency, congenital, with 46XY sex reversal, partial or complete"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02316\">H02316</a>  Adrenal insufficiency, NR5A1 related"]},{"values":["<a href=\"/entry/H02315\">H02315</a>  Disordered steroidogenesis due to cytochrome P450 oxidoreductase"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02319\">H02319</a>  IMAGE syndrome"]}]},{"values":["Gonadal diseases"],"expanded":false,"children":[{"children":[],"expanded":false,"values":["<a href=\"/entry/H00794\">H00794</a>  Aromatase excess syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02020\">H02020</a>  Aromatase deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02019\">H02019</a>  Familial male-limited precocious puberty"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02027\">H02027</a>  Male hypogonadism"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02061\">H02061</a>  Estrogen resistance syndrome"]}]},{"expanded":false,"children":[{"expanded":false,"children":[],"values":["<a href=\"/entry/H01635\">H01635</a>  Hyperlipidemia"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00239\">H00239</a>  Bartter syndrome"]},{"values":["<a href=\"/entry/H00240\">H00240</a>  Gitelman syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01522\">H01522</a>  Zollinger-Ellison syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00719\">H00719</a>  Leprechaunism"]},{"values":["<a href=\"/entry/H02323\">H02323</a>  Ruijs-Aalfs syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01733\">H01733</a>  Werner syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01565\">H01565</a>  Wernicke encephalopathy"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01566\">H01566</a>  Beriberi"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01582\">H01582</a>  Pellagra"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02059\">H02059</a>  Leptin deficiency"]},{"values":["<a href=\"/entry/H02060\">H02060</a>  Leptin receptor deficiency"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02105\">H02105</a>  Prohormone convertase 1/3 deficiency"]},{"values":["<a href=\"/entry/H02106\">H02106</a>  Genetic obesity"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02235\">H02235</a>  Morbid obesity and spermatogenic failure"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02384\">H02384</a>  Abdominal obesity-metabolic syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02499\">H02499</a>  AL amyloidosis"]}],"values":["Other endocrine and metabolic diseases"]}],"expanded":false},{"expanded":false,"children":[],"values":[]},{"expanded":false,"children":[{"expanded":false,"children":[{"children":[],"expanded":false,"values":["<a href=\"/entry/H00432\">H00432</a>  Hereditary dentine disorders"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00497\">H00497</a>  Cherubism"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00615\">H00615</a>  Amelogenesis imperfecta"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00618\">H00618</a>  Amelogenesis imperfecta hypoplastic-hypomaturation with taurodontism"]},{"values":["<a href=\"/entry/H00625\">H00625</a>  Tooth agenesis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00680\">H00680</a>  Primary failure of tooth eruption"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00857\">H00857</a>  Oligodontia-colorectal cancer syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01250\">H01250</a>  Hereditary gingival fibromatosis"]},{"values":["<a href=\"/entry/H02050\">H02050</a>  Prepubertal periodontitis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02348\">H02348</a>  Dentin dysplasia"],"children":[],"expanded":false}],"values":["Mouth and dental diseases"]},{"values":["Gastrointestinal diseases"],"expanded":false,"children":[{"expanded":false,"children":[],"values":["<a href=\"/entry/H00666\">H00666</a>  Peutz-Jeghers syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01016\">H01016</a>  Primary bile acid malabsorption"]},{"values":["<a href=\"/entry/H01023\">H01023</a>  Juvenile polyposis syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01024\">H01024</a>  Hereditary mixed polyposis syndrome"]},{"values":["<a href=\"/entry/H01025\">H01025</a>  Familial adenomatous polyposis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01174\">H01174</a>  Congenital diarrhea"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01276\">H01276</a>  Chronic idiopathic intestinal pseudo-obstruction"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01469\">H01469</a>  Short bowel syndrome"]},{"values":["<a href=\"/entry/H01602\">H01602</a>  Gastroesophageal reflux disease"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01615\">H01615</a>  Irritable bowel syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01634\">H01634</a>  Peptic ulcer"]},{"values":["<a href=\"/entry/H01782\">H01782</a>  Eosinophilic gastrointestinal disorder"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01853\">H01853</a>  Chronic nonspecific multiple ulcers of the small intestine"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01871\">H01871</a>  Isolated hypoganglionosis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01874\">H01874</a>  Cronkhite-Canada syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01901\">H01901</a>  Barrett esophagus"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02122\">H02122</a>  Chronic atrial and intestinal dysrhythmia"]},{"values":["<a href=\"/entry/H02123\">H02123</a>  Celiac disease"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02504\">H02504</a>  Gastrointestinal ulceration, recurrent, with dysfunctional platelets"]}]},{"values":["Liver diseases"],"expanded":false,"children":[{"values":["<a href=\"/entry/H00624\">H00624</a>  Progressive familial intrahepatic cholestasis"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02192\">H02192</a>  Benign recurrent intrahepatic cholestasis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02193\">H02193</a>  Intrahepatic cholestasis of pregnancy"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02194\">H02194</a>  North American Indian childhood cirrhosis"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01133\">H01133</a>  Reynolds syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01213\">H01213</a>  Gallbladder disease"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01264\">H01264</a>  Hepatic venoocclusive disease with immunodeficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02516\">H02516</a>  Alcoholic liver disease [PATH:<a href=\"/pathway/hsa04936\">hsa04936</a>]"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01333\">H01333</a>  Non-alcoholic fatty liver disease [PATH:<a href=\"/pathway/hsa04932\">hsa04932</a>]"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01467\">H01467</a>  Primary biliary cirrhosis"]},{"values":["<a href=\"/entry/H01506\">H01506</a>  Hepatic encephalopathy"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01679\">H01679</a>  Intrahepatic lithiasis"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01684\">H01684</a>  Primary sclerosing cholangitis"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01685\">H01685</a>  Autoimmune hepatitis"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01686\">H01686</a>  Idiopathic portal hypertension"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01687\">H01687</a>  Extrahepatic portal vein obstruction"]},{"values":["<a href=\"/entry/H01712\">H01712</a>  Fulminant hepatic failure"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02225\">H02225</a>  Familial cirrhosis"]}]},{"expanded":false,"children":[{"children":[],"expanded":false,"values":["<a href=\"/entry/H00861\">H00861</a>  Pancreatic agenesis"]},{"values":["<a href=\"/entry/H00920\">H00920</a>  Exocrine pancreatic insufficiency, dyserythropoietic anemia, and calvarial hyperostosis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00932\">H00932</a>  Tropical calcific pancreatitis"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00933\">H00933</a>  Hereditary pancreatitis"]},{"values":["<a href=\"/entry/H01680\">H01680</a>  Chronic pancreatitis"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01681\">H01681</a>  Acute pancreatitis"]}],"values":["Pancreas diseases"]}],"values":["<b>Digestive system diseases</b>"]},{"values":[],"expanded":false,"children":[]},{"values":["<b>Urinary system diseases</b>"],"expanded":false,"children":[{"values":["Kidney diseases"],"children":[{"expanded":false,"children":[],"values":["<a href=\"/entry/H02310\">H02310</a>  Renal tubular acidosis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00428\">H00428</a>  Distal renal tubular acidosis (RTA type 1)"]},{"values":["<a href=\"/entry/H00429\">H00429</a>  Proximal renal tubular acidosis (RTA type 2)"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00241\">H00241</a>  Combined proximal and distal renal tubular acidosis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00243\">H00243</a>  Hyperkalemic distal renal tubular acidosis (RTA type 4)"]},{"values":["<a href=\"/entry/H00252\">H00252</a>  Congenital nephrogenic diabetes insipidus"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00541\">H00541</a>  Autosomal dominant tubulointerstitial kidney disease"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00576\">H00576</a>  Pierson syndrome"]},{"values":["<a href=\"/entry/H00582\">H00582</a>  Benign familial hematuria"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01657\">H01657</a>  Nephrotic syndrome [PATH:<a href=\"/pathway/hsa03013\">hsa03013</a> <a href=\"/pathway/hsa04151\">hsa04151</a>]"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00626\">H00626</a>  Focal segmental glomerulosclerosis"]},{"values":["<a href=\"/entry/H00888\">H00888</a>  Nephrolithiasis/osteoporosis, hypophosphatemic"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00928\">H00928</a>  Nephropathy with pretibial epidermolysis bullosa and deafness"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00948\">H00948</a>  Renal hypouricemia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01037\">H01037</a>  Vesicoureteral reflux"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01260\">H01260</a>  Glomerulopathy with fibronectin deposits"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01304\">H01304</a>  Hyperglycinuria"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01500\">H01500</a>  Lupus nephritis"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01581\">H01581</a>  IgA nephropathy"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01456\">H01456</a>  Diabetic nephropathy"]},{"values":["<a href=\"/entry/H01642\">H01642</a>  Renal anemia"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01688\">H01688</a>  Rapidly progressive glomerulonephritis"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01691\">H01691</a>  Renal angiomyolipoma"]},{"values":["<a href=\"/entry/H01726\">H01726</a>  Membranoproliferative glomerulonephritis"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01767\">H01767</a>  Henoch-Schonlein purpura nephritis"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02011\">H02011</a>  Familial juvenile hyperuricemic nephropathy"]},{"values":["<a href=\"/entry/H02145\">H02145</a>  Calcium oxalate nephrolithiasis"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02149\">H02149</a>  X-linked hypercalciuric nephrolithiasis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00694\">H00694</a>  Dent disease"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02142\">H02142</a>  X-linked recessive hypophosphatemic rickets"]},{"values":["<a href=\"/entry/H02147\">H02147</a>  X-linked recessive nephrolithiasis with renal failure"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02148\">H02148</a>  Low molecular weight proteinuria with hypercalciuria and nephrocalcinosis"],"children":[],"expanded":false}],"expanded":false},{"values":["Urinary bladder diseases"],"expanded":false,"children":[{"children":[],"expanded":false,"values":["<a href=\"/entry/H00753\">H00753</a>  Urofacial syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01551\">H01551</a>  Interstitial cystitis"]}]}]},{"expanded":false,"children":[],"values":[]},{"expanded":false,"children":[{"values":["Reproductive system diseases"],"expanded":false,"children":[{"children":[],"expanded":false,"values":["<a href=\"/entry/H00607\">H00607</a>  46,XY gonadal dysgenesis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00608\">H00608</a>  46,XY disorder of sex development due to testosterone secretion defect"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00609\">H00609</a>  Persistent Mullerian duct syndrome"]},{"values":["<a href=\"/entry/H00598\">H00598</a>  46,XX testicular disorder of sex development"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00599\">H00599</a>  Ovarian dysgenesis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00600\">H00600</a>  Mullerian agenesis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00627\">H00627</a>  Premature ovarian failure"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01039\">H01039</a>  Ovarian hyperstimulation syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01607\">H01607</a>  Galactorrhea"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01639\">H01639</a>  Endometriosis"]},{"values":["<a href=\"/entry/H01640\">H01640</a>  Uterine leiomyoma"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01739\">H01739</a>  Polycystic ovary syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01897\">H01897</a>  Oocyte maturation defect"]},{"values":["<a href=\"/entry/H00289\">H00289</a>  Recurrent hydatidiform moles"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00890\">H00890</a>  Azoospermia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01208\">H01208</a>  Globozoospermia"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01282\">H01282</a>  Spermatogenic failure"]},{"values":["<a href=\"/entry/H02317\">H02317</a>  SERKAL syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02318\">H02318</a>  Palmoplantar hyperkeratosis with squamous cell carcinoma of skin and sex reversal"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02335\">H02335</a>  Preimplantation embryonic lethality"]}]}],"values":["<b>Reproductive system diseases</b>"]},{"values":[],"children":[],"expanded":false},{"expanded":false,"children":[{"values":["Skeletal diseases"],"expanded":false,"children":[{"children":[],"expanded":false,"values":["<a href=\"/entry/H00430\">H00430</a>  Fibrodysplasia ossificans progressiva"]},{"values":["<a href=\"/entry/H00431\">H00431</a>  Ossification of the posterior longitudinal ligament of spine"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00437\">H00437</a>  Paget disease of bone"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00441\">H00441</a>  Progressive osseous heteroplasia"]},{"values":["<a href=\"/entry/H00448\">H00448</a>  Familial osteochondritis dissecans"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00457\">H00457</a>  Primary hypertrophic osteoarthropathy"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00472\">H00472</a>  Torg syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00498\">H00498</a>  Gnathodiaphyseal dysplasia"]},{"values":["<a href=\"/entry/H00613\">H00613</a>  Infantile cortical hyperostosis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00623\">H00623</a>  Hajdu-Cheney syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01470\">H01470</a>  Giant cell tumor of bone"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01526\">H01526</a>  Legg-Calve-Perthes Disease"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01529\">H01529</a>  Avascular necrosis of femoral head"]},{"values":["<a href=\"/entry/H01593\">H01593</a>  Osteoporosis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01674\">H01674</a>  Ankylosing spondylitis"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01707\">H01707</a>  Ossified ligamentum flavum"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01708\">H01708</a>  Diffuse idiopathic skeletal hyperostosis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01709\">H01709</a>  Glucocorticoid-induced osteonecrosis"]},{"values":["<a href=\"/entry/H01711\">H01711</a>  Spinal stenosis"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01758\">H01758</a>  Relapsing polychondritis"]},{"values":["<a href=\"/entry/H01774\">H01774</a>  Hyperostosis corticalis generalisata"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01865\">H01865</a>  Multicentric carpotarsal osteolysis syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00888\">H00888</a>  Nephrolithiasis/osteoporosis, hypophosphatemic"]},{"values":["<a href=\"/entry/H02042\">H02042</a>  Familial expansile osteolysis"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02062\">H02062</a>  Familial digital arthropathy-brachydactyly"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02395\">H02395</a>  Calvarial doughnut lesions with bone fragility"]}]},{"values":["Muscular diseases"],"expanded":false,"children":[{"values":["<a href=\"/entry/H00590\">H00590</a>  Congenital muscular dystrophies (CMD/MDC)"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01341\">H01341</a>  Collagen VI myopathy"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01778\">H01778</a>  Ullrich disease"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01340\">H01340</a>  Bethlem myopathy"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01338\">H01338</a>  Myosclerosis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01958\">H01958</a>  Merosin-deficient congenital muscular dystrophy"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01310\">H01310</a>  Multi-minicore disease"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00562\">H00562</a>  Dystrophinopathies"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01963\">H01963</a>  Duchenne muscular dystrophy"]},{"values":["<a href=\"/entry/H01964\">H01964</a>  Becker muscular dystrophy"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00565\">H00565</a>  Sarcoglycanopathies"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01965\">H01965</a>  Miyoshi myopathy"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00568\">H00568</a>  Myotonic dystrophy"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00563\">H00563</a>  Emery-Dreifuss muscular dystrophy"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00591\">H00591</a>  Facioscapulohumeral muscular dystrophy"]},{"values":["<a href=\"/entry/H00704\">H00704</a>  Oculopharyngeal muscular dystrophy"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00592\">H00592</a>  Calpainopathy"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00593\">H00593</a>  Limb-girdle muscular dystrophy"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00567\">H00567</a>  Limb-girdle muscular dystrophy 1C"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01974\">H01974</a>  Limb-girdle muscular dystrophy 2B"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00594\">H00594</a>  Distal myopathy"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02182\">H02182</a>  Distal myopathy, Tateyama type"]},{"values":["<a href=\"/entry/H00566\">H00566</a>  Distal myopathy with anterior tibial onset"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01975\">H01975</a>  Welander distal myopathy"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01976\">H01976</a>  Tibial muscular dystrophy"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01977\">H01977</a>  Laing distal myopathy"]},{"values":["<a href=\"/entry/H00595\">H00595</a>  Myofibrillar myopathies"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00596\">H00596</a>  Nonaka distal myopathy (NM)"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00656\">H00656</a>  Scapuloperoneal myopathy"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00657\">H00657</a>  Reducing body myopathy"]},{"values":["<a href=\"/entry/H00697\">H00697</a>  X-linked myopathy with postural muscle atrophy"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01810\">H01810</a>  Congenital myopathy"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00698\">H00698</a>  Nemaline myopathy"]},{"values":["<a href=\"/entry/H00699\">H00699</a>  Central core disease"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00700\">H00700</a>  Centronuclear myopathy"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00701\">H00701</a>  Congenital fiber type disproportion"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00702\">H00702</a>  Cap myopathy"]},{"values":["<a href=\"/entry/H00703\">H00703</a>  Myosin storage myopathy"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01780\">H01780</a>  Non-dystrophic myotonia"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00705\">H00705</a>  Myotonia congenita"]},{"values":["<a href=\"/entry/H00743\">H00743</a>  Paramyotonia congenita"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00744\">H00744</a>  Potassium-aggravated myotonia"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00215\">H00215</a>  Periodic paralysis"]},{"values":["<a href=\"/entry/H00745\">H00745</a>  Hyperkalemic periodic paralysis (HyperPP)"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00746\">H00746</a>  Hypokalemic periodic paralysis (HypoPP)"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00747\">H00747</a>  Thyrotoxic hypokalemic periodic paralysis"]},{"values":["<a href=\"/entry/H01129\">H01129</a>  Brody myopathy"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01229\">H01229</a>  Inclusion body myopathy 3"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01291\">H01291</a>  Spheroid body myopathy"]},{"values":["<a href=\"/entry/H01505\">H01505</a>  Inclusion body myositis"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01777\">H01777</a>  Schwartz-Jampel syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01781\">H01781</a>  Autophagic vacuolar myopathy"]},{"values":["<a href=\"/entry/H02320\">H02320</a>  Vacuolar myopathy with CASQ1 aggregates"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01804\">H01804</a>  Isaacs syndrome"]},{"values":["<a href=\"/entry/H02031\">H02031</a>  Inclusion body myopathy with Paget disease of bone and frontotemporal dementia"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02084\">H02084</a>  Native American myopathy"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02179\">H02179</a>  Rippling muscle disease"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02258\">H02258</a>  Tubular aggregate myopathy"]},{"values":["<a href=\"/entry/H02321\">H02321</a>  Early-onset myopathy, areflexia, respiratory distress, and dysphagia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02452\">H02452</a>  Muscle hypertrophy"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02513\">H02513</a>  Oculopharyngodistal myopathy"]}]},{"expanded":false,"children":[{"children":[],"expanded":false,"values":["<a href=\"/entry/H00614\">H00614</a>  Hyaline fibromatosis syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01236\">H01236</a>  Familial articular chondrocalcinosis"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01391\">H01391</a>  Familial episodic pain syndrome"]},{"values":["<a href=\"/entry/H01507\">H01507</a>  Seronegative arthritis"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01532\">H01532</a>  Gout"]},{"values":["<a href=\"/entry/H01604\">H01604</a>  Polymyositis and dermatomyositis"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01606\">H01606</a>  Polymyalgia rheumatica"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01636\">H01636</a>  Fibromyalgia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01693\">H01693</a>  Eosinophilic fasciitis"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02089\">H02089</a>  Winchester syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02238\">H02238</a>  Spinal muscular atrophy with congenital bone fractures"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02268\">H02268</a>  Wieacker-Wolff syndrome"],"children":[],"expanded":false}],"values":["Other musculoskeletal diseases"]}],"values":["<b>Musculoskeletal diseases</b>"]},{"values":[],"expanded":false,"children":[]},{"values":["<b>Skin diseases</b>"],"children":[{"children":[{"values":["<a href=\"/entry/H00588\">H00588</a>  Kindler syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00681\">H00681</a>  Acne inversa"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00672\">H00672</a>  Pseudofolliculitis barbae"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00793\">H00793</a>  Poikiloderma with neutropenia"]},{"values":["<a href=\"/entry/H00795\">H00795</a>  Seborrhea-like dermatitis with psoriasiform element"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00780\">H00780</a>  Atrichia with papular lesions"]},{"values":["<a href=\"/entry/H00782\">H00782</a>  Hypotrichosis and recurrent skin vesicles"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00784\">H00784</a>  Localized autosomal recessive hypotrichosis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00786\">H00786</a>  Hypotrichosis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00842\">H00842</a>  Epidermodysplasia verruciformis"]},{"values":["<a href=\"/entry/H00880\">H00880</a>  Dyschromatosis symmetrica hereditaria"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00884\">H00884</a>  Familial progressive hyperpigmentation"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00885\">H00885</a>  Hypomelanosis of Ito"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00895\">H00895</a>  Basal cell nevus syndrome"]},{"values":["<a href=\"/entry/H00904\">H00904</a>  Cutis laxa with severe pulmonary, gastrointestinal, and urinary abnormalities"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00906\">H00906</a>  Macrocephaly, alopecia, cutis laxa, and scoliosis"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00928\">H00928</a>  Nephropathy with pretibial epidermolysis bullosa and deafness"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00944\">H00944</a>  Dowling-Degos disease"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00947\">H00947</a>  Pilomatricoma"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01133\">H01133</a>  Reynolds syndrome"]},{"values":["<a href=\"/entry/H01158\">H01158</a>  Alopecia universalis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01173\">H01173</a>  Stiff skin syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01217\">H01217</a>  Primary localized cutaneous amyloidosis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01357\">H01357</a>  Allergic contact dermatitis"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01358\">H01358</a>  Atopic dermatitis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01362\">H01362</a>  Dermatitis herpetiformis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01372\">H01372</a>  Vitiligo"]},{"values":["<a href=\"/entry/H01394\">H01394</a>  Cole disease"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00827\">H00827</a>  Brooke-Spiegler syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00828\">H00828</a>  Familial cylindromatosis"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00829\">H00829</a>  Multiple familial trichoepithelioma"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01473\">H01473</a>  Erythema nodosum leprosum"]},{"values":["<a href=\"/entry/H01476\">H01476</a>  Behcet disease"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01492\">H01492</a>  Systemic sclerosis"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01493\">H01493</a>  Localized Scleroderma"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01595\">H01595</a>  Cutaneous lupus erythematosus"]},{"values":["<a href=\"/entry/H01643\">H01643</a>  Chilblains"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01655\">H01655</a>  Granulomatosis with polyangiitis"]},{"values":["<a href=\"/entry/H01648\">H01648</a>  Pemphigus"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01650\">H01650</a>  Pemphigoid"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01652\">H01652</a>  Seborrheic dermatitis"]},{"values":["<a href=\"/entry/H01654\">H01654</a>  Lichen planus"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01656\">H01656</a>  Psoriasis"]},{"values":["<a href=\"/entry/H01659\">H01659</a>  Pityriasis rubra pilaris"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01660\">H01660</a>  Pityriasis rosea"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01663\">H01663</a>  Pustular psoriasis"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01661\">H01661</a>  Xanthoma"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01673\">H01673</a>  Palmoplantar keratoderma"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01690\">H01690</a>  Lichen sclerosus et atrophphicus"]},{"values":["<a href=\"/entry/H01694\">H01694</a>  Stevens-Johnson syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01695\">H01695</a>  Erythema multiforme"]},{"values":["<a href=\"/entry/H01796\">H01796</a>  Uncombable hair syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01799\">H01799</a>  Vibratory urticaria"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01848\">H01848</a>  Acquired idiopathic generalized anhidrosis"]},{"values":["<a href=\"/entry/H01905\">H01905</a>  Trichomegaly"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01910\">H01910</a>  Infantile myofibromatosis"]},{"values":["<a href=\"/entry/H00866\">H00866</a>  Trichothiodystrophy"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01307\">H01307</a>  Nonsyndromic congenital nail disorder"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02131\">H02131</a>  UV-sensitive syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02281\">H02281</a>  Isolated anhidrosis with normal sweat glands"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02350\">H02350</a>  Dyschromatosis universalis hereditaria"]},{"values":["<a href=\"/entry/H02429\">H02429</a>  Actinic keratosis"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02486\">H02486</a>  HELIX syndrome"]}],"expanded":false,"values":["Skin and soft tissue diseases"]}],"expanded":false},{"children":[],"expanded":false,"values":[]},{"expanded":false,"children":[{"values":["Congenital disorders of carbohydrate metabolism"],"expanded":false,"children":[{"children":[],"expanded":false,"values":["<a href=\"/entry/H00071\">H00071</a>  Hereditary fructose intolerance"]},{"values":["<a href=\"/entry/H00114\">H00114</a>  Fructose-1,6-bisphosphatase deficiency"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01096\">H01096</a>  Pyruvate kinase deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00072\">H00072</a>  Pyruvate dehydrogenase complex deficiency"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01997\">H01997</a>  Pyruvate dehydrogenase E1-alpha deficiency"]},{"values":["<a href=\"/entry/H01998\">H01998</a>  Pyruvate dehydrogenase E1-beta deficiency"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01999\">H01999</a>  Pyruvate dehydrogenase E2 deficiency"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02000\">H02000</a>  Dihydrolipoamide dehydrogenase deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02003\">H02003</a>  Pyruvate dehydrogenase E3-binding protein deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01996\">H01996</a>  Pyruvate dehydrogenase phosphatase deficiency"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00073\">H00073</a>  Pyruvate carboxylase deficiency"]},{"values":["<a href=\"/entry/H00070\">H00070</a>  Galactosemia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02008\">H02008</a>  Galactose-1P uridylyltransferase deficiency"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02009\">H02009</a>  Galactokinase deficiency"]},{"values":["<a href=\"/entry/H02010\">H02010</a>  Galactose epimerase deficiency"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00116\">H00116</a>  Congenital lactase deficiency"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00069\">H00069</a>  Glycogen storage disease"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01760\">H01760</a>  Hepatic glycogen storage disease"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01762\">H01762</a>  Muscle glycogen storage disease"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01939\">H01939</a>  Glycogen storage disease type I"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01940\">H01940</a>  Glycogen storage disease type II"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01941\">H01941</a>  Glycogen storage disease type III"]},{"values":["<a href=\"/entry/H01942\">H01942</a>  Glycogen storage disease type IV"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01943\">H01943</a>  Glycogen storage disease type V"]},{"values":["<a href=\"/entry/H01944\">H01944</a>  Glycogen storage disease type VI"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01945\">H01945</a>  Glycogen storage disease type VII"]},{"values":["<a href=\"/entry/H01948\">H01948</a>  Glycogen storage disease type IX"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01951\">H01951</a>  Glycogen storage disease type X"]},{"values":["<a href=\"/entry/H01946\">H01946</a>  Glycogen storage disease type XI"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01952\">H01952</a>  Glycogen storage disease type XII"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01953\">H01953</a>  Glycogen storage disease type XIII"]},{"values":["<a href=\"/entry/H01954\">H01954</a>  Glycogen storage disease type XIV"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01955\">H01955</a>  Glycogen storage disease type XV"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01950\">H01950</a>  Glycogen storage disease type 0a"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01949\">H01949</a>  Glycogen storage disease type 0b"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01956\">H01956</a>  Glycogen storage disease of heart"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01947\">H01947</a>  Fanconi-Bickel syndrome"]},{"values":["<a href=\"/entry/H00115\">H00115</a>  Congenital sucrase-isomaltase deficiency"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00117\">H00117</a>  Primary hyperoxaluria"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01071\">H01071</a>  Acute alcohol sensitivity"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01261\">H01261</a>  Congenital glucose-galactose malabsorption"]},{"values":["<a href=\"/entry/H02090\">H02090</a>  Trehalase deficiency"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02439\">H02439</a>  Short stature, developmental delay, congenital heart defect"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02451\">H02451</a>  Congenital disorder of glycosylation with defective fucosylation"]}]},{"expanded":false,"children":[{"expanded":false,"children":[],"values":["<a href=\"/entry/H00149\">H00149</a>  Neuronal ceroid lipofuscinosis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02275\">H02275</a>  Batten disease"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02276\">H02276</a>  Kufs disease"]},{"values":["<a href=\"/entry/H02277\">H02277</a>  Santavuori-Haltia disease"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02278\">H02278</a>  Jansky-Bielschowsky disease"]},{"values":["<a href=\"/entry/H02279\">H02279</a>  Cathepsin D deficiency"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00407\">H00407</a>  Peroxisomal beta-oxidation enzyme deficiency"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00176\">H00176</a>  Adrenoleukodystrophy"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00152\">H00152</a>  Sitosterolemia"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00153\">H00153</a>  Familial combined hyperlipidemia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00151\">H00151</a>  Cerebrotendinous xanthomatosis"]},{"values":["<a href=\"/entry/H00155\">H00155</a>  Familial hypercholesterolemia"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00154\">H00154</a>  Hyperlipoproteinemia, type I"]},{"values":["<a href=\"/entry/H01383\">H01383</a>  Hyperlipoproteinemia type IIa"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00156\">H00156</a>  Hyperlipoproteinemia, type III"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00157\">H00157</a>  Hyperlipoproteinemia, type V"]},{"values":["<a href=\"/entry/H01637\">H01637</a>  Hypertriglyceridemia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00158\">H00158</a>  Lecithin:cholesterol acyltransferase deficiency"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00159\">H00159</a>  Tangier disease [PATH:<a href=\"/pathway/hsa05417\">hsa05417</a>]"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00160\">H00160</a>  Abetalipoproteinemia"]},{"values":["<a href=\"/entry/H00161\">H00161</a>  Smith-Lemli-Opitz syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00162\">H00162</a>  Sjogren-Larsson syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00736\">H00736</a>  Dorfman-Chanarin syndrome"]},{"values":["<a href=\"/entry/H00148\">H00148</a>  Lysosomal acid lipase deficiency"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00134\">H00134</a>  X-linked ichthyosis"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00125\">H00125</a>  Fabry disease"]},{"values":["<a href=\"/entry/H00126\">H00126</a>  Gaucher disease"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00135\">H00135</a>  Krabbe disease"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00137\">H00137</a>  Niemann-Pick disease type A/B"]},{"values":["<a href=\"/entry/H00138\">H00138</a>  Farber lipogranulomatosis"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00127\">H00127</a>  Metachromatic leukodystrophy"]},{"values":["<a href=\"/entry/H00272\">H00272</a>  Multiple sulfatase deficiency"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00281\">H00281</a>  GM1 gangliosidosis"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00124\">H00124</a>  GM2 gangliosidoses"]},{"values":["<a href=\"/entry/H02016\">H02016</a>  Tay-Sachs disease"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02017\">H02017</a>  Sandhoff disease"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00144\">H00144</a>  Mucolipidosis IV"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00146\">H00146</a>  Alpha-N-acetylgalactosaminidase deficiency"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00206\">H00206</a>  Mevalonate kinase deficiency"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00525\">H00525</a>  Disorders of mitochondrial fatty-acid oxidation"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01980\">H01980</a>  SCAD deficiency"]},{"values":["<a href=\"/entry/H00488\">H00488</a>  MCAD deficiency"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00489\">H00489</a>  LCHAD deficiency"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00392\">H00392</a>  VLCAD deficiency"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00375\">H00375</a>  SBCAD deficiency"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01981\">H01981</a>  Carnitine palmitoyltransferase I deficiency"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01982\">H01982</a>  Carnitine palmitoyltransferase II deficiency"]},{"values":["<a href=\"/entry/H01983\">H01983</a>  Carnitine-acylcarnitine translocase deficiency"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00438\">H00438</a>  Nasu-Hakola disease"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00552\">H00552</a>  Chromosome Xp21 deletion syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00628\">H00628</a>  Congenital bile acid synthesis defect"]},{"values":["<a href=\"/entry/H02013\">H02013</a>  Glycerol kinase deficiency"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00601\">H00601</a>  Hutchinson-Gilford progeria syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00679\">H00679</a>  Hypomyelinating leukodystrophy"]},{"values":["<a href=\"/entry/H00869\">H00869</a>  Leukoencephalopathy with vanishing white matter"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02200\">H02200</a>  Leukoencephalopathy, progressive, with ovarian failure"]},{"values":["<a href=\"/entry/H00871\">H00871</a>  Leukoencephalopathy with brain stem and spinal cord involvement and lactate elevation"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00874\">H00874</a>  Leukoencephalopathy with dystonia and motor neuropathy"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00875\">H00875</a>  Megaloencephalic leukoencephalopathy with subcortical cysts"]},{"values":["<a href=\"/entry/H00878\">H00878</a>  Cystic leukoencephalopathy without megalencephaly"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00883\">H00883</a>  Lipoid proteinosis"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00887\">H00887</a>  Lipoprotein glomerulopathy"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00927\">H00927</a>  Chylomicron retention disease"]},{"values":["<a href=\"/entry/H00930\">H00930</a>  Hypoalphalipoproteinemia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01065\">H01065</a>  Pentosuria"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01101\">H01101</a>  Combined lipase deficiency"]},{"values":["<a href=\"/entry/H01126\">H01126</a>  Familial renal glucosuria"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01489\">H01489</a>  Inherited glycosylphosphatidylinositol deficiencies"]},{"values":["<a href=\"/entry/H01127\">H01127</a>  PIGM-congenital disorder of glycosylation"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01485\">H01485</a>  Autosomal recessive mental retardation-42"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01486\">H01486</a>  Multiple congenital anomalies-hypotonia-seizures syndrome"]},{"values":["<a href=\"/entry/H01487\">H01487</a>  CHIME syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01488\">H01488</a>  Hyperphosphatasia with mental retardation syndrome"]},{"values":["<a href=\"/entry/H01189\">H01189</a>  Transaldolase deficiency"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01199\">H01199</a>  Hyperalphalipoproteinemia"]},{"values":["<a href=\"/entry/H01290\">H01290</a>  Acute recurrent myoglobinuria"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01297\">H01297</a>  Neutral lipid storage disease with myopathy"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01589\">H01589</a>  Systemic primary carnitine deficiency"]},{"values":["<a href=\"/entry/H01661\">H01661</a>  Xanthoma"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01784\">H01784</a>  Primary hyperchylomicronemia"]},{"values":["<a href=\"/entry/H01918\">H01918</a>  Familial autosomal recessive hypercholesterolemia"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02284\">H02284</a>  Leukotriene C4 synthase deficiency"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02329\">H02329</a>  Hepatic lipase deficiency"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02330\">H02330</a>  Pancreatic lipase deficiency"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02432\">H02432</a>  Butyrylcholinesterase deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02468\">H02468</a>  Early childhood-onset progressive leukodystrophy"]}],"values":["Congenital disorders of lipid/glycolipid metabolism"]},{"children":[{"values":["<a href=\"/entry/H00118\">H00118</a>  Congenital disorders of glycosylation type I"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00119\">H00119</a>  Congenital disorders of glycosylation type II"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00128\">H00128</a>  Mucopolysaccharidosis type I"]},{"values":["<a href=\"/entry/H00129\">H00129</a>  Mucopolysaccharidosis type II"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00130\">H00130</a>  Mucopolysaccharidosis type III"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00123\">H00123</a>  Mucopolysaccharidosis type IV"]},{"values":["<a href=\"/entry/H00131\">H00131</a>  Mucopolysaccharidosis type VI"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00132\">H00132</a>  Mucopolysaccharidosis type VII"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00133\">H00133</a>  Mucopolysaccharidosis type IX"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02205\">H02205</a>  Mucopolysaccharidosis-plus syndrome"]},{"values":["<a href=\"/entry/H00143\">H00143</a>  Mucolipidosis II"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00139\">H00139</a>  alpha-Mannosidosis"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00140\">H00140</a>  beta-Mannosidosis"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00141\">H00141</a>  Fucosidosis"]},{"values":["<a href=\"/entry/H00142\">H00142</a>  Sialidosis"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00276\">H00276</a>  Galactosialidosis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00145\">H00145</a>  Aspartylglucosaminuria"]},{"values":["<a href=\"/entry/H02307\">H02307</a>  Muscular dystrophy-dystroglycanopathy"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00120\">H00120</a>  Muscular dystrophy-dystroglycanopathy type A"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01960\">H01960</a>  Muscular dystrophy-dystroglycanopathy type B"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01959\">H01959</a>  Muscular dystrophy-dystroglycanopathy type C"]},{"values":["<a href=\"/entry/H01957\">H01957</a>  Fukuyama congenital muscular dystrophy"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01961\">H01961</a>  Congenital muscular dystrophy type 1C"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01962\">H01962</a>  Congenital muscular dystrophy type 1D"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00122\">H00122</a>  Multiple exostoses"]},{"values":["<a href=\"/entry/H00147\">H00147</a>  Sialuria"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00692\">H00692</a>  Lowe syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00996\">H00996</a>  Amish infantile epilepsy syndrome"]},{"values":["<a href=\"/entry/H01188\">H01188</a>  Tn syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01497\">H01497</a>  Temtamy preaxial brachydactyly syndrome"]},{"values":["<a href=\"/entry/H01498\">H01498</a>  Multiple joint dislocations, short stature, craniofacial dysmorphism, and congenital heart defects"],"expanded":false,"children":[]}],"expanded":false,"values":["Congenital disorders of glycan/glycoprotein metabolism"]},{"values":["Congenital disorders of amino acid metabolism"],"children":[{"children":[],"expanded":false,"values":["<a href=\"/entry/H00167\">H00167</a>  Phenylketonuria"]},{"values":["<a href=\"/entry/H00165\">H00165</a>  Tyrosinemia"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00163\">H00163</a>  Alkaptonuria"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00166\">H00166</a>  Hermansky-Pudlak syndrome"]},{"values":["<a href=\"/entry/H00168\">H00168</a>  Oculocutaneous albinism"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00169\">H00169</a>  Ocular albinism"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00170\">H00170</a>  Piebaldism"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00171\">H00171</a>  Histidinemia"]},{"values":["<a href=\"/entry/H00172\">H00172</a>  Maple syrup urine disease"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00173\">H00173</a>  Isovaleric acidemia"]},{"values":["<a href=\"/entry/H00181\">H00181</a>  3-Methylcrotonylglycinuria"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00175\">H00175</a>  Propionic acidemia"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00174\">H00174</a>  Methylmalonic aciduria"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00179\">H00179</a>  3-Hydroxy-3-methylglutaryl-CoA lyase deficiency"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00275\">H00275</a>  Cystinosis"]},{"values":["<a href=\"/entry/H00182\">H00182</a>  Cystathioninuria"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00183\">H00183</a>  Homocystinuria"]},{"values":["<a href=\"/entry/H00184\">H00184</a>  Hypermethioninemia"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00164\">H00164</a>  Carbamoyl phosphate synthetase I deficiency"]},{"values":["<a href=\"/entry/H00185\">H00185</a>  Citrullinemia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00186\">H00186</a>  Hyperargininemia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00178\">H00178</a>  Glutaric acidemia"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00188\">H00188</a>  Hyperlysinemia"]},{"values":["<a href=\"/entry/H00187\">H00187</a>  Ornithine transcarbamylase deficiency"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00189\">H00189</a>  Ornithinaemia"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00190\">H00190</a>  Hyperprolinemia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00191\">H00191</a>  Nonketotic hyperglycinemia"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00074\">H00074</a>  Canavan disease"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00548\">H00548</a>  Brunner syndrome"]},{"values":["<a href=\"/entry/H00754\">H00754</a>  3-Methylglutaconic aciduria"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00834\">H00834</a>  Guanidinoacetate methyltransferase deficiency"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00835\">H00835</a>  Succinic semialdehyde dehydrogenase deficiency"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00849\">H00849</a>  Cerebral creatine deficiency syndrome"]},{"values":["<a href=\"/entry/H00899\">H00899</a>  Lysinuric protein intolerance"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00901\">H00901</a>  Cystinuria"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00905\">H00905</a>  Iminoglycinuria"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00911\">H00911</a>  Dicarboxylic aminoaciduria"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00923\">H00923</a>  Congenital systemic glutamine deficiency"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00925\">H00925</a>  2-Methyl-3-hydroxybutyryl-CoA dehydrogenase (MHBD) deficiency"]},{"values":["<a href=\"/entry/H01003\">H01003</a>  Dimethylglycine dehydrogenase deficiency"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01028\">H01028</a>  Argininosuccinic aciduria"]},{"values":["<a href=\"/entry/H01032\">H01032</a>  N-acetylglutamate synthase deficiency"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01079\">H01079</a>  3-Phosphoglycerate dehydrogenase (3-PGDH) deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01082\">H01082</a>  Phosphoserine aminotransferase deficiency"]},{"values":["<a href=\"/entry/H01076\">H01076</a>  Alpha-methylacetoacetic aciduria"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01119\">H01119</a>  Prolidase deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01121\">H01121</a>  Succinyl CoA:3-oxoacid CoA transferase (SCOT) deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01123\">H01123</a>  HMG-CoA synthase deficiency"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01146\">H01146</a>  Aminoacylase 1 deficiency"]},{"values":["<a href=\"/entry/H01187\">H01187</a>  Tietz syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01198\">H01198</a>  Fanconi renotubular syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01225\">H01225</a>  D-2-hydroxyglutaric aciduria"]},{"values":["<a href=\"/entry/H02304\">H02304</a>  Combined D-2- and L-2-hydroxyglutaric aciduria"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01233\">H01233</a>  Urocanase deficiency"]},{"values":["<a href=\"/entry/H01237\">H01237</a>  Sulfite oxidase deficiency"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01242\">H01242</a>  Saccharopinuria"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01257\">H01257</a>  GABA-transaminase deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01262\">H01262</a>  Formiminotransferase deficiency"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01279\">H01279</a>  Isobutyryl-CoA dehydrogenase deficiency"]},{"values":["<a href=\"/entry/H01280\">H01280</a>  L-2-hydroxyglutaric aciduria"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01283\">H01283</a>  Malonyl-CoA decarboxylase deficiency"]},{"values":["<a href=\"/entry/H01285\">H01285</a>  Methylcobalamin deficiency type G"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00668\">H00668</a>  Anemia due to disorders of glutathione metabolism"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01375\">H01375</a>  Glucose 6-phosphate dehydrogenase deficiency"]},{"values":["<a href=\"/entry/H02312\">H02312</a>  Glutathione synthetase deficiency"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00843\">H00843</a>  Hartnup disorder"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01386\">H01386</a>  Asparagine synthetase deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01398\">H01398</a>  Primary hyperammonemic disorders (Urea cycle disorders)"]},{"values":["<a href=\"/entry/H01400\">H01400</a>  Secondary hyperammonemia"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01583\">H01583</a>  Hydroxykynureninuria"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02087\">H02087</a>  Vertebral, cardiac, renal, and limb defects syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02109\">H02109</a>  Combined malonic and methylmalonic aciduria"]},{"values":["<a href=\"/entry/H02116\">H02116</a>  Phosphoserine phosphatase deficiency"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02117\">H02117</a>  Neu-Laxova syndrome"]},{"values":["<a href=\"/entry/H02136\">H02136</a>  Branched-chain ketoacid dehydrogenase kinase deficiency"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02196\">H02196</a>  X-linked creatine deficiency syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02285\">H02285</a>  Methylmalonate semialdehyde dehydrogenase deficiency"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02311\">H02311</a>  Molybdenum cofactor deficiency"]},{"values":["<a href=\"/entry/H02313\">H02313</a>  5-Oxoprolinase deficiency"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02380\">H02380</a>  D-glyceric aciduria"]},{"values":["<a href=\"/entry/H02419\">H02419</a>  Glycine encephalopathy with normal serum glycine"],"children":[],"expanded":false}],"expanded":false},{"values":["Congenital disorders of nucleotide metabolism"],"children":[{"children":[],"expanded":false,"values":["<a href=\"/entry/H00194\">H00194</a>  Lesch-Nyhan syndrome"]},{"values":["<a href=\"/entry/H00195\">H00195</a>  Adenine phosphoribosyltransferase deficiency"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00197\">H00197</a>  Adenylosuccinate lyase deficiency"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00192\">H00192</a>  Xanthinuria"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00196\">H00196</a>  Phosphoribosylpyrophosphate synthetase superactivity"]},{"values":["<a href=\"/entry/H00198\">H00198</a>  Orotic aciduria"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00193\">H00193</a>  Dihydropyrimidine dehydrogenase deficiency"]},{"values":["<a href=\"/entry/H00199\">H00199</a>  Dihydropyrimidinase deficiency"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00200\">H00200</a>  Beta-ureidopropionase deficiency"]},{"values":["<a href=\"/entry/H00964\">H00964</a>  Thiopurine S-methyltransferase deficiency (TPMT deficiency)"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00966\">H00966</a>  AICA-ribosiduria"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01135\">H01135</a>  Ribose 5-phosphate isomerase deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02237\">H02237</a>  AMP deaminase deficiency"]},{"values":["<a href=\"/entry/H02433\">H02433</a>  Hypomyelination with brainstem and spinal cord involvement and leg spasticity"],"expanded":false,"children":[]}],"expanded":false},{"expanded":false,"children":[{"expanded":false,"children":[],"values":["<a href=\"/entry/H00180\">H00180</a>  Holocarboxylase synthetase deficiency"]},{"values":["<a href=\"/entry/H01763\">H01763</a>  Porphyria"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00201\">H00201</a>  Erythropoietic porphyria"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00202\">H00202</a>  Hepatic porphyria"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00208\">H00208</a>  Hyperbilirubinemia"]},{"values":["<a href=\"/entry/H02054\">H02054</a>  Crigler-Najjar syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02055\">H02055</a>  Gilbert syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02056\">H02056</a>  Dubin-Johnson syndrome"]},{"values":["<a href=\"/entry/H02057\">H02057</a>  Rotor syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00213\">H00213</a>  Hypophosphatasia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00981\">H00981</a>  Ataxia with isolated vitamin E deficiency (AVED)"]},{"values":["<a href=\"/entry/H01143\">H01143</a>  Vitamin D-dependent rickets"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01197\">H01197</a>  Dihydrofolate reductase deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01182\">H01182</a>  Biotinidase deficiency"]},{"values":["<a href=\"/entry/H01567\">H01567</a>  Thiamine pyrophosphokinase deficiency"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02221\">H02221</a>  Methylmalonic aciduria and homocystinuria"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02222\">H02222</a>  Methylmalonic acidemia and hyperhomocysteinemia, cblX type"]}],"values":["Congenital disorders of cofactor/vitamin metabolism"]},{"values":["Congenital disorders of ion transport and metabolism"],"expanded":false,"children":[{"values":["<a href=\"/entry/H00218\">H00218</a>  Cystic fibrosis"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00209\">H00209</a>  Menkes syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00210\">H00210</a>  Wilson disease"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00212\">H00212</a>  Acrodermatitis enteropathica"]},{"values":["<a href=\"/entry/H00211\">H00211</a>  Hemochromatosis"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00217\">H00217</a>  Pulmonary alveolar proteinosis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00214\">H00214</a>  Hypophosphatemic rickets"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02138\">H02138</a>  Hereditary hypophophatemic rickets with hypercalciuria"]},{"values":["<a href=\"/entry/H02139\">H02139</a>  Autosomal recessive hypophosphatemic rickets"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02141\">H02141</a>  Autosomal dominant hypophosphatemic rickets"]},{"values":["<a href=\"/entry/H02142\">H02142</a>  X-linked recessive hypophosphatemic rickets"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02143\">H02143</a>  X-linked dominant hypophosphatemic rickets"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00215\">H00215</a>  Periodic paralysis"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00745\">H00745</a>  Hyperkalemic periodic paralysis (HyperPP)"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00746\">H00746</a>  Hypokalemic periodic paralysis (HypoPP)"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00747\">H00747</a>  Thyrotoxic hypokalemic periodic paralysis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01190\">H01190</a>  Transcobalamin II deficiency"]},{"values":["<a href=\"/entry/H01302\">H01302</a>  Hyperchlorhidrosis isolated (HCHLH)"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01859\">H01859</a>  Occipital horn syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01925\">H01925</a>  Transient neonatal zinc deficiency"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01935\">H01935</a>  Familial hypercholanemia"]},{"values":["<a href=\"/entry/H02026\">H02026</a>  Familial hypocalciuric hypercalcemia"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02340\">H02340</a>  Absorptive hypercalciuria"],"children":[],"expanded":false}]},{"values":["Lysosomal storage diseases"],"expanded":false,"children":[{"values":["<a href=\"/entry/H01425\">H01425</a>  Lysosomal storage disease"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00149\">H00149</a>  Neuronal ceroid lipofuscinosis"]},{"values":["<a href=\"/entry/H00125\">H00125</a>  Fabry disease"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00421\">H00421</a>  Mucopolysaccharidosis"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00128\">H00128</a>  Mucopolysaccharidosis type I"]},{"values":["<a href=\"/entry/H00129\">H00129</a>  Mucopolysaccharidosis type II"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00130\">H00130</a>  Mucopolysaccharidosis type III"]},{"values":["<a href=\"/entry/H00123\">H00123</a>  Mucopolysaccharidosis type IV"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00131\">H00131</a>  Mucopolysaccharidosis type VI"]},{"values":["<a href=\"/entry/H00132\">H00132</a>  Mucopolysaccharidosis type VII"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00133\">H00133</a>  Mucopolysaccharidosis type IX"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00422\">H00422</a>  Glycoproteinoses"]},{"values":["<a href=\"/entry/H00142\">H00142</a>  Sialidosis"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00276\">H00276</a>  Galactosialidosis"]},{"values":["<a href=\"/entry/H00139\">H00139</a>  alpha-Mannosidosis"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00140\">H00140</a>  beta-Mannosidosis"]},{"values":["<a href=\"/entry/H00145\">H00145</a>  Aspartylglucosaminuria"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00141\">H00141</a>  Fucosidosis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00146\">H00146</a>  Alpha-N-acetylgalactosaminidase deficiency"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00423\">H00423</a>  Sphingolipidosis"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00127\">H00127</a>  Metachromatic leukodystrophy"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00135\">H00135</a>  Krabbe disease"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00424\">H00424</a>  Defects in the degradation of sphingomyelin"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00137\">H00137</a>  Niemann-Pick disease type A/B"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00138\">H00138</a>  Farber lipogranulomatosis"]},{"values":["<a href=\"/entry/H00425\">H00425</a>  Lysosomal cysteine protease deficiencies"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00274\">H00274</a>  Papillon-Lefevre syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00273\">H00273</a>  Pycnodysostosis"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00426\">H00426</a>  Gangliosidosis"]},{"values":["<a href=\"/entry/H00281\">H00281</a>  GM1 gangliosidosis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00124\">H00124</a>  GM2 gangliosidoses"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02016\">H02016</a>  Tay-Sachs disease"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02017\">H02017</a>  Sandhoff disease"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00126\">H00126</a>  Gaucher disease"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00136\">H00136</a>  Niemann-Pick disease type C"]},{"values":["<a href=\"/entry/H00143\">H00143</a>  Mucolipidosis II"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02130\">H02130</a>  Mucolipidosis III"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00144\">H00144</a>  Mucolipidosis IV"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00148\">H00148</a>  Lysosomal acid lipase deficiency"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00150\">H00150</a>  Danon disease"]},{"values":["<a href=\"/entry/H00275\">H00275</a>  Cystinosis"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00147\">H00147</a>  Sialuria"]},{"values":["<a href=\"/entry/H01113\">H01113</a>  Acid phosphatase deficiency"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01239\">H01239</a>  Combined SAP deficiency"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02128\">H02128</a>  Defects in lysosomal trafficking"]}]},{"values":["Peroxisomal diseases"],"expanded":false,"children":[{"values":["<a href=\"/entry/H00205\">H00205</a>  Peroxisome biogenesis disorder"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01342\">H01342</a>  Zellweger syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00177\">H00177</a>  Neonatal adrenoleukodystrophy"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00204\">H00204</a>  Infantile Refsum disease"]},{"values":["<a href=\"/entry/H00075\">H00075</a>  Refsum disease"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00207\">H00207</a>  Rhizomelic chondrodysplasia punctata"]},{"values":["<a href=\"/entry/H00407\">H00407</a>  Peroxisomal beta-oxidation enzyme deficiency"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02096\">H02096</a>  Peroxisomal acyl-CoA oxidase deficiency"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02098\">H02098</a>  D-bifunctional protein deficiency"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00176\">H00176</a>  Adrenoleukodystrophy"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00203\">H00203</a>  Acatalasemia"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02099\">H02099</a>  Alpha-methylacyl-CoA racemase deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02100\">H02100</a>  Peroxisomal fatty acyl-CoA reductase 1 disorder"]}]},{"children":[{"expanded":false,"children":[],"values":["<a href=\"/entry/H01427\">H01427</a>  Mitochondrial disease"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00473\">H00473</a>  Mitochondrial complex I deficiency"]},{"values":["<a href=\"/entry/H02005\">H02005</a>  Mitochondrial complex II deficiency"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02086\">H02086</a>  Mitochondrial complex III deficiency"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01368\">H01368</a>  Cytochrome c oxidase (COX) deficiency"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00891\">H00891</a>  Combined oxidative phosphorylation deficiency"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01369\">H01369</a>  ATP synthase deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00469\">H00469</a>  Mitochondrial DNA depletion syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00898\">H00898</a>  Myopathy with lactic acidosis and sideroblastic anaemia"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01305\">H01305</a>  Global cerebral hypomyelination"]},{"values":["<a href=\"/entry/H01347\">H01347</a>  MELAS Syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01354\">H01354</a>  Leigh syndrome [PATH:<a href=\"/pathway/hsa05022\">hsa05022</a>]"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01355\">H01355</a>  Kearns-Sayre syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00068\">H00068</a>  Leber hereditary optic atrophy"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01365\">H01365</a>  Leber hereditary optic neuropathy and dystonia"]},{"values":["<a href=\"/entry/H01118\">H01118</a>  Progressive external ophthalmoplegia"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01348\">H01348</a>  Mitochondrial phosphate carrier deficiency"]},{"values":["<a href=\"/entry/H01349\">H01349</a>  Methacrylic aciduria"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01351\">H01351</a>  Spastic ataxia"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01352\">H01352</a>  Mitochondrial trifunctional protein deficiency"]},{"values":["<a href=\"/entry/H01356\">H01356</a>  Myoclonic Epilepsy and Ragged-Red Fiber Disease"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01363\">H01363</a>  NARP syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01364\">H01364</a>  3-Hydroxyacyl-CoA dehydrogenase deficiency"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01123\">H01123</a>  HMG-CoA synthase deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01367\">H01367</a>  Infantile liver failure"]},{"values":["<a href=\"/entry/H01381\">H01381</a>  Antithrombin III deficiency"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01383\">H01383</a>  Hyperlipoproteinemia type IIa"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01384\">H01384</a>  Mitochondrial recessive ataxia syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01389\">H01389</a>  Alpers syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01390\">H01390</a>  Mitochondrial neurogastrointestinal encephalomyopathy"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01200\">H01200</a>  Fatal infantile cardioencephalomyopathy"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01395\">H01395</a>  Autosomal recessive progressive external ophthalmoplegia"]},{"values":["<a href=\"/entry/H01894\">H01894</a>  Multiple mitochondrial dysfunctions syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01900\">H01900</a>  Encephalopathy due to defective mitochondrial and peroxisomal fission"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01022\">H01022</a>  Diseases of the tricarboxylic acid cycle"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02004\">H02004</a>  Fumarase deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02006\">H02006</a>  Alpha-ketoglutarate dehydrogenase complex deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02007\">H02007</a>  GRACILE syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01929\">H01929</a>  2,4-Dienoyl-CoA reductase deficiency"]},{"values":["<a href=\"/entry/H02085\">H02085</a>  Acyl-CoA dehydrogenase 9 deficiency"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00989\">H00989</a>  Mohr-Tranebjaerg syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00820\">H00820</a>  Bjornstad syndrome"]},{"values":["<a href=\"/entry/H02197\">H02197</a>  Mitochondrial pyruvate carrier deficiency"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02201\">H02201</a>  Mitochondrial myopathy with lactic acidosis"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02438\">H02438</a>  Hyperglycinemia, lactic acidosis, and seizures"]},{"values":["<a href=\"/entry/H02441\">H02441</a>  HUPRA syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02447\">H02447</a>  Myopathy with extrapyramidal signs"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02448\">H02448</a>  Harel-Yoon syndrome"],"children":[],"expanded":false}],"expanded":false,"values":["Mitochondrial diseases"]},{"expanded":false,"children":[{"expanded":false,"children":[],"values":["<a href=\"/entry/H00418\">H00418</a>  Bardet-Biedl syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00419\">H00419</a>  Congenital generalized lipodystrophy"]},{"values":["<a href=\"/entry/H00420\">H00420</a>  Familial partial lipodystrophy"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00759\">H00759</a>  Waardenburg syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00967\">H00967</a>  Adiponectin deficiency"]},{"values":["<a href=\"/entry/H00988\">H00988</a>  Enterokinase deficiency"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01103\">H01103</a>  Alpha-1-antitrypsin deficiency"]},{"values":["<a href=\"/entry/H01108\">H01108</a>  CD36 deficiency"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01168\">H01168</a>  Sea-blue histiocyte disease"]},{"values":["<a href=\"/entry/H01193\">H01193</a>  Familial tumoral calcinosis"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01171\">H01171</a>  Poor drug metabolism"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01205\">H01205</a>  Coumarin resistance"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01210\">H01210</a>  Hypomagnesemia"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00245\">H00245</a>  Calcium sensing receptor (CASR) related disease"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01371\">H01371</a>  Hypercalcemia infantile"]},{"values":["<a href=\"/entry/H01230\">H01230</a>  Adult-onset autosomal dominant leukodystrophy"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01231\">H01231</a>  Biotin-responsive basal ganglia disease"]},{"values":["<a href=\"/entry/H01234\">H01234</a>  Trimethylaminuria"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01248\">H01248</a>  Erythrocyte lactate transporter defect"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01249\">H01249</a>  Ethylmalonic encephalopathy"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01266\">H01266</a>  Hypercarotenemia and vitamin A deficiency"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01267\">H01267</a>  Familial hyperinsulinemic hypoglycemia"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01268\">H01268</a>  Hyperornithinemia-hyperammonemia-homocitrullinuria syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01270\">H01270</a>  Familial hypobetalipoproteinemia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01474\">H01474</a>  Acquired generalized lipodystrophy"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01475\">H01475</a>  Lipodystrophy"]},{"values":["<a href=\"/entry/H01883\">H01883</a>  Nestor-Guillermo progeria syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01909\">H01909</a>  Hypoinsulinemic hypoglycemia with hemihypertrophy"]},{"values":["<a href=\"/entry/H01936\">H01936</a>  Hyperbiliverdinemia"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02152\">H02152</a>  Transient familial neonatal hyperbilirubinemia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02181\">H02181</a>  Idiopathic hyperCKemia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02236\">H02236</a>  Keppen-Lubinsky syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02485\">H02485</a>  Extraoral halitosis due to MTO deficiency"]}],"values":["Other congenital disorders of metabolism"]}],"values":["<b>Congenital disorders of metabolism</b>"]},{"values":[],"children":[],"expanded":false},{"children":[{"expanded":false,"children":[{"values":["<a href=\"/entry/H00269\">H00269</a>  Primary microcephaly"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02132\">H02132</a>  Microcephaly syndrome"]},{"values":["<a href=\"/entry/H00990\">H00990</a>  Microcephaly, Amish type"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01835\">H01835</a>  Neuronal migration disorder"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00268\">H00268</a>  Lissencephaly"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00270\">H00270</a>  Periventricular nodular heterotopia"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00271\">H00271</a>  Polymicrogyria"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00263\">H00263</a>  Acrocallosal syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00839\">H00839</a>  Porencephaly"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00897\">H00897</a>  Pontocerebellar hypoplasia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01160\">H01160</a>  Schizencephaly"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00544\">H00544</a>  Septo-optic dysplasia"]},{"values":["<a href=\"/entry/H00267\">H00267</a>  Holoprosencephaly"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00530\">H00530</a>  Joubert syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00534\">H00534</a>  Cerebral cavernous malformation"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00536\">H00536</a>  Cerebral autosomal dominant arteriopathy with subcortical infarcts and leucoencephalopathy (CADASIL)"]},{"values":["<a href=\"/entry/H00262\">H00262</a>  Spina bifida"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00792\">H00792</a>  Warburg micro syndrome"]},{"values":["<a href=\"/entry/H01001\">H01001</a>  COACH syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01034\">H01034</a>  L1 syndrome"]},{"values":["<a href=\"/entry/H01112\">H01112</a>  Polyhydramnios, megalencephaly, and symptomatic epilepsy"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01211\">H01211</a>  MECP2-related severe neonatal encephalopathy"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01251\">H01251</a>  Focal cortical dysplasia of Taylor"]},{"values":["<a href=\"/entry/H01561\">H01561</a>  Chiari malformation"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01675\">H01675</a>  Syringomyelia"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01677\">H01677</a>  Congenital hydrocephalus"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02458\">H02458</a>  Hydrocephalus due to congenital stenosis of aqueduct of sylvius"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01678\">H01678</a>  Dandy-Walker syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01789\">H01789</a>  You-Hoover-Fong syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01722\">H01722</a>  Galloway-Mowat syndrome"]},{"values":["<a href=\"/entry/H01757\">H01757</a>  Cerebral autosomal recessive arteriopathy with subcortical infarcts and leukoencephalopathy"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01811\">H01811</a>  Arima syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01833\">H01833</a>  Hemimegalencephaly"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01870\">H01870</a>  Microhydranencephaly"]},{"values":["<a href=\"/entry/H01881\">H01881</a>  Complex cortical dysplasia with other brain malformations"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01921\">H01921</a>  MICPCH syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01937\">H01937</a>  Multinucleated neurons, anhydramnios, renal dysplasia, cerebellar hypoplasia, and hydranencephaly"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02118\">H02118</a>  Agnathia-otocephaly complex"]},{"values":["<a href=\"/entry/H02120\">H02120</a>  Anencephaly"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02151\">H02151</a>  Hereditary congenital facial paresis"]},{"values":["<a href=\"/entry/H02178\">H02178</a>  MASA syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02272\">H02272</a>  CAPOS syndrome"]},{"values":["<a href=\"/entry/H02282\">H02282</a>  Spastic tetraplegia, thin corpus callosum, and progressive microcephaly"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02287\">H02287</a>  Deafness, dystonia, and cerebral hypomyelination"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02326\">H02326</a>  Keipert syndrome"]},{"values":["<a href=\"/entry/H02355\">H02355</a>  Deafness and myopia"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02356\">H02356</a>  PCWH syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02358\">H02358</a>  Arthrogryposis multiplex congenita, neurogenic, with myelin defect"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02396\">H02396</a>  Corpus callosum agenesis with facial anomalies and cerebellar ataxia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02431\">H02431</a>  Cerebellar hypoplasia, epilepsy, and global developmental delay"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02444\">H02444</a>  Luscan-Lumish syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02446\">H02446</a>  Autosomal recessive macrocephaly/megalencephaly syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02464\">H02464</a>  Poretti-Boltshauser syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02470\">H02470</a>  Neurodevelopmental disorder with structural brain abnormalities"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02487\">H02487</a>  Diencephalic-mesencephalic junction dysplasia syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02494\">H02494</a>  Alkuraya-Kucinskas syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02501\">H02501</a>  Occipital cortical malformation"]}],"values":["Congenital malformations of the nervous system"]},{"values":["Congenital malformations of eye"],"expanded":false,"children":[{"expanded":false,"children":[],"values":["<a href=\"/entry/H00620\">H00620</a>  Axenfeld-Rieger syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00635\">H00635</a>  Aniridia"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00662\">H00662</a>  Ectopia lentis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00676\">H00676</a>  Congenital primary aphakia"]},{"values":["<a href=\"/entry/H00677\">H00677</a>  Aplasia of lacrimal and salivary glands"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00826\">H00826</a>  Blepharophimosis-ptosis-epicanthus inversus syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01012\">H01012</a>  Oculo-auricular syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01027\">H01027</a>  Microphthalmia"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02170\">H02170</a>  Microphthalmia, syndromic"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02172\">H02172</a>  Nanophthalmos"]},{"values":["<a href=\"/entry/H01029\">H01029</a>  Cornea plana congenita"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01075\">H01075</a>  Peters anomaly"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01114\">H01114</a>  Ocular coloboma"]},{"values":["<a href=\"/entry/H01159\">H01159</a>  Anterior segment dysgenesis"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01203\">H01203</a>  Primary congenital glaucoma"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01766\">H01766</a>  Juvenile retinoschisis"]},{"values":["<a href=\"/entry/H02045\">H02045</a>  Norrie disease"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02074\">H02074</a>  Knobloch syndrome"]},{"values":["<a href=\"/entry/H02203\">H02203</a>  Optic nerve hypoplasia"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02231\">H02231</a>  Optic disc anomalies with retinal and/or macular dystrophy"]},{"values":["<a href=\"/entry/H02270\">H02270</a>  Cavitary optic disc anomalies"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02288\">H02288</a>  Retinal dystrophy with inner retinal dysfunction and ganglion cell abnormalities"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02289\">H02289</a>  Retinal dystrophy with or without extraocular anomalies"]},{"values":["<a href=\"/entry/H02290\">H02290</a>  Retinal dystrophy and iris coloboma with congenital cataract"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02291\">H02291</a>  Retinal dystrophy, iris coloboma, and comedogenic acne syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02292\">H02292</a>  Retinal dystrophy, juvenile cataracts, and short stature syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02426\">H02426</a>  EDICT syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02445\">H02445</a>  Microcornea, myopic chorioretinal atrophy, and telecanthus"]},{"values":["<a href=\"/entry/H02475\">H02475</a>  Retinoschisis"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02514\">H02514</a>  Lacrimal duct defect"],"children":[],"expanded":false}]},{"values":["Congenital malformations of ear"],"expanded":false,"children":[{"values":["<a href=\"/entry/H01286\">H01286</a>  Microtia hearing impairment and cleft palate (MHICP)"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02115\">H02115</a>  Congenital aural atresia"]},{"values":["<a href=\"/entry/H02286\">H02286</a>  Congenital deafness with inner ear agenesis, microtia, and microdontia"],"children":[],"expanded":false}]},{"values":["Congenital malformations of face and neck"],"children":[{"children":[],"expanded":false,"values":["<a href=\"/entry/H00516\">H00516</a>  Cleft lip and/or cleft palate"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00909\">H00909</a>  Cleft palate with ankyloglossia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00817\">H00817</a>  Branchiooculofacial syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01927\">H01927</a>  Van der Woude syndrome"]},{"values":["<a href=\"/entry/H02126\">H02126</a>  Mandibulofacial dysostosis with alopecia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02202\">H02202</a>  Oblique facial cleft"],"expanded":false,"children":[]}],"expanded":false},{"expanded":false,"children":[{"values":["<a href=\"/entry/H00531\">H00531</a>  Venous malformations"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00532\">H00532</a>  Parkes Weber syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00533\">H00533</a>  Hereditary hemorrhagic telangiectasia"]},{"values":["<a href=\"/entry/H00546\">H00546</a>  Atrial septal defect"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00547\">H00547</a>  Atrioventricular septal defect"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00549\">H00549</a>  Tetralogy of Fallot"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00550\">H00550</a>  Complete transposition of the great arteries"]},{"values":["<a href=\"/entry/H00553\">H00553</a>  Congenital supravalvar aortic stenosis"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00554\">H00554</a>  Aortic valve disease"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00579\">H00579</a>  Hereditary angiopathy with nephropathy, aneurysms, and muscle cramps (HANAC)"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00669\">H00669</a>  Naxos disease [PATH:<a href=\"/pathway/hsa05412\">hsa05412</a>]"]},{"values":["<a href=\"/entry/H00800\">H00800</a>  Loeys-Dietz syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01272\">H01272</a>  Hypoplastic left heart syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01630\">H01630</a>  Patent ductus arteriosus"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01783\">H01783</a>  Ebstein anomaly"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01785\">H01785</a>  Tricuspid atresia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01786\">H01786</a>  Congenitally corrected transposition of the great arteries"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01787\">H01787</a>  Univentricular heart"]},{"values":["<a href=\"/entry/H01802\">H01802</a>  Pulmonary atresia with intact ventricular septum"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01803\">H01803</a>  Pulmonary atresia with ventricular septal defect"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01849\">H01849</a>  Peripheral arteriovenous malformation"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02094\">H02094</a>  Carvajal syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02043\">H02043</a>  Capillary malformation-arteriovenous malformation"]},{"values":["<a href=\"/entry/H02044\">H02044</a>  Cutaneous and mucosal venous malformation"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02199\">H02199</a>  Congenital heart defects, multiple type"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02230\">H02230</a>  X-linked cardiac valvular dysplasia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02375\">H02375</a>  Cardiac valvular defect, developmental"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02453\">H02453</a>  Congenital heart defects and ectodermal dysplasia"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02454\">H02454</a>  Congenital heart defects, dysmorphic facial features, and intellectual developmental disorder"]},{"values":["<a href=\"/entry/H02455\">H02455</a>  Congenital heart defects, hamartomas of tongue, and polysyndactyly"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00939\">H00939</a>  Darsun syndrome"]}],"values":["Congenital malformations of the circulatory system"]},{"values":["Congenital malformations of the digestive system"],"expanded":false,"children":[{"expanded":false,"children":[],"values":["<a href=\"/entry/H00463\">H00463</a>  Currarino syndrome"]},{"values":["<a href=\"/entry/H00545\">H00545</a>  Polycystic liver disease"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00551\">H00551</a>  Alagille syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00652\">H00652</a>  Solitary median maxillary central incisor syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00677\">H00677</a>  Aplasia of lacrimal and salivary glands"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00724\">H00724</a>  White sponge nevus"]},{"values":["<a href=\"/entry/H00910\">H00910</a>  Hirschsprung disease"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01477\">H01477</a>  Congenital short bowel syndrome"]},{"values":["<a href=\"/entry/H01805\">H01805</a>  Tricho-hepato-enteric syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01855\">H01855</a>  Biliary atresia"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01858\">H01858</a>  Persistent cloaca"]},{"values":["<a href=\"/entry/H01869\">H01869</a>  Megacystis microcolon intestinal hypoperistalsis syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02331\">H02331</a>  Gastrointestinal defects and immunodeficiency syndrome"],"children":[],"expanded":false}]},{"values":["Congenital malformations of genital organs"],"expanded":false,"children":[{"values":["<a href=\"/entry/H00460\">H00460</a>  Hand-foot-genital syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01033\">H01033</a>  Congenital bilateral absence of vas deferens"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01973\">H01973</a>  Fertile eunuch syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02175\">H02175</a>  Hypospadias"]},{"values":["<a href=\"/entry/H02176\">H02176</a>  Cryptorchidism"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02177\">H02177</a>  Androgen insensitivity syndrome"]}]},{"children":[{"values":["<a href=\"/entry/H00261\">H00261</a>  Meckel syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00537\">H00537</a>  Nephronophthisis"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00538\">H00538</a>  Senior-Loken syndrome"]},{"values":["<a href=\"/entry/H00542\">H00542</a>  Polycystic kidney disease"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00575\">H00575</a>  Renal tubular dysgenesis"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00822\">H00822</a>  Renal hypodysplasia and aplasia"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01026\">H01026</a>  Renal coloboma syndrome"]},{"values":["<a href=\"/entry/H01728\">H01728</a>  Potter syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01856\">H01856</a>  Cloacal exstrophy"]},{"values":["<a href=\"/entry/H01867\">H01867</a>  Congenital anomalies of kidney and urinary tract"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02012\">H02012</a>  Medullary cystic kidney disease"]},{"values":["<a href=\"/entry/H02495\">H02495</a>  Congenital megabladder"],"children":[],"expanded":false}],"expanded":false,"values":["Congenital malformations of the urinary system"]},{"children":[{"values":["<a href=\"/entry/H00207\">H00207</a>  Rhizomelic chondrodysplasia punctata"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00434\">H00434</a>  Camurati-Engelmann disease"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00436\">H00436</a>  Osteopetrosis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00444\">H00444</a>  Osteopathia striata with cranial sclerosis"]},{"values":["<a href=\"/entry/H00445\">H00445</a>  Osteoarthritis with mild chondrodysplasia"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00447\">H00447</a>  HEM skeletal dysplasia"]},{"values":["<a href=\"/entry/H00450\">H00450</a>  Worth type autosomal dominant osteosclerosis"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00452\">H00452</a>  Buschke-Ollendorff syndrome"]},{"values":["<a href=\"/entry/H00456\">H00456</a>  Fronto-otopalatodigital syndromes"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00459\">H00459</a>  Synpolydactyly"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00461\">H00461</a>  Ischiocoxopodopatellar syndrome"]},{"values":["<a href=\"/entry/H00462\">H00462</a>  Stuve-Wiedemann syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00466\">H00466</a>  Grebe dysplasia"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00467\">H00467</a>  Fibular hypoplasia and complex brachydactyly"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00468\">H00468</a>  Acromesomelic dysplasia, Demirhan type"]},{"values":["<a href=\"/entry/H00470\">H00470</a>  Acromesomelic dysplasia, Maroteaux type"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00471\">H00471</a>  Split-hand/foot malformation"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00474\">H00474</a>  Schneckenbecken dysplasia"]},{"values":["<a href=\"/entry/H00475\">H00475</a>  Enlarged parietal foramina/cranium bifidum"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00476\">H00476</a>  Multiple epiphyseal dysplasia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00477\">H00477</a>  Pseudoachondroplasia"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00479\">H00479</a>  Metaphyseal dysplasias"]},{"values":["<a href=\"/entry/H00482\">H00482</a>  Brachydactyly"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00483\">H00483</a>  Angel shaped phalangoepiphyseal dysplasia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00484\">H00484</a>  Multiple synostosis syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00486\">H00486</a>  Sclerosteosis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00491\">H00491</a>  Craniometaphyseal dysplasia"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00494\">H00494</a>  Desbuquois syndrome"]},{"values":["<a href=\"/entry/H00495\">H00495</a>  Eiken dysplasia"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00499\">H00499</a>  Spondylocarpotarsal synostosis syndrome"]},{"values":["<a href=\"/entry/H00493\">H00493</a>  Heparan sulfate proteoglycan gene defects"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00501\">H00501</a>  Fibrous dysplasia, polyostotic"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00503\">H00503</a>  Ellis-van Creveld syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00505\">H00505</a>  FGFR3-related short limb skeletal dysplasia"]},{"values":["<a href=\"/entry/H01749\">H01749</a>  Achondroplasia"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01750\">H01750</a>  Thanatophoric dysplasia"]},{"values":["<a href=\"/entry/H00506\">H00506</a>  Osteogenesis imperfecta"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00508\">H00508</a>  Blomstrand syndrome"]},{"values":["<a href=\"/entry/H00511\">H00511</a>  Short rib-polydactyly syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00514\">H00514</a>  Bruck syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00515\">H00515</a>  Atelosteogenesis type II"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00517\">H00517</a>  Spondylocostal dysostosis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00521\">H00521</a>  Cleidocranial dysplasia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00522\">H00522</a>  Brachyolmia"]},{"values":["<a href=\"/entry/H00528\">H00528</a>  Frontonasal dysplasia"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02210\">H02210</a>  Acromelic frontonasal dysostosis"]},{"values":["<a href=\"/entry/H02211\">H02211</a>  Acrodysostosis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00540\">H00540</a>  Osteoporosis, lymphedema, anhydrotic ectodermal dysplasia with immunodeficiency (OLEDAID)"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00572\">H00572</a>  ESCO2-related disorders"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00580\">H00580</a>  Schimke immunoosseous dysplasia"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00629\">H00629</a>  Acheiropodia"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00636\">H00636</a>  Tetra-amelia syndrome"]},{"values":["<a href=\"/entry/H00637\">H00637</a>  Ulnar-mammary syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00660\">H00660</a>  Congenital contractural arachnodactyly"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00751\">H00751</a>  Asphyxiating thoracic dystrophy"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00758\">H00758</a>  Progressive pseudorheumatoid dysplasia"]},{"values":["<a href=\"/entry/H00778\">H00778</a>  Tarsal-carpal coalition syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00846\">H00846</a>  Fuhrmann syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00847\">H00847</a>  Al-Awadi/Raas-Rothschild syndrome"]},{"values":["<a href=\"/entry/H00850\">H00850</a>  Frontorhiny"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00851\">H00851</a>  Proximal symphalangism"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00852\">H00852</a>  Klippel-Feil syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00853\">H00853</a>  Cenani-Lenz syndactyly syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00855\">H00855</a>  Triphalangeal thumb-polysyndactyly syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01226\">H01226</a>  Polysyndactyly"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02332\">H02332</a>  Preaxial polydactyly"]},{"values":["<a href=\"/entry/H02333\">H02333</a>  Laurin-Sandrow syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00863\">H00863</a>  Spondylo-megaepiphyseal-metaphyseal dysplasia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00865\">H00865</a>  Lethal congenital contractural syndrome"]},{"values":["<a href=\"/entry/H00870\">H00870</a>  Brachydactyly-syndactyly syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00903\">H00903</a>  Congenital clubfoot"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00929\">H00929</a>  Congenital vertical talus"]},{"values":["<a href=\"/entry/H00979\">H00979</a>  Caudal regression syndrome and Sirenomelia"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01018\">H01018</a>  Metachondromatosis"]},{"values":["<a href=\"/entry/H01030\">H01030</a>  Congenital arthrogryposis with anterior horn cell disease"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01095\">H01095</a>  Syndactyly"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01105\">H01105</a>  Cranio-lenticulo-sutural dysplasia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01194\">H01194</a>  X-linked chondrodysplasia punctata"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01207\">H01207</a>  Trigonocephaly"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01241\">H01241</a>  Congenital diaphragmatic hernia"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01246\">H01246</a>  Isolated congenital nail clubbing"]},{"values":["<a href=\"/entry/H01376\">H01376</a>  Acrofacial dysostosis"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01392\">H01392</a>  Arthrogryposis, mental retardation, and seizures"]},{"values":["<a href=\"/entry/H01393\">H01393</a>  Van Maldergem syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01402\">H01402</a>  Nicolaides-Baraitser syndrome"]},{"values":["<a href=\"/entry/H01571\">H01571</a>  Singleton-Merten syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01572\">H01572</a>  Cole-Carpenter syndrome"]},{"values":["<a href=\"/entry/H01575\">H01575</a>  Roifman syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01817\">H01817</a>  Beukes hip dysplasia"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01824\">H01824</a>  CODAS syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02343\">H02343</a>  EVEN-plus syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00490\">H00490</a>  Diaphyseal dysplasia with anemia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02185\">H02185</a>  Spondylometaphyseal dysplasia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01821\">H01821</a>  Spondylometaphyseal dysplasia with cone-rod dystrophy"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01825\">H01825</a>  Spondylometaphyseal dysplasia, Sedaghatian type"]},{"values":["<a href=\"/entry/H01830\">H01830</a>  Spondylometaphyseal dysplasia, Megarbane-Dagher-Melki type"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02462\">H02462</a>  Spondyloepiphyseal dysplasia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00519\">H00519</a>  Spondyloepiphyseal dysplasia congenita"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00760\">H00760</a>  Spondyloepiphyseal dysplasia tarda"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00762\">H00762</a>  Spondyloepiphyseal dysplasia with congenital joint dislocations"]},{"values":["<a href=\"/entry/H00765\">H00765</a>  Spondyloepiphyseal dysplasia, Kimberley type"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02186\">H02186</a>  Spondyloepiphyseal dysplasia, Maroteaux type"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02187\">H02187</a>  Spondyloepimetaphyseal dysplasia"]},{"values":["<a href=\"/entry/H00761\">H00761</a>  SEMD, Pakistani type"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00767\">H00767</a>  SEMD, Matrilin type"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00777\">H00777</a>  SEMD, short limb-hand type"]},{"values":["<a href=\"/entry/H01494\">H01494</a>  SEMD with joint laxity type"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01576\">H01576</a>  Spondyloenchondrodysplasia with immune dysregulation (SPENCDI)"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01828\">H01828</a>  Opsismodysplasia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01832\">H01832</a>  Lenz-Majewski syndrome"]},{"values":["<a href=\"/entry/H01851\">H01851</a>  Congenital scoliosis associated with rib anomalies"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01852\">H01852</a>  Postaxial polydactyly"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01854\">H01854</a>  Metacarpal 4-5 fusion"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01884\">H01884</a>  Auriculocondylar syndrome"]},{"values":["<a href=\"/entry/H02048\">H02048</a>  Larsen syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02063\">H02063</a>  Diastrophic dysplasia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02064\">H02064</a>  Atelosteogenesis type I and III"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00678\">H00678</a>  Achondrogenesis type IA"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02065\">H02065</a>  Achondrogenesis type IB"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02066\">H02066</a>  Achondrogenesis type II"]},{"values":["<a href=\"/entry/H02068\">H02068</a>  Hypochondroplasia"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02069\">H02069</a>  SADDAN"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02070\">H02070</a>  Kniest dysplasia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02071\">H02071</a>  Czech dysplasia"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00520\">H00520</a>  Type II collagenopathies"]},{"values":["<a href=\"/entry/H02079\">H02079</a>  Oto-spondylo-megaepiphyseal dysplasia"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02080\">H02080</a>  Fibrochondrogenesis"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02154\">H02154</a>  Omodysplasia"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02155\">H02155</a>  Dyssegmental dysplasia"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02157\">H02157</a>  Short-rib thoracic dysplasia"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02158\">H02158</a>  Weyers acrofacial dysostosis"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02161\">H02161</a>  Greig cephalopolysyndactyly syndrome"]},{"values":["<a href=\"/entry/H02183\">H02183</a>  Parastremmatic dwarfism"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02184\">H02184</a>  Metatropic dysplasia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02223\">H02223</a>  Osteocraniostenosis"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02227\">H02227</a>  Frontometaphyseal dysplasia"]},{"values":["<a href=\"/entry/H02228\">H02228</a>  Acromicric dysplasia"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02299\">H02299</a>  Arthrogryposis multiplex congenita"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02300\">H02300</a>  Steel syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02306\">H02306</a>  Chondrodysplasia with joint dislocations, GPAPP type"]},{"values":["<a href=\"/entry/H02349\">H02349</a>  Odontochondrodysplasia"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02415\">H02415</a>  Craniofacial dysmorphism, skeletal anomalies, and mental retardation syndrome"]},{"values":["<a href=\"/entry/H02436\">H02436</a>  Al-Gazali syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02491\">H02491</a>  Immunoskeletal dysplasia with neurodevelopmental abnormalities"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02497\">H02497</a>  Smith-McCort dysplasia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02502\">H02502</a>  Joint laxity, short stature, and myopia"]}],"expanded":false,"values":["Congenital malformations of the musculoskeletal system"]},{"values":["Congenital malformations of skin"],"children":[{"values":["<a href=\"/entry/H01771\">H01771</a>  Congenital ichthyosis"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00134\">H00134</a>  X-linked ichthyosis"]},{"values":["<a href=\"/entry/H00671\">H00671</a>  Netherton syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00691\">H00691</a>  Bullous congenital ichthyosiform erythroderma (BCIE)"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00693\">H00693</a>  Ichthyosis bullosa of Siemens"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00707\">H00707</a>  Ichthyosis hystrix, Curth-Macklin type"]},{"values":["<a href=\"/entry/H02265\">H02265</a>  Annular epidermolytic ichthyosis"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00712\">H00712</a>  KID/HID syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00733\">H00733</a>  Harlequin ichthyosis"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00734\">H00734</a>  Autosomal recessive congenital ichthyosis"]},{"values":["<a href=\"/entry/H02449\">H02449</a>  Autosomal dominant lamellar ichthyosis"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00735\">H00735</a>  Ichthyosis vulgaris"]},{"values":["<a href=\"/entry/H00737\">H00737</a>  Peeling skin syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00738\">H00738</a>  Ichthyosis with confetti"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00739\">H00739</a>  Ichthyosis with hypotrichosis"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00740\">H00740</a>  Ichthyosis follicularis, alopecia, and photophobia syndrome"]},{"values":["<a href=\"/entry/H00741\">H00741</a>  Ichthyosis prematurity syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00742\">H00742</a>  Neonatal ichthyosis-sclerosing cholangitis (NISCH) syndrome"]},{"values":["<a href=\"/entry/H01737\">H01737</a>  Epidermolysis bullosa"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00584\">H00584</a>  Epidermolysis bullosa simplex"]},{"values":["<a href=\"/entry/H00585\">H00585</a>  Epidermolysis bullosa, hemidesmosomal"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00586\">H00586</a>  Epidermolysis bullosa, junctional"]},{"values":["<a href=\"/entry/H00587\">H00587</a>  Epidermolysis bullosa, dysprophica"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00763\">H00763</a>  Transient bullous dermolysis of the newborn"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00425\">H00425</a>  Lysosomal cysteine protease deficiencies"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00274\">H00274</a>  Papillon-Lefevre syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00487\">H00487</a>  Tricho-dento-osseous syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00646\">H00646</a>  Odontoonychodermal dysplasia"]},{"values":["<a href=\"/entry/H00535\">H00535</a>  Lymphatic malformation"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00557\">H00557</a>  Cutis laxa"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00558\">H00558</a>  Geroderma osteodysplasticum"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00560\">H00560</a>  Pseudoxanthoma elasticum"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00638\">H00638</a>  Ectrodactyly-ectodermal dysplasia cleft-palate syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00645\">H00645</a>  Incontinentia pigmenti"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00644\">H00644</a>  Ectodermal dysplasia/skin fragility syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00647\">H00647</a>  Ectodermal dysplasia-syndactyly syndrome"]},{"values":["<a href=\"/entry/H00648\">H00648</a>  Ectodermal dysplasia, Clouston type"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00649\">H00649</a>  Ectodermal dysplasia, hair-nail type"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00651\">H00651</a>  Hypohidrotic ectodermal dysplasia"]},{"values":["<a href=\"/entry/H02456\">H02456</a>  Ectodermal dysplasia"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00663\">H00663</a>  Restrictive dermopathy"]},{"values":["<a href=\"/entry/H00695\">H00695</a>  Mal de Meleda"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00696\">H00696</a>  Haim-Munk syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00706\">H00706</a>  Bart-Pumphrey syndrome"]},{"values":["<a href=\"/entry/H00708\">H00708</a>  Naegeli-Franceschetti-Jadassohn syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00710\">H00710</a>  Erythrokeratodermia variabilis"]},{"values":["<a href=\"/entry/H00714\">H00714</a>  Vohwinkel syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00715\">H00715</a>  Darier disease"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00716\">H00716</a>  Palmoplantar keratoderma with deafness"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00717\">H00717</a>  Striate palmoplantar keratoderma"]},{"values":["<a href=\"/entry/H00722\">H00722</a>  Epidermolytic palmoplantar keratoderma"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00723\">H00723</a>  Non-epidermolytic palmoplantar keratoderma"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02263\">H02263</a>  Focal nonepidermolytic palmoplantar keratoderma"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02264\">H02264</a>  Palmoplantar keratoderma, Nagashima type"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02266\">H02266</a>  Palmoplantar keratoderma, Bothnian type"]},{"values":["<a href=\"/entry/H00750\">H00750</a>  Keratosis follicularis spinulosa decalvans"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00755\">H00755</a>  Acrokeratosis verruciformis"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00781\">H00781</a>  Schopf-Schulz-Passarge syndrome"]},{"values":["<a href=\"/entry/H00790\">H00790</a>  Keratosis linearis with ichthyosis congenita and sclerosing keratoderma"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00791\">H00791</a>  Disseminated superficial actinic porokeratosis (DSAP)"]},{"values":["<a href=\"/entry/H00796\">H00796</a>  Dermatopathia pigmentosa reticularis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00799\">H00799</a>  CEDNIK syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00802\">H00802</a>  Ehlers-Danlos syndrome"]},{"values":["<a href=\"/entry/H02241\">H02241</a>  Ehlers-Danlos syndrome cardiac valvular type"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02242\">H02242</a>  Ehlers-Danlos syndrome vascular type"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02243\">H02243</a>  Ehlers-Danlos syndrome arthrochalasia type"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02244\">H02244</a>  Ehlers-Danlos syndrome dermatospraxis type"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02245\">H02245</a>  Ehlers-Danlos syndrome kyphoscoliosis type"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02239\">H02239</a>  Ehlers-Danlos syndrome, spondylodysplastic type"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02246\">H02246</a>  Ehlers-Danlos syndrome musculocontractural type"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02247\">H02247</a>  Ehlers-Danlos syndrome myopathic type"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02240\">H02240</a>  Ehlers-Danlos syndrome periodontal type"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01902\">H01902</a>  Brittle cornea syndrome"]},{"values":["<a href=\"/entry/H00813\">H00813</a>  Laryngo onycho cutaneous syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00844\">H00844</a>  Familial benign chronic pemphigus"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00893\">H00893</a>  Skin fragility-woolly hair syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00949\">H00949</a>  Focal dermal hypoplasia"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01017\">H01017</a>  Choanal atresia and lymphedema"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01404\">H01404</a>  Punctate palmoplantar keratoderma"]},{"values":["<a href=\"/entry/H01428\">H01428</a>  Xeroderma pigmentosum"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01579\">H01579</a>  Congenital symmetric circumferential skin creases"]},{"values":["<a href=\"/entry/H01933\">H01933</a>  Porokeratosis"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00667\">H00667</a>  Woolly hair"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00670\">H00670</a>  Monilethrix"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00683\">H00683</a>  Anonychia congenita"]},{"values":["<a href=\"/entry/H00684\">H00684</a>  Pachyonychia congenita"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00858\">H00858</a>  Marie-Unna hereditary hypotrichosis"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01896\">H01896</a>  Aplasia cutis congenita"]},{"values":["<a href=\"/entry/H01906\">H01906</a>  Poikiloderma, hereditary fibrosing, with tendon contractures, myopathy, and pulmonary fibrosis"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02083\">H02083</a>  Focal facial dermal dysplasia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02119\">H02119</a>  Proteus syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02167\">H02167</a>  Lymphedema-distichiasis syndrome"]},{"values":["<a href=\"/entry/H02168\">H02168</a>  Hypotrichosis-lymphedema-telangiectasia syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02220\">H02220</a>  MEDNIK syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02295\">H02295</a>  Adermatoglyphia"]},{"values":["<a href=\"/entry/H02296\">H02296</a>  Basan syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02417\">H02417</a>  Gingival fibromatosis with hypertrichosis"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02474\">H02474</a>  Blepharocheilodontic syndrome"]}],"expanded":false},{"values":["Other congenital malformations"],"expanded":false,"children":[{"expanded":false,"children":[],"values":["<a href=\"/entry/H00417\">H00417</a>  Alstrom syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00433\">H00433</a>  Holt-Oram syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00442\">H00442</a>  Campomelic dysplasia"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00443\">H00443</a>  Osteoglophonic dysplasia"]},{"values":["<a href=\"/entry/H00446\">H00446</a>  Craniofacial-deafness-hand syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00449\">H00449</a>  Oculodentodigital dysplasia"]},{"values":["<a href=\"/entry/H00451\">H00451</a>  Osteoporosis-pseudoglioma syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00453\">H00453</a>  Branchio-oto-renal syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00454\">H00454</a>  Oral-facial-digital syndrome"]},{"values":["<a href=\"/entry/H00748\">H00748</a>  Andersen-Tawil syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02160\">H02160</a>  Craniosynostoses"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00458\">H00458</a>  Syndromic craniosynostoses"]},{"values":["<a href=\"/entry/H01753\">H01753</a>  Antley-Bixler syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01754\">H01754</a>  Crouzon syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01755\">H01755</a>  Apert syndrome"]},{"values":["<a href=\"/entry/H01756\">H01756</a>  Pfeiffer syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01988\">H01988</a>  Jackson-Weiss syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01989\">H01989</a>  Beare-Stevenson syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01990\">H01990</a>  Muenke syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01991\">H01991</a>  Saethre-Chotzen syndrome"]},{"values":["<a href=\"/entry/H01992\">H01992</a>  Craniofrontonasal syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01993\">H01993</a>  Baller-Gerold syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00464\">H00464</a>  Nail-patella syndrome"]},{"values":["<a href=\"/entry/H00485\">H00485</a>  Robinow syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00492\">H00492</a>  SHOX-related short stature"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00496\">H00496</a>  Congenital hemidysplasia with ichthyosiform nevus and limb defects (CHILD)"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00500\">H00500</a>  Keutel syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00502\">H00502</a>  Pallister-Hall syndrome"]},{"values":["<a href=\"/entry/H00504\">H00504</a>  Rubinstein-Taybi syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00509\">H00509</a>  3M syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00510\">H00510</a>  Feingold syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00526\">H00526</a>  Camptodactyly-arthropathy-coxa vara-pericarditis syndrome"]},{"values":["<a href=\"/entry/H00543\">H00543</a>  Renal-hepatic-pancreatic dysplasia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00571\">H00571</a>  Johanson-Blizzard syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00574\">H00574</a>  Coffin-Lowry syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00581\">H00581</a>  Alport syndrome"]},{"values":["<a href=\"/entry/H00597\">H00597</a>  Snyder-Robinson syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00617\">H00617</a>  Desmosterolosis"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00631\">H00631</a>  Cornelia de Lange syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00634\">H00634</a>  Duane-radial ray syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00639\">H00639</a>  Ectodermal dysplasia, ectrodactyly, and macular dystrophy"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00640\">H00640</a>  Limb-mammary syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00641\">H00641</a>  ADULT syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00665\">H00665</a>  Mandibuloacral dysplasia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00673\">H00673</a>  Weill-Marchesani syndrome"]},{"values":["<a href=\"/entry/H00675\">H00675</a>  Acrocapitofemoral dysplasia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00682\">H00682</a>  Woodhouse-Sakati syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00756\">H00756</a>  Pitt-Hopkins syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00757\">H00757</a>  Dyggve-Melchior-Clausen disease"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00785\">H00785</a>  Congenital hypotrichosis with juvenile macular dystrophy"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00907\">H00907</a>  Kleefstra syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00908\">H00908</a>  Mowat-Wilson syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00921\">H00921</a>  Revesz syndrome"]},{"values":["<a href=\"/entry/H00936\">H00936</a>  Goldberg-Shprintzen megacolon syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00940\">H00940</a>  Cohen syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00523\">H00523</a>  Noonan syndrome and related disorders"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01738\">H01738</a>  Noonan syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01984\">H01984</a>  Leopard syndrome"]},{"values":["<a href=\"/entry/H01745\">H01745</a>  Cardiofaciocutaneous syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01747\">H01747</a>  Costello syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02190\">H02190</a>  CBL syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02191\">H02191</a>  Noonan-like syndrome with loose anagen hair"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02189\">H02189</a>  Neurofibromatosis-Noonan syndrome"]},{"values":["<a href=\"/entry/H01437\">H01437</a>  Neurofibromatosis type 1"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01438\">H01438</a>  Neurofibromatosis type 2"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02188\">H02188</a>  Watson syndrome"]},{"values":["<a href=\"/entry/H01986\">H01986</a>  Legius syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00539\">H00539</a>  PTEN hamartoma tumor syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01222\">H01222</a>  Cowden syndrome"]},{"values":["<a href=\"/entry/H00559\">H00559</a>  von Hippel-Lindau syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00296\">H00296</a>  Defects in RecQ helicases"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01346\">H01346</a>  Bloom syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01734\">H01734</a>  Rothmund-Thomson syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00403\">H00403</a>  Disorders of nucleotide excision repair"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01800\">H01800</a>  Verheij syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00529\">H00529</a>  Cranioectodermal dysplasia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00569\">H00569</a>  Aarskog-Scott syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00583\">H00583</a>  Opitz-GBBB syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00555\">H00555</a>  Char syndrome"]},{"values":["<a href=\"/entry/H00556\">H00556</a>  CHARGE syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00570\">H00570</a>  Kabuki syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00573\">H00573</a>  Townes-Brocks syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00611\">H00611</a>  Popliteal pterygium syndrome (PPS)"]},{"values":["<a href=\"/entry/H00619\">H00619</a>  Kenny-Caffey syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00632\">H00632</a>  Heterotaxy"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00622\">H00622</a>  Hypoparathyroidism-retardation-dysmorphism syndrome"]},{"values":["<a href=\"/entry/H00642\">H00642</a>  Lacrimo-auriculo-dento-digital syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00643\">H00643</a>  Tooth and nail syndrome"]},{"values":["<a href=\"/entry/H00709\">H00709</a>  Birk Barel mental retardation syndrome (BBMRS)"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00711\">H00711</a>  Russell-Silver syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00713\">H00713</a>  Beckwith-Wiedemann syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00718\">H00718</a>  Sotos syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01751\">H01751</a>  Weaver syndrome"]},{"values":["<a href=\"/entry/H00653\">H00653</a>  Marfan syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00659\">H00659</a>  Shprintzen-Goldberg syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00661\">H00661</a>  MASS phenotype"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00685\">H00685</a>  Bifid nose with or without anorectal and renal anomalies"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00686\">H00686</a>  Manitoba oculotrichoanal syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00687\">H00687</a>  Fraser syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00727\">H00727</a>  Athabascan brainstem dysgenesis syndrome"]},{"values":["<a href=\"/entry/H00752\">H00752</a>  Ankyloblepharon-ctodermal defects-cleft lip/palate (AEC) syndrome and Rapp-Hodgkin syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00797\">H00797</a>  Martsolf syndrome"]},{"values":["<a href=\"/entry/H00811\">H00811</a>  Distal arthrogryposis"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00872\">H00872</a>  Trismus-pseudocamptodactyly syndrome"]},{"values":["<a href=\"/entry/H00882\">H00882</a>  Cocoon syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00894\">H00894</a>  FG syndrome"]},{"values":["<a href=\"/entry/H00859\">H00859</a>  Guttmacher syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00867\">H00867</a>  Radioulnar synostosis with amegakaryocytic thrombocytopenia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00868\">H00868</a>  Stapes ankylosis with broad thumb and toes"]},{"values":["<a href=\"/entry/H00873\">H00873</a>  Cousin syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00886\">H00886</a>  Donnai-Barrow syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00889\">H00889</a>  Lujan-Fryns syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00935\">H00935</a>  Cold-induced sweating syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00900\">H00900</a>  Geleophysic dysplasia"]},{"values":["<a href=\"/entry/H00914\">H00914</a>  Warsaw breakage syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00915\">H00915</a>  Tuberous sclerosis complex"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00922\">H00922</a>  Schinzel-Giedion midface retraction syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00934\">H00934</a>  Caudal duplication anomaly"]},{"values":["<a href=\"/entry/H00926\">H00926</a>  Growth retardation, developmental delay, coarse facies, and early death"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00943\">H00943</a>  TARP syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00946\">H00946</a>  Arts syndrome"]},{"values":["<a href=\"/entry/H00950\">H00950</a>  Arthrogryposis, renal dysfunction, and cholestasis"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00965\">H00965</a>  RAPADILINO syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00997\">H00997</a>  CATSHL syndrome"]},{"values":["<a href=\"/entry/H00968\">H00968</a>  Raine syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00969\">H00969</a>  Skeletal defects, genital hypoplasia, and mental retardation"]},{"values":["<a href=\"/entry/H00972\">H00972</a>  Endocrine-cerebro-osteodysplasia syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00977\">H00977</a>  Trichorhinophalangeal syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00980\">H00980</a>  Nevo syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00986\">H00986</a>  Multiple pterygium syndrome"]},{"values":["<a href=\"/entry/H00987\">H00987</a>  Fetal akinesia deformation sequence"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00992\">H00992</a>  Seckel syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00993\">H00993</a>  Microcephalic osteodysplastic primordial dwarfism, type I (MOPD I)"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00991\">H00991</a>  Microcephalic osteodysplastic primordial dwarfism, type II (MOPD II)"]},{"values":["<a href=\"/entry/H01008\">H01008</a>  C syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02047\">H02047</a>  Bohring-Opitz syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01035\">H01035</a>  Corpus callosum, agenesis of, with mental retardation, ocular coloboma and micrognathia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01156\">H01156</a>  STAR syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01192\">H01192</a>  Lysyl hydroxylase 3 deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01195\">H01195</a>  VACTERL/VATER association"]},{"values":["<a href=\"/entry/H01215\">H01215</a>  Simpson-Golabi-Behmel syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01220\">H01220</a>  Congenital cataracts, facial dysmorphism, and neuropathy"]},{"values":["<a href=\"/entry/H01255\">H01255</a>  Juvenile-onset dystonia"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01265\">H01265</a>  Hydrolethalus syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01271\">H01271</a>  Hypoparathyroidism with sensorineural deafness and renal dysplasia"]},{"values":["<a href=\"/entry/H01281\">H01281</a>  Lathosterolosis"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01289\">H01289</a>  Mulibrey nanism"]},{"values":["<a href=\"/entry/H01292\">H01292</a>  Nance-Horan syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01308\">H01308</a>  Macrocephaly macrosomia facial dysmorphism syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01370\">H01370</a>  SHORT syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01385\">H01385</a>  Rienhoff syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01403\">H01403</a>  Coffin-Siris syndrome"]},{"values":["<a href=\"/entry/H01435\">H01435</a>  Congenital asplenia"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01764\">H01764</a>  Polysplenia syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01497\">H01497</a>  Temtamy preaxial brachydactyly syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01412\">H01412</a>  Perlman syndrome"]},{"values":["<a href=\"/entry/H01413\">H01413</a>  Adams-Oliver syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01496\">H01496</a>  Spondyloocular syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01568\">H01568</a>  3C syndrome"]},{"values":["<a href=\"/entry/H01569\">H01569</a>  CHOPS syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01573\">H01573</a>  Zimmermann-Laband syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01752\">H01752</a>  ATR-X syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01769\">H01769</a>  ZTTK syndrome"]},{"values":["<a href=\"/entry/H01776\">H01776</a>  Aicardi syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01793\">H01793</a>  Young-Simpson syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01794\">H01794</a>  Genitopatellar syndrome"]},{"values":["<a href=\"/entry/H01795\">H01795</a>  Blepharophimosis-mental retardation syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01788\">H01788</a>  Klippel-Trenaunay-Weber syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01797\">H01797</a>  Webb-Dattani syndrome"]},{"values":["<a href=\"/entry/H01806\">H01806</a>  Tenorio syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01814\">H01814</a>  Stromme syndrome"]},{"values":["<a href=\"/entry/H01816\">H01816</a>  Frank-ter Haar syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01834\">H01834</a>  Marshall-Smith syndrome"]},{"values":["<a href=\"/entry/H01838\">H01838</a>  Mandibulofacial dysostosis with microcephaly"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01839\">H01839</a>  Burn-McKeown syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01840\">H01840</a>  Moebius syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01843\">H01843</a>  Cerebrocostomandibular syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01844\">H01844</a>  Diaphanospondylodysostosis"]},{"values":["<a href=\"/entry/H01845\">H01845</a>  Catel-Manzke syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01847\">H01847</a>  Thrombocytopenia-absent radius syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01850\">H01850</a>  Hartsfield syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01857\">H01857</a>  Filippi syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01872\">H01872</a>  Microcephaly-capillary malformation syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01876\">H01876</a>  Microcephaly with or without chorioretinopathy, lymphedema, or mental retardation"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01878\">H01878</a>  Al-Raqad syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01879\">H01879</a>  Wiedemann-Steiner syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01880\">H01880</a>  Autosomal recessive microcephaly and chorioretinopathy"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01885\">H01885</a>  Megalencephaly-polymicrogyria-polydactyly-hydrocephalus syndrome"]},{"values":["<a href=\"/entry/H01886\">H01886</a>  Van den Ende-Gupta syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01887\">H01887</a>  3MC syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01888\">H01888</a>  Carpenter syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01889\">H01889</a>  Meier-Gorlin syndrome"]},{"values":["<a href=\"/entry/H01893\">H01893</a>  Lateral meningocele syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01904\">H01904</a>  Microphthalmia with linear skin defects syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01908\">H01908</a>  Carey-Fineman-Ziter syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01912\">H01912</a>  Congenital lipomatous overgrowth, vascular malformations, and epidermal nevi"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01913\">H01913</a>  Renpenning syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01914\">H01914</a>  Christianson syndrome"]},{"values":["<a href=\"/entry/H01915\">H01915</a>  Borjeson-Forssman-Lehmann syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01916\">H01916</a>  Stocco dos Santos X-linked mental retardation syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01917\">H01917</a>  CK syndrome"]},{"values":["<a href=\"/entry/H01919\">H01919</a>  Proud syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01922\">H01922</a>  Infantile hypotonia with psychomotor retardation and characteristic facies"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01923\">H01923</a>  Microcephaly, short stature, and impaired glucose metabolism"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01928\">H01928</a>  Smith-Kingsmore syndrome"]},{"values":["<a href=\"/entry/H01930\">H01930</a>  Au-Kline syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01931\">H01931</a>  Lethal-type popliteal pterygium syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01932\">H01932</a>  Ablepharon-macrostomia syndrome"]},{"values":["<a href=\"/entry/H01934\">H01934</a>  Barber-Say syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02023\">H02023</a>  Baraitser-Winter syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02046\">H02046</a>  OFC syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02067\">H02067</a>  Boomerang dysplasia"]},{"values":["<a href=\"/entry/H02072\">H02072</a>  Stickler syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02081\">H02081</a>  Marshall syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02082\">H02082</a>  Floating-Harbor syndrome"]},{"values":["<a href=\"/entry/H02095\">H02095</a>  Perrault syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02102\">H02102</a>  Myhre syndrome"]},{"values":["<a href=\"/entry/H02127\">H02127</a>  Yunis-Varon syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02134\">H02134</a>  Microphthalmia with limb anomalies"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02153\">H02153</a>  Megalencephaly-capillary malformation syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02169\">H02169</a>  Hennekam lymphangiectasia-lymphedema syndrome"]},{"values":["<a href=\"/entry/H02180\">H02180</a>  McKusick-Kaufman syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02195\">H02195</a>  MEHMO syndrome"]},{"values":["<a href=\"/entry/H02198\">H02198</a>  Pancreatic agenesis and congenital heart disease"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02218\">H02218</a>  DOORS syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02219\">H02219</a>  DDOD syndrome"]},{"values":["<a href=\"/entry/H02224\">H02224</a>  Grange syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02226\">H02226</a>  Cardiospondylocarpofacial syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02229\">H02229</a>  Terminal osseous dysplasia"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02232\">H02232</a>  CAGSSS syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02233\">H02233</a>  Alazami syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02234\">H02234</a>  Hamamy syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02248\">H02248</a>  MEND syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02249\">H02249</a>  Primrose syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02253\">H02253</a>  Beaulieu-Boycott-Innes syndrome"]},{"values":["<a href=\"/entry/H02254\">H02254</a>  Craniosynostosis and dental anomalies"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02255\">H02255</a>  FDLAB syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02260\">H02260</a>  Chondrodysplasia Chassaing-Lacombe type"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02267\">H02267</a>  Wilson-Turner syndrome"]},{"values":["<a href=\"/entry/H02271\">H02271</a>  Cerebellofaciodental syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02274\">H02274</a>  Cerebellar atrophy, visual impairment, and psychomotor retardation"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02280\">H02280</a>  Complex lethal osteochondrodysplasia"]},{"values":["<a href=\"/entry/H02283\">H02283</a>  IVIC syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02294\">H02294</a>  Tatton-Brown-Rahman syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02297\">H02297</a>  CLAPO syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02298\">H02298</a>  Macrocephaly, dysmorphic facies, and psychomotor retardation"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02303\">H02303</a>  Alopecia-mental retardation syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02324\">H02324</a>  Sacral agenesis with vertebral anomalies"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02325\">H02325</a>  Schaaf-Yang syndrome"]},{"values":["<a href=\"/entry/H02327\">H02327</a>  KBG syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02328\">H02328</a>  Sifrim-Hitz-Weiss syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02334\">H02334</a>  Pierpont syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02337\">H02337</a>  Skraban-Deardorff syndrome"]},{"values":["<a href=\"/entry/H02346\">H02346</a>  Intellectual developmental disorder with short stature, facial anomalies, and speech defects"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02347\">H02347</a>  Thauvin-Robinet-Faivre syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02363\">H02363</a>  Ververi-Brady syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02364\">H02364</a>  Heart and brain malformation syndrome"]},{"values":["<a href=\"/entry/H02365\">H02365</a>  Helsmoortel-van der Aa syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02368\">H02368</a>  Developmental delay with short stature, dysmorphic facial features, and sparse hair"]},{"values":["<a href=\"/entry/H02369\">H02369</a>  IMAGE-I syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02370\">H02370</a>  FILS syndrome"]},{"values":["<a href=\"/entry/H02376\">H02376</a>  Global developmental delay, absent or hypoplastic corpus callosum, and dysmorphic facies"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02378\">H02378</a>  Hypotonia, ataxia, and delayed development syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02381\">H02381</a>  Cleft palate, psychomotor retardation, and distinctive facial features"]},{"values":["<a href=\"/entry/H02382\">H02382</a>  Bainbridge-Ropers syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02383\">H02383</a>  Midface hypoplasia, hearing impairment, elliptocytosis, and nephrocalcinosis"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02391\">H02391</a>  Infantile-onset multisystem neurologic, endocrine, and pancreatic disease"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02394\">H02394</a>  Cleft palate, cardiac defects, and mental retardation"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02422\">H02422</a>  Retinitis pigmentosa with skeletal anomalies"]},{"values":["<a href=\"/entry/H02435\">H02435</a>  Deafness-infertility syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02437\">H02437</a>  Growth retardation, impaired intellectual development, hypotonia, and hepatopathy"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02465\">H02465</a>  Weiss-Kruszka syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02477\">H02477</a>  Cohen-Gibson syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02478\">H02478</a>  CATIFA syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02479\">H02479</a>  Nivelon-Nivelon-Mabille syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02480\">H02480</a>  Fontaine progeroid syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02481\">H02481</a>  Syndromic disorder with short stature"]},{"values":["<a href=\"/entry/H02482\">H02482</a>  ROSAH syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02483\">H02483</a>  Basel-Vanagait-Smirin-Yosef syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02488\">H02488</a>  Cardiac-urogenital syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02492\">H02492</a>  Microcephaly, growth restriction, and increased sister chromatid exchange"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02493\">H02493</a>  Al Kaissi syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02496\">H02496</a>  Cerebellar, ocular, craniofacial, and genital syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02500\">H02500</a>  Congenital interstitial lung disease with nephrotic syndrome and epidermolysis bullosa"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02503\">H02503</a>  Richieri-Costa-Pereira syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02506\">H02506</a>  Cardioacrofacial dysplasia"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02508\">H02508</a>  Agenesis of corpus callosum, cardiac, ocular, and genital syndrome"]}]}],"expanded":false,"values":["<b>Congenital malformations</b>"]},{"children":[],"expanded":false,"values":[]},{"expanded":false,"children":[{"children":[{"values":["<a href=\"/entry/H00478\">H00478</a>  Prader-Willi syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01732\">H01732</a>  Angelman syndrome"]},{"values":["<a href=\"/entry/H01552\">H01552</a>  Down syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01562\">H01562</a>  Patau syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01564\">H01564</a>  Edwards syndrome"]},{"values":["<a href=\"/entry/H01439\">H01439</a>  Williams-Beuren syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00465\">H00465</a>  Fragile X syndrome"]},{"values":["<a href=\"/entry/H00561\">H00561</a>  Brachydactyly-mental retardation syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01004\">H01004</a>  Velocardiofacial syndrome"]},{"values":["<a href=\"/entry/H01223\">H01223</a>  Mental retardation-stereotypic movements-epilepsy and/or cerebral malformations"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01238\">H01238</a>  Phelan-McDermid syndrome"]},{"values":["<a href=\"/entry/H01790\">H01790</a>  Emanuel syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01791\">H01791</a>  Smith-Magenis syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01731\">H01731</a>  Fragile X tremor/ataxia syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01801\">H01801</a>  Kagami-Ogata syndrome"]},{"values":["<a href=\"/entry/H01792\">H01792</a>  1p36 deletion syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01525\">H01525</a>  22q11.2 deletion syndrome"]},{"values":["<a href=\"/entry/H01773\">H01773</a>  4p deletion syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H00764\">H00764</a>  Chromosme 5p deletion syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01861\">H01861</a>  Chromosome 15q24 microdeletion syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01877\">H01877</a>  Chromosome 15q13.3 microdeletion syndrome"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01831\">H01831</a>  Ring chromosome 20 syndrome"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01288\">H01288</a>  Mosaic variegated aneuploidy syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02103\">H02103</a>  DeSanto-Shinawi syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02121\">H02121</a>  Koolen-De Vries syndrome"]},{"values":["<a href=\"/entry/H02146\">H02146</a>  Glass syndrome"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02156\">H02156</a>  Lamb-Shaffer syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02471\">H02471</a>  Brain malformations with urinary tract defects"]}],"expanded":false,"values":["Chromosomal abnormalities"]},{"expanded":false,"children":[{"children":[],"expanded":false,"values":["<a href=\"/entry/H00237\">H00237</a>  Diamond-Blackfan anemia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00439\">H00439</a>  Shwachman-Diamond syndrome"]},{"values":["<a href=\"/entry/H00507\">H00507</a>  Dyskeratosis congenita"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00518\">H00518</a>  Metaphyseal dysplasia without hypotrichosis"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01966\">H01966</a>  Cartilage-hair hypoplasia"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01967\">H01967</a>  Anauxetic dysplasia"]},{"values":["<a href=\"/entry/H00610\">H00610</a>  Treacher Collins syndrome"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00616\">H00616</a>  Bowen-Conradi syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00621\">H00621</a>  Alopecia neurologic defects and endocrinopathy syndrome"]},{"values":["<a href=\"/entry/H00788\">H00788</a>  Hoyeraal-Hreidarsson syndrome"],"expanded":false,"children":[]}],"values":["Ribosomopathies"]}],"values":["<b>Other congenital disorders</b>"]},{"values":[],"expanded":false,"children":[]},{"values":["<b>Other diseases</b>"],"children":[{"expanded":false,"children":[{"children":[],"expanded":false,"values":["<a href=\"/entry/H00862\">H00862</a>  Tourette syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01895\">H01895</a>  Attention deficit hyperactivity disorder (ADHD)"]},{"values":["<a href=\"/entry/H01453\">H01453</a>  Obsessive-Compulsive and Related Disorder"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01450\">H01450</a>  Obsessive-compulsive disorder"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01448\">H01448</a>  Hoarding disorder"]},{"values":["<a href=\"/entry/H00864\">H00864</a>  Trichotillomania"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01449\">H01449</a>  Excoriation disorder"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01447\">H01447</a>  Body dysmorphic disorder"]},{"values":["<a href=\"/entry/H01611\">H01611</a>  Alcohol dependence [PATH:<a href=\"/pathway/hsa05034\">hsa05034</a>]"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01646\">H01646</a>  Major depressive disorder"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01653\">H01653</a>  Bipolar disorder"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01649\">H01649</a>  Schizophrenia"]},{"values":["<a href=\"/entry/H01662\">H01662</a>  Generalized anxiety disorder"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H01664\">H01664</a>  Panic disorder"],"expanded":false,"children":[]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01670\">H01670</a>  Social anxiety disorder"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01671\">H01671</a>  Neurosis"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01703\">H01703</a>  Eating Disorders"]},{"values":["<a href=\"/entry/H02111\">H02111</a>  Autism"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H02371\">H02371</a>  Intellectual developmental disorder with autism and speech delay"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00440\">H00440</a>  Rett syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01882\">H01882</a>  Asperger syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01899\">H01899</a>  Dyslexia"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00902\">H00902</a>  Speech-language disorder 1"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00480\">H00480</a>  X-linked mental retardation"]},{"values":["<a href=\"/entry/H00658\">H00658</a>  Syndromic X-linked mental retardation"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H00768\">H00768</a>  Autosomal recessive mental retardation"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00773\">H00773</a>  Autosomal dominant mental retardation"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01911\">H01911</a>  Syndromic autosomal recessive mental retardation"]},{"values":["<a href=\"/entry/H02459\">H02459</a>  Syndromic neurodevelopmental disorder"],"children":[],"expanded":false},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02397\">H02397</a>  Neurodevelopmental disorder with movement abnormalities, abnormal gait, and autistic features"]},{"values":["<a href=\"/entry/H02460\">H02460</a>  Neurodevelopmental disorder with dysmorphic facies and skeletal anomalies"],"expanded":false,"children":[]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H02461\">H02461</a>  Neurodevelopmental disorder with microcephaly"]},{"values":["<a href=\"/entry/H02305\">H02305</a>  RERE-related neurodevelopmental syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02463\">H02463</a>  Syndromic intellectual developmental disorder"],"children":[],"expanded":false},{"values":["<a href=\"/entry/H01306\">H01306</a>  FRA12A mental retardation"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01514\">H01514</a>  Landau-Kleffner syndrome"]},{"values":["<a href=\"/entry/H02387\">H02387</a>  Snijders Blok-Fisher syndrome"],"expanded":false,"children":[]},{"values":["<a href=\"/entry/H02490\">H02490</a>  Gabriele-de Vries syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02507\">H02507</a>  Pilarowski-Bjornsson syndrome"]}],"values":["Mental and behavioural disorders"]},{"children":[{"values":["<a href=\"/entry/H00815\">H00815</a>  H syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00818\">H00818</a>  Birt-Hogg-Dube syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00823\">H00823</a>  ABCD syndrome"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00876\">H00876</a>  Mismatch repair deficiency"]},{"children":[],"expanded":false,"values":["<a href=\"/entry/H00994\">H00994</a>  Familial skewed X-chromosome inactivation"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H00881\">H00881</a>  Li-Fraumeni syndrome"]},{"values":["<a href=\"/entry/H01134\">H01134</a>  Rhabdoid predisposition syndrome"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H01461\">H01461</a>  Crow-Fukase syndrome"]},{"expanded":false,"children":[],"values":["<a href=\"/entry/H01820\">H01820</a>  Carney complex"]},{"values":["<a href=\"/entry/H00804\">H00804</a>  Multiple cutaneous and uterine leiomyomata"],"children":[],"expanded":false},{"children":[],"expanded":false,"values":["<a href=\"/entry/H02129\">H02129</a>  Prune belly syndrome"]}],"expanded":false,"values":["Others"]}],"expanded":false}],"expanded":true,"values":[]}
  }
  

  let isSmartPhone = navigator.userAgent.match(/iPhone|Android.+Mobile/)
  let isSmallView = (window.matchMedia && window.matchMedia('(max-width:640px)').matches)

  // ããã«ã®ééãã©ã°ãæªå®ã®å ´åã¯ããã¤ã¹ãµã¤ãºç­ãã¿ã¦æ±ºããã
  let e = document.getElementById('displayControlPanel')
  if (e != null) {
    if (e.value === '') {
      e.value = (isSmartPhone || isSmallView) ? 'hide' : 'show'
    }
  }
      </script>
     </input>
    </input>
   </input>
  </input>
 </body>
</html>'''

# %%
l1=re.findall('/entry/[H0-9]+',qwerty)
l2=[]
for i in l1:
    l2.append('https://www.kegg.jp'+i)

# %%
len(l2)
# Out:
# 2260

# %%
for i in l2:
    print(i)
# Out:
# https://www.kegg.jp/entry/H02420
# https://www.kegg.jp/entry/H00016
# https://www.kegg.jp/entry/H01508
# https://www.kegg.jp/entry/H01509
# https://www.kegg.jp/entry/H01559
# https://www.kegg.jp/entry/H00054
# https://www.kegg.jp/entry/H00055
# https://www.kegg.jp/entry/H00017
# https://www.kegg.jp/entry/H00018
# https://www.kegg.jp/entry/H00034
# https://www.kegg.jp/entry/H00020
# https://www.kegg.jp/entry/H00044
# https://www.kegg.jp/entry/H00048
# https://www.kegg.jp/entry/H02302
# https://www.kegg.jp/entry/H01557
# https://www.kegg.jp/entry/H00046
# https://www.kegg.jp/entry/H00047
# https://www.kegg.jp/entry/H00019
# https://www.kegg.jp/entry/H00045
# https://www.kegg.jp/entry/H01591
# https://www.kegg.jp/entry/H00014
# https://www.kegg.jp/entry/H00013
# https://www.kegg.jp/entry/H00015
# https://www.kegg.jp/entry/H00038
# https://www.kegg.jp/entry/H00039
# https://www.kegg.jp/entry/H00040
# https://www.kegg.jp/entry/H01555
# https://www.kegg.jp/entry/H01463
# ...

# %%
import json

# %%
#!pip install url_normalize

# %%
import logging
import time
import json
from urllib.parse import urljoin
from url_normalize import url_normalize
import requests
from bs4 import BeautifulSoup

logging.basicConfig(format = '%(asctime)s %(levelname)s:%(message)s', level = logging.INFO)

class Crawler:

    def __init__(self, urls = [], domains = [], limit = 50):
        
        self.visited_urls = []
        self.urls_to_visit = urls
        self.limit = limit
        self.domains = domains
        return

    def download_url(self, url):
        try:
            time.sleep(1)
            return requests.get(url).text
        
        except Exception as E:
            return ''

    def get_linked_urls(self, url, html):
        soup = BeautifulSoup(html, 'html.parser')
        
        for link in soup.find_all('a'):
            
            path = link.get('href')
            
            if path and (path.startswith('/') or not path.startswith('https://')):
                path = urljoin(url, path)

            yield path

    def domain_check(self, url):
        for domain in self.domains:
            if domain in url:
                return True
        return False

    def add_url_to_visit(self, url):
        total_crawled = len(self.visited_urls) + len(self.urls_to_visit)
        
        if total_crawled >= self.limit:
            return
        
        if not url or url == '':
            return

        if self.domain_check(url) == False:
            return

        if url not in self.visited_urls and url not in self.urls_to_visit:
            self.urls_to_visit.append(url)
            return

    def crawl(self, url):
        html = self.download_url(url)
        
        for url in self.get_linked_urls(url, html):
            self.add_url_to_visit(url)

    def run(self):
        while self.urls_to_visit:
            url = self.urls_to_visit.pop(0)
            
            logging.info(f' Fetching {url}')
            
            try:
                self.crawl(url)
            
            except Exception:
                logging.exception(f' Failed to fetch {url}')
            
            finally:
                self.visited_urls.append(url)

if __name__ == '__main__':

    crawler = Crawler(urls = ['https://www.kegg.jp/brite/br08402'], domains = ['https://www.kegg.jp/'], limit = 30000)
    crawler.run()

    display = False
    
    if display == True:
        print(crawler.visited_urls, flush = True)

    # Saving visited URLs
    with open('crawled_URLs.json', 'w+') as f:
        json.dump(crawler.visited_urls, f)

# %%
table={'Name':[],'Overview':[],'Symptoms':[],'When to see a doctor':[],'Causes':[],'Risk factors':[],'Complications':[]
      ,'Prevention':[]}

# %%
for i in urls:
    print(i)  
    try:
        url = i
        response = requests.get(url)
        html = response.text
        soup = BeautifulSoup(html,'html.parser')
        table['Name']=soup.find_all('h1')[0].text.strip()
        if len(soup.find_all('h2',string=re.compile('Overview')))==0:
            table['Overview'].append('')
        else:
            mark=soup.find('h2',string=re.compile('Overview'))
            plot=[]
            for elt in mark.find_next_siblings():
                if re.search('h[0-9]',elt.name):
                    break
                if hasattr(elt, "text"):
                    plot.append(elt.text)
            table['Overview'].append("".join(plot))
        if len(soup.find_all('h2',string=re.compile('Symptoms')))==0:
            table['Symptoms'].append('')
        else:
            mark=soup.find('h2',string=re.compile('Symptoms'))
            plot=[]
            for elt in mark.find_next_siblings():
                if re.search('h[0-9]',elt.name):
                    break
                if hasattr(elt, "text"):
                    plot.append(elt.text)
            table['Symptoms'].append("".join(plot))
        if len(soup.find_all('h2',string=re.compile('Symptoms')))==0:
            table['Symptoms'].append('')
        else:
            mark=soup.find('h2',string=re.compile('Symptoms'))
            plot=[]
            for elt in mark.find_next_siblings():
                if re.search('h[0-9]',elt.name):
                    break
                if hasattr(elt, "text"):
                    plot.append(elt.text)
            table['Symptoms'].append("".join(plot))
        if len(soup.find_all('h2',string=re.compile('When to see a doctor')))==0:
            table['When to see a doctor'].append('')
        else:
            mark=soup.find('h2',string=re.compile('When to see a doctor'))
            plot=[]
            for elt in mark.find_next_siblings():
                if re.search('h[0-9]',elt.name):
                    break
                if hasattr(elt, "text"):
                    plot.append(elt.text)
            table['When to see a doctor'].append("".join(plot))
        if len(soup.find_all('h2',string=re.compile('Causes')))==0:
            table['Causes'].append('')
        else:
            mark=soup.find('h2',string=re.compile('Causes'))
            plot=[]
            for elt in mark.find_next_siblings():
                if re.search('h[0-9]',elt.name):
                    break
                if hasattr(elt, "text"):
                    plot.append(elt.text)
            table['Causes'].append("".join(plot))
        if len(soup.find_all('h2',string=re.compile('Risk factors')))==0:
            table['Risk factors'].append('')
        else:
            mark=soup.find('h2',string=re.compile('Risk factors'))
            plot=[]
            for elt in mark.find_next_siblings():
                if re.search('h[0-9]',elt.name):
                    break
                if hasattr(elt, "text"):
                    plot.append(elt.text)
            table['Risk factors'].append("".join(plot))
        if len(soup.find_all('h2',string=re.compile('Complications')))==0:
            table['Complications'].append('')
        else:
            mark=soup.find('h2',string=re.compile('Complications'))
            plot=[]
            for elt in mark.find_next_siblings():
                if re.search('h[0-9]',elt.name):
                    break
                if hasattr(elt, "text"):
                    plot.append(elt.text)
            table['Complications'].append("".join(plot))
        if len(soup.find_all('h2',string=re.compile('Prevention')))==0:
            table['Prevention'].append('')
        else:
            mark=soup.find('h2',string=re.compile('Prevention'))
            plot=[]
            for elt in mark.find_next_siblings():
                if re.search('h[0-9]',elt.name):
                    break
                if hasattr(elt, "text"):
                    plot.append(elt.text)
            table['Prevention'].append("".join(plot))
    except IndexError:
        err_url.append(i)

# %%
table={'Name':[],'Overview':[],'Symptoms':[],'When to see a doctor':[],'Causes':[],'Risk factors':[],'Complications':[]
      ,'Prevention':[]}
